# %% [markdown]
# # XGBRegression (P,A,D coordinates to LMA Features)

# %%
"""
Using the identified emotions of each LMA feature set rather than the normal ones
"""
# Out:
# '\nUsing the identified emotions of each LMA feature set rather than the normal ones\n'

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.lines as mlines

import tensorflow as tf

import sklearn
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold

import xgboost as xgb

xgb.set_config(verbosity=0)

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import normalize

from sklearn.utils import shuffle
import math
import joblib
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
model_p = xgb.XGBRegressor(verbosity=0)
model_p.load_model("../../emotion_classifier/model_training/models/bandai_l2p_model.json")

model_a = xgb.XGBRegressor(verbosity=0)
model_a.load_model("../../emotion_classifier/model_training/models/bandai_l2a_model.json")

model_d = xgb.XGBRegressor(verbosity=0)
model_d.load_model("../../emotion_classifier/model_training/models/bandai_l2d_model.json")

scaler = joblib.load('../../emotion_classifier/model_training/datasets/scalers/standardizers/S_BANDAI_5frame.pkl')

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv('datasets/BANDAI_5frame.csv')
dataset.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.130036                 0.335475
# 1           0.348051                 0.145184                 0.256784
# 2           0.320294                 0.206306                 0.180224
# 3           0.400389                 0.287300                 0.136974
# 4           0.465923                 0.356129                 0.136171
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.184473                   0.310089
# 1           0.455501                   0.197954                   0.284215
# 2           0.380190                   0.234406                   0.259905
# 3           0.319861                   0.279208                   0.239450
# 4           0.309995                   0.313229                   0.224432
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.210679                  0.093915
# 1                  0.172405                  0.104876
# 2                  0.133006                  0.127385
# 3                  0.112632                  0.156856
# 4                  0.112950                  0.186680
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.236151                 0.223894  ...     -0.137483
# 1                   0.236151                 0.223894  ...     -0.072441
# 2                   0.236151                 0.223894  ...     -0.039016
# 3                   0.236151                 0.223894  ...     -0.036825
# 4                   0.236151                 0.223894  ...     -0.054338
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0   -0.139467                       0.092920                       0.196129
# 1   -0.095084                       0.048935                       0.032804
# 2   -0.093423                       0.030819                       0.043059
# 3   -0.101489                       0.044534                       0.054382
# 4   -0.117573                       0.044670                       0.036618
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.221155                       0.137483
# 1                       0.070625                       0.072096
# 2                       0.028182                       0.036532
# 3                       0.015679                       0.012813
# 4                       0.020074                       0.022012
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     0.139467       0.05       -0.4        0.0
# 1                     0.045111       0.05       -0.4        0.0
# 2                     0.014232       0.05       -0.4        0.0
# 3                     0.021506       0.05       -0.4        0.0
# 4                     0.024961       0.05       -0.4        0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.9, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])

train_dataset = shuffle(train_dataset)
test_dataset = shuffle(test_dataset)
# Out:
# No Training Samples: 70696
# No Test Samples: 7855

# %% [markdown]
# ### Split Features from Targets

# %%
train_emotions = pd.concat([train_dataset.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
train_emotions_OG = train_emotions.copy()

test_emotions = pd.concat([test_dataset.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
test_emotions_OG = test_emotions.copy()

# %%
train_dataset_scaled = scaler.transform(train_dataset)
test_dataset_scaled = scaler.transform(test_dataset)

# %%
train_emotions_p = model_p.predict(train_dataset_scaled)
train_emotions_a = model_a.predict(train_dataset_scaled)
train_emotions_d = model_d.predict(train_dataset_scaled)

for i in range(len(train_dataset_scaled)):
    train_emotions.iloc[i] = [train_emotions_p[i], train_emotions_a[i], train_emotions_d[i]]

train_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 52519  -0.099846  -0.549837  -0.149424
# 66731  -0.093649  -0.553372  -0.147966
# 17920   0.302760   0.382684   0.610001
# 43712   0.057933  -0.404123  -0.010288
# 34534   0.095309   0.576228   0.377522

# %%
train_emotions_OG.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 52519      -0.10      -0.55      -0.15
# 66731      -0.10      -0.55      -0.15
# 17920       0.30       0.40       0.60
# 43712       0.05      -0.40       0.00
# 34534       0.10       0.60       0.40

# %%
test_emotions_p = model_p.predict(test_dataset_scaled)
test_emotions_a = model_a.predict(test_dataset_scaled)
test_emotions_d = model_d.predict(test_dataset_scaled)

for i in range(len(test_dataset_scaled)):
    test_emotions.iloc[i] = [test_emotions_p[i], test_emotions_a[i], test_emotions_d[i]]


test_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 28404   0.268875   0.394604   0.569668
# 19173  -0.519783   0.730773   0.917185
# 55913  -0.098935  -0.553049  -0.145300
# 32130   0.215776  -0.825093  -0.369049
# 67969  -0.098603  -0.550084  -0.149676

# %%
test_emotions_OG.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 28404        0.3       0.40       0.60
# 19173       -0.5       0.80       0.90
# 55913       -0.1      -0.55      -0.15
# 32130        0.2      -0.75      -0.30
# 67969       -0.1      -0.55      -0.15

# %%
train_y_sets = []
test_y_sets = []
# List of np.arrays each containing the LMA features of a given column (i.e one list per feature)

# %%
for colname in train_dataset.columns:
    train_y_sets.append(pd.concat([train_dataset.pop(x) for x in [colname]], axis=1))
    
for colname in test_dataset.columns:
    test_y_sets.append(pd.concat([test_dataset.pop(x) for x in [colname]], axis=1))

# %%
train_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 52519  -0.099846  -0.549837  -0.149424
# 66731  -0.093649  -0.553372  -0.147966
# 17920   0.302760   0.382684   0.610001
# 43712   0.057933  -0.404123  -0.010288
# 34534   0.095309   0.576228   0.377522

# %%
for i in range(len(train_y_sets)):
    print(train_y_sets[i].columns[0])

# %% [markdown]
# ## Define Model

# %%
xgbr = xgb.XGBRegressor(verbosity=1) 

params = {
        'eta': [0.01, 0.05, 0.1],
        'min_child_weight': [1, 5, 11, 21],
        'max_depth': [3, 6, 10, 15],
        'gamma': [0, 0.001, 0.01],
        'subsample': [0.75, 1],
        'colsample_bytree': [0.75, 1],
        'lambda': [1, 1.25],
        'alpha': [0.0, 0.25]
        }

models = []

for i in range(len(train_y_sets)):
    models.append(
        xgb.XGBRegressor(
                    n_estimators=1500, learning_rate=0.05, max_depth=6, min_child_weight=11, 
                    reg_alpha=0.25, reg_lambda=1.25, gamma=0.01,
                    subsample=0.75, colsample_bytree=0.75, objective="reg:squarederror",
                    tree_method='gpu_hist'
                )
    )

# %% [markdown]
# ## Train Model

# %%
for i in range(len(models)):
    print(train_y_sets[i].columns[0])
    models[i].fit(train_emotions, train_y_sets[i])

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Training Score

# %%
for i in range(len(models)):
    score = models[i].score(train_emotions, train_y_sets[i])
    print(train_y_sets[i].columns[0])
    print("Training score: ", score)

    print()

# %% [markdown]
# ### Test Set MAE & MSE

# %%
for i in range(len(models)):
    pred_y = models[i].predict(test_emotions)
    mse = mean_squared_error(test_y_sets[i], pred_y)
    mae = mean_absolute_error(test_y_sets[i], pred_y)
    print(test_y_sets[i].columns[0])
    print("MSE: %.2f" % mse)
    print("MAE: %.2f" % mae)
    print("Example: ", test_y_sets[i].iloc[0][0])
    print()

# %%
generated_features = []

for i in range(len(models)):
    pred_y = models[i].predict(test_emotions)
    generated_features.append(pred_y)
    
    
rows = []
for i in range(len(generated_features[0])):
    row = []
    for j in range(len(models)):
        row.append(generated_features[j][i])
    rows.append(row)
    
print(len(rows))
        
generated = pd.DataFrame(rows, columns=["max_hand_distance",
          "avg_l_hand_hip_distance",
          "avg_r_hand_hip_distance",
          "max_stride_length",
          "avg_l_hand_chest_distance",
          "avg_r_hand_chest_distance",
          "avg_l_elbow_hip_distance",
          "avg_r_elbow_hip_distance",
          "avg_chest_pelvis_distance",
          "avg_neck_chest_distance",
          
          "avg_total_body_volume",
          "avg_lower_body_volume",
          "avg_upper_body_volume",
          
          "avg_triangle_area_hands_neck",
          "avg_triangle_area_feet_hips",
          
          "l_hand_speed",
          "r_hand_speed",
          "l_foot_speed",
          "r_foot_speed",
          "neck_speed",
          
          "l_hand_acceleration_magnitude",
          "r_hand_acceleration_magnitude",
          "l_foot_acceleration_magnitude",
          "r_foot_acceleration_magnitude",
          "neck_acceleration_magnitude",
    ])

generated.head()

# %%
generated_scaled = scaler.transform(generated)

gen_emotions_p = model_p.predict(generated_scaled)
gen_emotions_a = model_a.predict(generated_scaled)
gen_emotions_d = model_d.predict(generated_scaled)

rows = []
for i in range(len(generated_scaled)):
    rows.append([gen_emotions_p[i], gen_emotions_a[i], gen_emotions_d[i]])

gen_emotions = pd.DataFrame(rows, columns=[
            "EMOTION_P", "EMOTION_A", "EMOTION_D"
         ])

gen_emotions.head()

# %%
import random

mae_errors = mean_absolute_error(test_emotions, gen_emotions, multioutput='raw_values')
mse_errors = mean_squared_error(test_emotions, gen_emotions, multioutput='raw_values')

features = ["PLEASURE", "AROUSAL", "DOMINANCE"
         ]

print("Overall MAE: " + str(mean_absolute_error(test_emotions, gen_emotions)))

print()
for i in range(len(mse_errors)):
    print("==" + features[i] + "==")
    print("MSE: %.5f" % mse_errors[i])
    print("MAE: %.5f" % mae_errors[i])
    print()
    
for i in range(30):
    row = random.randint(0, len(test_emotions))

    print("Real: " + str([test_emotions_OG.iloc[row,0], test_emotions_OG.iloc[row,1], test_emotions_OG.iloc[row,2]]))
    print("Predicted: " + str([test_emotions.iloc[row,0], test_emotions.iloc[row,1], test_emotions.iloc[row,2]]))
    print("Generated: " + str([gen_emotions.iloc[row,0], gen_emotions.iloc[row,1], gen_emotions.iloc[row,2]]))
    print()

# %% [markdown]
# ### Prediction Examples

# %%
model_p = xgb.XGBRegressor(verbosity=0)
model_p.load_model("../../emotion_classifier/model_training/models/bandai_l2p_model.json")

model_a = xgb.XGBRegressor(verbosity=0)
model_a.load_model("../../emotion_classifier/model_training/models/bandai_l2a_model.json")

model_d = xgb.XGBRegressor(verbosity=0)
model_d.load_model("../../emotion_classifier/model_training/models/bandai_l2d_model.json")

scaler = joblib.load('../../emotion_classifier/model_training/datasets/scalers/standardizers/S_BANDAI_5frame.pkl')

# %%
index = 4

real_coordinates = np.asarray([test_X.iloc[index]])

generated_features = []
for i in range(len(models)):
    generated_features.append(models[i].predict(real_coordinates)[0])
    #print(test_y_sets[i].columns[0], " - ", generated_features[i])
    
generated_features = pd.DataFrame([generated_features], columns=["max_hand_distance",
          "avg_l_hand_hip_distance",
          "avg_r_hand_hip_distance",
          "max_stride_length",
          "avg_l_hand_chest_distance",
          "avg_r_hand_chest_distance",
          "avg_l_elbow_hip_distance",
          "avg_r_elbow_hip_distance",
          "avg_chest_pelvis_distance",
          "avg_neck_chest_distance",
          
          "avg_total_body_volume",
          "avg_lower_body_volume",
          "avg_upper_body_volume",
          
          "avg_triangle_area_hands_neck",
          "avg_triangle_area_feet_hips",
          
          "l_hand_speed",
          "r_hand_speed",
          "l_foot_speed",
          "r_foot_speed",
          "neck_speed",
          
          "l_hand_acceleration_magnitude",
          "r_hand_acceleration_magnitude",
          "l_foot_acceleration_magnitude",
          "r_foot_acceleration_magnitude",
          "neck_acceleration_magnitude",
    ])

generated_features = scaler.transform(generated_features)

y_p = model_p.predict(generated_features)
y_a = model_a.predict(generated_features)
y_d = model_d.predict(generated_features)

print('Real: %s' % np.asarray(real_coordinates))
print('Predicted: %s' % [y_p[0], y_a[0], y_d[0]])

# %% [markdown]
# ## Save Models

# %%
# save to JSON

# %% [markdown]
# ## Load Models

# %% [markdown]
# # Hyperparameter Grid Search with XGBoost

# %%
from datetime import datetime
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

import sklearn
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_absolute_error


import xgboost as xgb

xgb.set_config(verbosity=2)

from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
import joblib

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv('datasets/BANDAI_5frame.csv')
dataset.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.130036                 0.335475
# 1           0.348051                 0.145184                 0.256784
# 2           0.320294                 0.206306                 0.180224
# 3           0.400389                 0.287300                 0.136974
# 4           0.465923                 0.356129                 0.136171
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.184473                   0.310089
# 1           0.455501                   0.197954                   0.284215
# 2           0.380190                   0.234406                   0.259905
# 3           0.319861                   0.279208                   0.239450
# 4           0.309995                   0.313229                   0.224432
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.210679                  0.093915
# 1                  0.172405                  0.104876
# 2                  0.133006                  0.127385
# 3                  0.112632                  0.156856
# 4                  0.112950                  0.186680
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.236151                 0.223894  ...     -0.137483
# 1                   0.236151                 0.223894  ...     -0.072441
# 2                   0.236151                 0.223894  ...     -0.039016
# 3                   0.236151                 0.223894  ...     -0.036825
# 4                   0.236151                 0.223894  ...     -0.054338
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0   -0.139467                       0.092920                       0.196129
# 1   -0.095084                       0.048935                       0.032804
# 2   -0.093423                       0.030819                       0.043059
# 3   -0.101489                       0.044534                       0.054382
# 4   -0.117573                       0.044670                       0.036618
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.221155                       0.137483
# 1                       0.070625                       0.072096
# 2                       0.028182                       0.036532
# 3                       0.015679                       0.012813
# 4                       0.020074                       0.022012
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     0.139467       0.05       -0.4        0.0
# 1                     0.045111       0.05       -0.4        0.0
# 2                     0.014232       0.05       -0.4        0.0
# 3                     0.021506       0.05       -0.4        0.0
# 4                     0.024961       0.05       -0.4        0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.85, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])

train_dataset = shuffle(train_dataset)
test_dataset = shuffle(test_dataset)
# Out:
# No Training Samples: 66768
# No Test Samples: 11783

# %% [markdown]
# ### Split Features from Targets

# %%
train_emotions = pd.concat([train_dataset.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
train_emotions_OG = train_emotions.copy()

test_emotions = pd.concat([test_dataset.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
test_emotions_OG = test_emotions.copy()

# %%
train_dataset_scaled = scaler.transform(train_dataset)
test_dataset_scaled = scaler.transform(test_dataset)

# %%
train_emotions_p = model_p.predict(train_dataset_scaled)
train_emotions_a = model_a.predict(train_dataset_scaled)
train_emotions_d = model_d.predict(train_dataset_scaled)

for i in range(len(train_dataset_scaled)):
    train_emotions.iloc[i] = [train_emotions_p[i], train_emotions_a[i], train_emotions_d[i]]

train_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 1215    0.598510   0.410306   0.109578
# 33554   0.049066  -0.378166   0.004800
# 51267   0.194166  -0.733100  -0.282327
# 73542   0.056268  -0.444426  -0.005041
# 16701   0.045859  -0.393998  -0.001824

# %%
train_emotions_OG.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 1215        0.60       0.40        0.1
# 33554       0.05      -0.40        0.0
# 51267       0.20      -0.75       -0.3
# 73542       0.05      -0.40        0.0
# 16701       0.05      -0.40        0.0

# %%
test_emotions_p = model_p.predict(test_dataset_scaled)
test_emotions_a = model_a.predict(test_dataset_scaled)
test_emotions_d = model_d.predict(test_dataset_scaled)

for i in range(len(test_dataset_scaled)):
    test_emotions.iloc[i] = [test_emotions_p[i], test_emotions_a[i], test_emotions_d[i]]


test_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 33591   0.059653  -0.042422   0.221249
# 53950   0.094404  -0.636535  -0.211325
# 58754   0.167364  -0.784619  -0.305917
# 4135   -0.096311  -0.545753  -0.147985
# 21381   0.490266   0.527579   0.301747

# %%
test_emotions_OG.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 33591       0.05      -0.40       0.00
# 53950       0.20      -0.75      -0.30
# 58754       0.20      -0.75      -0.30
# 4135       -0.10      -0.55      -0.15
# 21381       0.80       0.50       0.15

# %%
train_y_sets = []
test_y_sets = []
# List of np.arrays each containing the LMA features of a given column (i.e one list per feature)

# %%
for colname in train_dataset.columns:
    train_y_sets.append(pd.concat([train_dataset.pop(x) for x in [colname]], axis=1))
    
for colname in test_dataset.columns:
    test_y_sets.append(pd.concat([test_dataset.pop(x) for x in [colname]], axis=1))

# %%
train_emotions.head()
# Out:
#        EMOTION_P  EMOTION_A  EMOTION_D
# 1215    0.598510   0.410306   0.109578
# 33554   0.049066  -0.378166   0.004800
# 51267   0.194166  -0.733100  -0.282327
# 73542   0.056268  -0.444426  -0.005041
# 16701   0.045859  -0.393998  -0.001824

# %%
for i in range(len(train_y_sets)):
    print(train_y_sets[i].columns[0])
# Out:
# max_hand_distance
# avg_l_hand_hip_distance
# avg_r_hand_hip_distance
# max_stride_length
# avg_l_hand_chest_distance
# avg_r_hand_chest_distance
# avg_l_elbow_hip_distance
# avg_r_elbow_hip_distance
# avg_chest_pelvis_distance
# avg_neck_chest_distance
# avg_total_body_volume
# avg_lower_body_volume
# avg_upper_body_volume
# avg_triangle_area_hands_neck
# avg_triangle_area_feet_hips
# l_hand_speed
# r_hand_speed
# l_foot_speed
# r_foot_speed
# neck_speed
# l_hand_acceleration_magnitude
# r_hand_acceleration_magnitude
# l_foot_acceleration_magnitude
# r_foot_acceleration_magnitude
# neck_acceleration_magnitude

# %% [markdown]
# ## RandomSearchCV

# %%
# A parameter grid for XGBoost
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
params = {
        'eta': [0.01, 0.05, 0.1, 0.15],
        'min_child_weight': [1, 5, 11, 21],
        'max_depth': [3, 6, 10, 15],
        'gamma': [0, 0.001, 0.01],
        'subsample': [0.75, 1],
        'colsample_bytree': [0.75, 1],
        'lambda': [0.85, 1, 1.25],
        'alpha': [0.0, 0.1, 0.25]
        }

n_iter = 150

# %%
models = []

for i in range(len(train_y_sets)):
    models.append(
        xgb.XGBRegressor(
                    n_estimators=1500, 
                    objective="reg:squarederror",
                    tree_method='gpu_hist'
                )
    )

# %%
# Pleasure
# run randomized search

random_searches = []

for i in range(5):
    print(train_y_sets[i].columns[0])
    
    kfold = KFold(n_splits=2, shuffle=True)

    random_search = RandomizedSearchCV(models[i], param_distributions=params,
                               cv=kfold, scoring='neg_mean_squared_error', n_iter = n_iter)

    start = time.time()
    random_search.fit(train_emotions, train_y_sets[i])
    
    random_searches.append(random_search)

    print("GridSearchCV took %.2f seconds"
          " parameter settings." % ((time.time() - start)))
    print(i)
    print()
# Out:
# max_hand_distance
# GridSearchCV took 2771.96 seconds parameter settings.
# 0
#
# avg_l_hand_hip_distance
# GridSearchCV took 2277.75 seconds parameter settings.
# 1
#
# avg_r_hand_hip_distance
# GridSearchCV took 2996.16 seconds parameter settings.
# 2
#
# max_stride_length
# GridSearchCV took 3656.57 seconds parameter settings.
# 3
#
# avg_l_hand_chest_distance
# GridSearchCV took 2481.93 seconds parameter settings.
# 4

# %%
for i in range(5,10):
    print(train_y_sets[i].columns[0])
    
    kfold = KFold(n_splits=3, shuffle=True)

    random_search = RandomizedSearchCV(models[i], param_distributions=params,
                               cv=kfold, scoring='neg_mean_squared_error', n_iter = n_iter)

    start = time.time()
    random_search.fit(train_emotions, train_y_sets[i])
    
    random_searches.append(random_search)

    print("GridSearchCV took %.2f seconds"
          " parameter settings." % ((time.time() - start)))
    print(i)
    print()
# Out:
# avg_r_hand_chest_distance
# GridSearchCV took 3139.44 seconds parameter settings.
# 5
#
# avg_l_elbow_hip_distance
# GridSearchCV took 3242.82 seconds parameter settings.
# 6
#
# avg_r_elbow_hip_distance
# GridSearchCV took 9917.56 seconds parameter settings.
# 7
#
# avg_chest_pelvis_distance
# GridSearchCV took 1656.44 seconds parameter settings.
# 8
#
# avg_neck_chest_distance
# GridSearchCV took 1590.75 seconds parameter settings.
# 9

# %%
for i in range(10,15):
    print(train_y_sets[i].columns[0])
    
    kfold = KFold(n_splits=3, shuffle=True)

    random_search = RandomizedSearchCV(models[i], param_distributions=params,
                               cv=kfold, scoring='neg_mean_squared_error', n_iter = n_iter)

    start = time.time()
    random_search.fit(train_emotions, train_y_sets[i])
    
    random_searches.append(random_search)

    print("GridSearchCV took %.2f seconds"
          " parameter settings." % ((time.time() - start)))
    print(i)
    print()
# Out:
# avg_total_body_volume
# GridSearchCV took 18339.15 seconds parameter settings.
# 10
#
# avg_lower_body_volume
# GridSearchCV took 7882.80 seconds parameter settings.
# 11
#
# avg_upper_body_volume
# GridSearchCV took 10286.84 seconds parameter settings.
# 12
#
# avg_triangle_area_hands_neck
# GridSearchCV took 8993.73 seconds parameter settings.
# 13
#
# avg_triangle_area_feet_hips
# GridSearchCV took 10404.30 seconds parameter settings.
# 14

# %%
for i in range(15,20):
    print(train_y_sets[i].columns[0])
    
    kfold = KFold(n_splits=3, shuffle=True)

    random_search = RandomizedSearchCV(models[i], param_distributions=params,
                               cv=kfold, scoring='neg_mean_squared_error', n_iter = n_iter)

    start = time.time()
    random_search.fit(train_emotions, train_y_sets[i])
    
    random_searches.append(random_search)

    print("GridSearchCV took %.2f seconds"
          " parameter settings." % ((time.time() - start)))
    print(i)
    print()
# Out:
# l_hand_speed
# GridSearchCV took 3685.12 seconds parameter settings.
# 15
#
# r_hand_speed
# GridSearchCV took 2387.59 seconds parameter settings.
# 16
#
# l_foot_speed
# GridSearchCV took 3236.86 seconds parameter settings.
# 17
#
# r_foot_speed
# GridSearchCV took 3453.18 seconds parameter settings.
# 18
#
# neck_speed
# GridSearchCV took 2921.11 seconds parameter settings.
# 19

# %%
for i in range(20,25):
    print(train_y_sets[i].columns[0])
    
    kfold = KFold(n_splits=3, shuffle=True)

    random_search = RandomizedSearchCV(models[i], param_distributions=params,
                               cv=kfold, scoring='neg_mean_squared_error', n_iter = n_iter)

    start = time.time()
    random_search.fit(train_emotions, train_y_sets[i])
    
    random_searches.append(random_search)

    print("GridSearchCV took %.2f seconds"
          " parameter settings." % ((time.time() - start)))
    print(i)
    print()
# Out:
# l_hand_acceleration_magnitude
# GridSearchCV took 1062.07 seconds parameter settings.
# 20
#
# r_hand_acceleration_magnitude
# GridSearchCV took 1801.74 seconds parameter settings.
# 21
#
# l_foot_acceleration_magnitude
# GridSearchCV took 2273.35 seconds parameter settings.
# 22
#
# r_foot_acceleration_magnitude
# GridSearchCV took 1843.36 seconds parameter settings.
# 23
#
# neck_acceleration_magnitude
# GridSearchCV took 1377.02 seconds parameter settings.
# 24

# %% [markdown]
# ### Results

# %%
best_regressors = []
for i in range(len(random_searches)):
    print(train_y_sets[i].columns[0])
    best_regressor = random_searches[i].best_estimator_

    print(best_regressor.get_params())
    best_regressors.append(best_regressor)
    print()
# Out:
# max_hand_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1, 'eta': 0.01, 'alpha': 0.25}
#
# avg_l_hand_hip_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.01, 'alpha': 0.1}
#
# avg_r_hand_hip_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.25}
#
# max_stride_length
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.75, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.05, 'alpha': 0.25}
#
# avg_l_hand_chest_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.1}
#
# avg_r_hand_chest_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.25}
#
# avg_l_elbow_hip_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.01, 'alpha': 0.25}
#
# avg_r_elbow_hip_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.01, 'alpha': 0.0}
#
# avg_chest_pelvis_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.150000006, 'max_delta_step': 0, 'max_depth': 3, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.15, 'alpha': 0.0}
#
# avg_neck_chest_distance
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.150000006, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.15, 'alpha': 0.0}
#
# avg_total_body_volume
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.01, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.05, 'alpha': 0.25}
#
# avg_lower_body_volume
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.0}
#
# avg_upper_body_volume
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 10, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1, 'eta': 0.01, 'alpha': 0.0}
#
# avg_triangle_area_hands_neck
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.01, 'alpha': 0.0}
#
# avg_triangle_area_feet_hips
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.75, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1, 'eta': 0.05, 'alpha': 0.1}
#
# l_hand_speed
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.05, 'alpha': 0.1}
#
# r_hand_speed
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.05, 'alpha': 0.25}
#
# l_foot_speed
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.25}
#
# r_foot_speed
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1, 'eta': 0.05, 'alpha': 0.25}
#
# neck_speed
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.100000001, 'max_delta_step': 0, 'max_depth': 15, 'min_child_weight': 1, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.1, 'alpha': 0.0}
#
# l_hand_acceleration_magnitude
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 10, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1, 'eta': 0.05, 'alpha': 0.25}
#
# r_hand_acceleration_magnitude
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 21, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.01, 'alpha': 0.25}
#
# l_foot_acceleration_magnitude
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 10, 'min_child_weight': 21, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.05, 'alpha': 0.1}
#
# r_foot_acceleration_magnitude
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0.001, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.0500000007, 'max_delta_step': 0, 'max_depth': 10, 'min_child_weight': 21, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.100000001, 'reg_lambda': 0.850000024, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 0.85, 'eta': 0.05, 'alpha': 0.1}
#
# neck_acceleration_magnitude
# {'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.75, 'enable_categorical': False, 'gamma': 0, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.00999999978, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 11, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1500, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.25, 'reg_lambda': 1.25, 'scale_pos_weight': 1, 'subsample': 0.75, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.25, 'eta': 0.01, 'alpha': 0.25}

# %%
for i in range(len(best_regressors)):
    pred_y = best_regressors[i].predict(test_emotions)
    mse = mean_squared_error(test_y_sets[i], pred_y)
    mae = mean_absolute_error(test_y_sets[i], pred_y)
    print(test_y_sets[i].columns[0])
    print("MSE: %.2f" % mse)
    print("MAE: %.2f" % mae)
    print("Example: ", test_y_sets[i].iloc[0][0])
    print()
# Out:
# max_hand_distance
# MSE: 0.03
# MAE: 0.14
# Example:  0.3395164437960131
#
# avg_l_hand_hip_distance
# MSE: 0.01
# MAE: 0.09
# Example:  0.1460816920579784
#
# avg_r_hand_hip_distance
# MSE: 0.01
# MAE: 0.09
# Example:  0.3123311051315577
#
# max_stride_length
# MSE: 0.02
# MAE: 0.13
# Example:  0.8030836218859783
#
# avg_l_hand_chest_distance
# MSE: 0.01
# MAE: 0.07
# Example:  0.1383561128526125
#
# avg_r_hand_chest_distance
# MSE: 0.01
# MAE: 0.07
# Example:  0.2989139337221463
#
# avg_l_elbow_hip_distance
# MSE: 0.01
# MAE: 0.08
# Example:  0.1966807706423693
#
# avg_r_elbow_hip_distance
# MSE: 0.01
# MAE: 0.07
# Example:  0.0866701273552188
#
# avg_chest_pelvis_distance
# MSE: 0.00
# MAE: 0.00
# Example:  0.2361509837184195
#
# avg_neck_chest_distance
# MSE: 0.00
# MAE: 0.00
# Example:  0.2238940679121701
#
# avg_total_body_volume
# MSE: 0.02
# MAE: 0.10
# Example:  0.3006713489203775
#
# avg_lower_body_volume
# MSE: 0.00
# MAE: 0.02
# Example:  0.073142898767215
#
# avg_upper_body_volume
# MSE: 0.00
# MAE: 0.02
# Example:  0.1795983565982234
#
# avg_triangle_area_hands_neck
# MSE: 0.00
# MAE: 0.03
# Example:  0.0524842573712577
#
# avg_triangle_area_feet_hips
# MSE: 0.00
# MAE: 0.05
# Example:  0.2230379041237674
#
# l_hand_speed
# MSE: 0.00
# MAE: 0.04
# Example:  -0.128934897241862
#
# r_hand_speed
# MSE: 0.00
# MAE: 0.04
# Example:  -0.2389464932440452
#
# l_foot_speed
# MSE: 0.00
# MAE: 0.05
# Example:  -0.2074642870851447
#
# r_foot_speed
# MSE: 0.00
# MAE: 0.04
# Example:  -0.1496209261758277
#
# neck_speed
# MSE: 0.00
# MAE: 0.03
# Example:  -0.1743706766856205
#
# l_hand_acceleration_magnitude
# MSE: 0.00
# MAE: 0.01
# Example:  0.0280104091683733
#
# r_hand_acceleration_magnitude
# MSE: 0.00
# MAE: 0.01
# Example:  0.0281633970784426
#
# l_foot_acceleration_magnitude
# MSE: 0.00
# MAE: 0.01
# Example:  0.0189219044659881
#
# r_foot_acceleration_magnitude
# MSE: 0.00
# MAE: 0.01
# Example:  0.0577477996176199
#
# neck_acceleration_magnitude
# MSE: 0.00
# MAE: 0.01
# Example:  0.0229078523779035

# %%
generated_features = []

for i in range(len(best_regressors)):
    pred_y = best_regressors[i].predict(test_emotions)
    generated_features.append(pred_y)
    
    
rows = []
for i in range(len(generated_features[0])):
    row = []
    for j in range(len(best_regressors)):
        row.append(generated_features[j][i])
    rows.append(row)
    
print(len(rows))
        
generated = pd.DataFrame(rows, columns=["max_hand_distance",
          "avg_l_hand_hip_distance",
          "avg_r_hand_hip_distance",
          "max_stride_length",
          "avg_l_hand_chest_distance",
          "avg_r_hand_chest_distance",
          "avg_l_elbow_hip_distance",
          "avg_r_elbow_hip_distance",
          "avg_chest_pelvis_distance",
          "avg_neck_chest_distance",
          
          "avg_total_body_volume",
          "avg_lower_body_volume",
          "avg_upper_body_volume",
          
          "avg_triangle_area_hands_neck",
          "avg_triangle_area_feet_hips",
          
          "l_hand_speed",
          "r_hand_speed",
          "l_foot_speed",
          "r_foot_speed",
          "neck_speed",
          
          "l_hand_acceleration_magnitude",
          "r_hand_acceleration_magnitude",
          "l_foot_acceleration_magnitude",
          "r_foot_acceleration_magnitude",
          "neck_acceleration_magnitude",
    ])

generated.head()
# Out:
# 11783
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.578577                 0.358444                 0.315181
# 1           0.496892                 0.321827                 0.284121
# 2           0.572839                 0.329404                 0.343924
# 3           0.452568                 0.266322                 0.275323
# 4           0.629005                 0.400293                 0.338895
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.570301                   0.326959                   0.321908
# 1           0.368784                   0.333197                   0.318864
# 2           0.437277                   0.338510                   0.350466
# 3           0.336494                   0.337077                   0.339549
# 4           0.519348                   0.360873                   0.338076
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.269332                  0.273666
# 1                  0.246853                  0.226619
# 2                  0.242346                  0.240951
# 3                  0.216333                  0.207190
# 4                  0.252865                  0.241222
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                   0.236151                 0.223894  ...     -0.161990
# 1                   0.236151                 0.223894  ...     -0.083568
# 2                   0.236151                 0.223894  ...     -0.081745
# 3                   0.236151                 0.223894  ...     -0.049883
# 4                   0.236151                 0.223894  ...     -0.141254
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0     -0.171768     -0.166984     -0.140310   -0.169120
# 1     -0.088609     -0.086647     -0.079619   -0.081231
# 2     -0.072975     -0.074694     -0.080889   -0.080502
# 3     -0.048127     -0.051660     -0.046582   -0.046869
# 4     -0.130724     -0.132408     -0.132202   -0.148772
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       0.039009                       0.040110
# 1                       0.016622                       0.014403
# 2                       0.016718                       0.015721
# 3                       0.007783                       0.006947
# 4                       0.037114                       0.038120
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.032660                       0.036784
# 1                       0.017334                       0.017245
# 2                       0.019167                       0.019130
# 3                       0.009587                       0.009138
# 4                       0.031605                       0.037570
#
#    neck_acceleration_magnitude
# 0                     0.026315
# 1                     0.010942
# 2                     0.013167
# 3                     0.004998
# 4                     0.020852
#
# [5 rows x 25 columns]

# %%
generated_scaled = scaler.transform(generated)

gen_emotions_p = model_p.predict(generated_scaled)
gen_emotions_a = model_a.predict(generated_scaled)
gen_emotions_d = model_d.predict(generated_scaled)

rows = []
for i in range(len(generated_scaled)):
    rows.append([gen_emotions_p[i], gen_emotions_a[i], gen_emotions_d[i]])

gen_emotions = pd.DataFrame(rows, columns=[
            "EMOTION_P", "EMOTION_A", "EMOTION_D"
         ])

gen_emotions.head()
# Out:
#    EMOTION_P  EMOTION_A  EMOTION_D
# 0   0.055875  -0.179928   0.131175
# 1   0.109576  -0.568476  -0.178256
# 2   0.098387  -0.425646  -0.103049
# 3  -0.015099  -0.533289  -0.192106
# 4   0.189480  -0.019819   0.078834

# %%
import random

mae_errors = mean_absolute_error(test_emotions, gen_emotions, multioutput='raw_values')
mse_errors = mean_squared_error(test_emotions, gen_emotions, multioutput='raw_values')

features = ["PLEASURE", "AROUSAL", "DOMINANCE"
         ]

print("Overall MAE: " + str(mean_absolute_error(test_emotions, gen_emotions)))

print()
for i in range(len(mse_errors)):
    print("==" + features[i] + "==")
    print("MSE: %.5f" % mse_errors[i])
    print("MAE: %.5f" % mae_errors[i])
    print()
    
for i in range(30):
    row = random.randint(0, len(test_emotions))

    print("Real: " + str([test_emotions_OG.iloc[row,0], test_emotions_OG.iloc[row,1], test_emotions_OG.iloc[row,2]]))
    print("Predicted: " + str([test_emotions.iloc[row,0], test_emotions.iloc[row,1], test_emotions.iloc[row,2]]))
    print("Generated: " + str([gen_emotions.iloc[row,0], gen_emotions.iloc[row,1], gen_emotions.iloc[row,2]]))
    print()
# Out:
# Overall MAE: 0.23917437127804594
#
# ==PLEASURE==
# MSE: 0.03727
# MAE: 0.14666
#
# ==AROUSAL==
# MSE: 0.19555
# MAE: 0.33816
#
# ==DOMINANCE==
# MSE: 0.10395
# MAE: 0.23270
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.12424357980489731, -0.07422919571399689, 0.0940399318933487]
# Generated: [0.17585872, -0.066053234, 0.03748347]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.04575508460402489, -0.36959075927734375, 0.0583079569041729]
# Generated: [0.1787874, -0.26896548, -0.16222437]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.102762870490551, -0.5240640640258789, -0.13709397614002228]
# Generated: [0.16377203, -0.3565656, -0.082784295]
#
# Real: [0.6, 0.4, 0.1]
# Predicted: [0.614004373550415, 0.43613719940185547, 0.08583536744117737]
# Generated: [0.45218647, -0.006354671, -0.05885044]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.07651668787002563, -0.44719091057777405, -0.05797743424773216]
# Generated: [0.08739927, -0.5726265, -0.18666345]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.11406940966844559, -0.5616194605827332, -0.1882019191980362]
# Generated: [0.015814226, -0.48833063, -0.09548528]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.14229321479797363, -0.4396514594554901, -0.11121508479118347]
# Generated: [0.10057012, -0.41634205, -0.17481902]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.0620020255446434, -0.4995725154876709, -0.1317598819732666]
# Generated: [0.07840058, -0.47805187, -0.16099225]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.07321658730506897, -0.2806989252567291, -8.294930921692867e-06]
# Generated: [0.14020005, -0.026029054, 0.10262811]
#
# Real: [0.6, 0.4, 0.1]
# Predicted: [0.6057837605476379, 0.41571709513664246, 0.0989529937505722]
# Generated: [0.28672847, -0.19745354, -0.03063844]
#
# Real: [0.3, 0.4, 0.6]
# Predicted: [0.3336304724216461, 0.37830665707588196, 0.4593943953514099]
# Generated: [0.24336946, 0.038819335, -0.033831254]
#
# Real: [0.2, -0.75, -0.3]
# Predicted: [0.2083721160888672, -0.7676032781600952, -0.32760271430015564]
# Generated: [0.09577598, -0.5836281, -0.18284345]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.11329571157693863, -0.5456847548484802, -0.15017010271549225]
# Generated: [-0.12743951, -0.5408509, -0.24782594]
#
# Real: [0.6, 0.4, 0.1]
# Predicted: [0.609931230545044, 0.39922896027565, 0.08344270288944244]
# Generated: [0.31023479, 0.18163878, -0.056290116]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.04844093322753906, -0.3782025873661041, 0.013842356391251087]
# Generated: [0.2857239, -0.26354942, -0.12823375]
#
# Real: [0.1, 0.6, 0.4]
# Predicted: [0.10018902271986008, 0.4564180076122284, 0.2952340543270111]
# Generated: [0.17165843, -0.24410626, -0.03869289]
#
# Real: [0.1, 0.6, 0.4]
# Predicted: [0.08140271157026291, 0.509131669998169, 0.3259592056274414]
# Generated: [0.09949998, -0.19858477, -0.056258608]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.06306403875350952, -0.4946836233139038, -0.10392818599939346]
# Generated: [0.085627615, -0.52993125, -0.16816005]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.059104353189468384, -0.41035187244415283, -0.009631042368710041]
# Generated: [0.10832092, -0.5088946, -0.1863918]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.2274315506219864, -0.32512223720550537, 0.023986248299479485]
# Generated: [0.19230999, -0.38745752, -0.16821408]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.07361430674791336, -0.37284353375434875, -0.06338229775428772]
# Generated: [0.120125964, -0.32207066, -0.19457574]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.0766611248254776, -0.25931867957115173, -0.06082560494542122]
# Generated: [0.029639818, -0.4798812, -0.13245282]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.06325815618038177, -0.3922121822834015, -0.013957747258245945]
# Generated: [0.17948133, -0.5952927, -0.22574775]
#
# Real: [0.05, -0.4, 0.0]
# Predicted: [0.045464109629392624, -0.3534122109413147, 0.02099025622010231]
# Generated: [0.2516292, -0.20030951, -0.07312471]
#
# Real: [0.3, 0.4, 0.6]
# Predicted: [0.3028688430786133, 0.4025457799434662, 0.6093378663063049]
# Generated: [0.20108223, -0.59838283, -0.1522894]
#
# Real: [-0.1, -0.55, -0.15]
# Predicted: [-0.10930246114730835, -0.5602139830589294, -0.15210884809494019]
# Generated: [0.10255335, -0.5104031, -0.16545227]
#
# Real: [0.1, 0.6, 0.4]
# Predicted: [0.03144197538495064, 0.36362606287002563, 0.28993308544158936]
# Generated: [0.12585714, -0.187439, 0.0694065]
#
# Real: [0.2, -0.75, -0.3]
# Predicted: [0.19994033873081207, -0.7041571736335754, -0.2342141717672348]
# Generated: [0.16209032, -0.6452974, -0.20851624]
#
# Real: [0.3, 0.4, 0.6]
# Predicted: [0.29820194840431213, 0.40033039450645447, 0.5971366763114929]
# Generated: [-0.06631459, -0.66139615, -0.2532303]
#
# Real: [0.1, 0.6, 0.4]
# Predicted: [0.0766531452536583, 0.38146016001701355, 0.19480866193771362]
# Generated: [0.13715921, -0.03918639, 0.09270828]

# %%
# save to JSON
for i in range(len(best_regressors)):
    best_regressors[i].save_model("models/bandai/xgb/" + test_y_sets[i].columns[0] +".json")

# %% [markdown]
# ### Predictions

# %%
model_p = xgb.XGBRegressor(verbosity=0)
model_p.load_model("../../emotion_classifier/model_training/models/bandai_l2p_model.json")

model_a = xgb.XGBRegressor(verbosity=0)
model_a.load_model("../../emotion_classifier/model_training/models/bandai_l2a_model.json")

model_d = xgb.XGBRegressor(verbosity=0)
model_d.load_model("../../emotion_classifier/model_training/models/bandai_l2d_model.json")

scaler = joblib.load('../../emotion_classifier/model_training/datasets/scalers/standardizers/S_BANDAI_5frame.pkl')

# %%
index = 10

real_coordinates = np.asarray([test_X.iloc[index]])

generated_features = []
for i in range(len(models)):
    generated_features.append(best_regressors[i].predict(real_coordinates)[0])
    #print(test_y_sets[i].columns[0], " - ", generated_features[i])
    
generated_features = pd.DataFrame([generated_features], columns=["max_hand_distance",
          "avg_l_hand_hip_distance",
          "avg_r_hand_hip_distance",
          "max_stride_length",
          "avg_l_hand_chest_distance",
          "avg_r_hand_chest_distance",
          "avg_l_elbow_hip_distance",
          "avg_r_elbow_hip_distance",
          "avg_chest_pelvis_distance",
          "avg_neck_chest_distance",
          
          "avg_total_body_volume",
          "avg_lower_body_volume",
          "avg_upper_body_volume",
          
          "avg_triangle_area_hands_neck",
          "avg_triangle_area_feet_hips",
          
          "l_hand_speed",
          "r_hand_speed",
          "l_foot_speed",
          "r_foot_speed",
          "neck_speed",
          
          "l_hand_acceleration_magnitude",
          "r_hand_acceleration_magnitude",
          "l_foot_acceleration_magnitude",
          "r_foot_acceleration_magnitude",
          "neck_acceleration_magnitude",
    ])

generated_features = scaler.transform(generated_features)

y_p = model_p.predict(generated_features)
y_a = model_a.predict(generated_features)
y_d = model_d.predict(generated_features)

print('Real: %s' % np.asarray(real_coordinates))
print('Predicted: %s' % [y_p[0], y_a[0], y_d[0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-193a8445b6b0> in <module>
#       1 index = 10
#       2
# ----> 3 real_coordinates = np.asarray([test_X.iloc[index]])
#       4
#       5 generated_features = []
#
# NameError: name 'test_X' is not defined
