# %% [markdown]
# # Data Preparation - LMA Features Data

# %% [markdown]
# ### Note: Datasets follow the format preprocess_datasetname
# So we have, for example: Fs_B_dataset1.csv -> Dataset was first Feature Selected and then Balanced
#
# Fs - Feature Selected
#
# B - Balanced
#
# N - Normalized
#
# S - Standardized

# %% [markdown]
# ## Imports

# %%
import ast
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTENC, SMOTE
from imblearn.under_sampling import NearMiss
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import joblib
from collections import Counter
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv('datasets/BANDAI_KIN_05sec.csv')

# %%
data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.158604                 0.262368
# 1           0.502380                 0.348371                 0.141433
# 2           0.523859                 0.430275                 0.176769
# 3           0.506404                 0.372590                 0.182689
# 4           0.399879                 0.189986                 0.280258
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.204290                   0.286321
# 1           0.355769                   0.308451                   0.226158
# 2           0.588712                   0.337860                   0.209359
# 3           0.671607                   0.304908                   0.199841
# 4           0.595205                   0.236768                   0.250473
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.174445                  0.107800
# 1                  0.114087                  0.185519
# 2                  0.111133                  0.249847
# 3                  0.092428                  0.244035
# 4                  0.108253                  0.145548
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.236151                 0.223894  ...      0.544719
# 1                   0.236151                 0.223894  ...      0.375438
# 2                   0.236151                 0.223894  ...      0.343913
# 3                   0.236151                 0.223894  ...      1.118295
# 4                   0.236151                 0.223894  ...      1.306542
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0    0.747464                       0.783573                       2.388999
# 1    0.813410                       1.279194                       1.685722
# 2    0.897555                       0.762036                       0.337886
# 3    0.912977                       1.376315                       0.773128
# 4    0.828419                       0.436481                       0.562979
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       2.320488                       1.089438
# 1                       0.708942                       0.661071
# 2                       0.417700                       0.325002
# 3                       0.324001                       1.594570
# 4                       1.256880                       0.433401
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     1.494928       0.05       -0.1        0.0
# 1                     0.783065       0.05       -0.1        0.0
# 2                     0.209341       0.05       -0.1        0.0
# 3                     0.748233       0.05       -0.1        0.0
# 4                     0.184292       0.05       -0.1        0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Feature Selection

# %%
data = pd.read_csv('datasets/BANDAI_KIN_05sec.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.158604                 0.262368
# 1           0.502380                 0.348371                 0.141433
# 2           0.523859                 0.430275                 0.176769
# 3           0.506404                 0.372590                 0.182689
# 4           0.399879                 0.189986                 0.280258
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.204290                   0.286321
# 1           0.355769                   0.308451                   0.226158
# 2           0.588712                   0.337860                   0.209359
# 3           0.671607                   0.304908                   0.199841
# 4           0.595205                   0.236768                   0.250473
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.174445                  0.107800
# 1                  0.114087                  0.185519
# 2                  0.111133                  0.249847
# 3                  0.092428                  0.244035
# 4                  0.108253                  0.145548
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                   0.236151                 0.223894  ...      0.391787
# 1                   0.236151                 0.223894  ...      0.807009
# 2                   0.236151                 0.223894  ...      0.989961
# 3                   0.236151                 0.223894  ...      1.082582
# 4                   0.236151                 0.223894  ...      1.172738
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0      1.194499      1.160244      0.544719    0.747464
# 1      1.046016      1.007270      0.375438    0.813410
# 2      0.908436      1.027262      0.343913    0.897555
# 3      0.689009      1.158406      1.118295    0.912977
# 4      0.480506      0.535663      1.306542    0.828419
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       0.783573                       2.388999
# 1                       1.279194                       1.685722
# 2                       0.762036                       0.337886
# 3                       1.376315                       0.773128
# 4                       0.436481                       0.562979
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       2.320488                       1.089438
# 1                       0.708942                       0.661071
# 2                       0.417700                       0.325002
# 3                       0.324001                       1.594570
# 4                       1.256880                       0.433401
#
#    neck_acceleration_magnitude
# 0                     1.494928
# 1                     0.783065
# 2                     0.209341
# 3                     0.748233
# 4                     0.184292
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Variance Analysis

# %%
x_fs = []
y_fs = []
for i in data.columns:
    x_fs.append(data[i].var())
    y_fs.append(i)


fig, ax = plt.subplots(figsize=(15,10))

ax.bar(y_fs, x_fs)

plt.show()

for i in data.columns:
    print(i, " - ", data[i].var())
# Out:
# max_hand_distance  -  0.04228168764373475
# avg_l_hand_hip_distance  -  0.02423701436728336
# avg_r_hand_hip_distance  -  0.025552573700501464
# max_stride_length  -  0.02901407754552197
# avg_l_hand_chest_distance  -  0.009934495740628956
# avg_r_hand_chest_distance  -  0.010219135714330365
# avg_l_elbow_hip_distance  -  0.008450460050310922
# avg_r_elbow_hip_distance  -  0.008523900105683132
# avg_chest_pelvis_distance  -  5.585569485299485e-16
# avg_neck_chest_distance  -  7.382038792866843e-16
# avg_total_body_volume  -  0.023139229158241254
# avg_lower_body_volume  -  0.0020468231564047317
# avg_upper_body_volume  -  0.0012069677612653884
# avg_triangle_area_hands_neck  -  0.0019123383365826842
# avg_triangle_area_feet_hips  -  0.003043319284806088
# l_hand_speed  -  0.21410585892887146
# r_hand_speed  -  0.21495712673925604
# l_foot_speed  -  0.21753766813606407
# r_foot_speed  -  0.21591498505725448
# neck_speed  -  0.17451516046040194
# l_hand_acceleration_magnitude  -  0.2313326994956406
# r_hand_acceleration_magnitude  -  0.23293158569525368
# l_foot_acceleration_magnitude  -  0.17614447375342723
# r_foot_acceleration_magnitude  -  0.17032341042501836
# neck_acceleration_magnitude  -  0.09959061004237349

# %% [markdown]
# ### Remove highly correlated features

# %%
data = pd.read_csv('datasets/BANDAI_KIN_05sec.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.158604                 0.262368
# 1           0.502380                 0.348371                 0.141433
# 2           0.523859                 0.430275                 0.176769
# 3           0.506404                 0.372590                 0.182689
# 4           0.399879                 0.189986                 0.280258
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.204290                   0.286321
# 1           0.355769                   0.308451                   0.226158
# 2           0.588712                   0.337860                   0.209359
# 3           0.671607                   0.304908                   0.199841
# 4           0.595205                   0.236768                   0.250473
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.174445                  0.107800
# 1                  0.114087                  0.185519
# 2                  0.111133                  0.249847
# 3                  0.092428                  0.244035
# 4                  0.108253                  0.145548
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                   0.236151                 0.223894  ...      0.391787
# 1                   0.236151                 0.223894  ...      0.807009
# 2                   0.236151                 0.223894  ...      0.989961
# 3                   0.236151                 0.223894  ...      1.082582
# 4                   0.236151                 0.223894  ...      1.172738
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0      1.194499      1.160244      0.544719    0.747464
# 1      1.046016      1.007270      0.375438    0.813410
# 2      0.908436      1.027262      0.343913    0.897555
# 3      0.689009      1.158406      1.118295    0.912977
# 4      0.480506      0.535663      1.306542    0.828419
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       0.783573                       2.388999
# 1                       1.279194                       1.685722
# 2                       0.762036                       0.337886
# 3                       1.376315                       0.773128
# 4                       0.436481                       0.562979
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       2.320488                       1.089438
# 1                       0.708942                       0.661071
# 2                       0.417700                       0.325002
# 3                       0.324001                       1.594570
# 4                       1.256880                       0.433401
#
#    neck_acceleration_magnitude
# 0                     1.494928
# 1                     0.783065
# 2                     0.209341
# 3                     0.748233
# 4                     0.184292
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(figsize=[32,32])
corr_mtx = data.corr()
sns.heatmap(corr_mtx, xticklabels=corr_mtx.columns, yticklabels=corr_mtx.columns, annot=True, cmap='Blues')
plt.title('Correlation analysis')
plt.show()

# %%
cor_matrix = data.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(to_drop)
# Out:
# ['neck_speed']

# %%
df = pd.read_csv('datasets/BANDAI_KIN_05sec.csv')

cor = df.corr()

#Correlation with output variable
cor_target = abs(cor["EMOTION_P"])
print("===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_A"])
print("\n===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_D"])
print("\n===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===")
print(cor_target)
# Out:
# ===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===
# max_hand_distance                0.202808
# avg_l_hand_hip_distance          0.027953
# avg_r_hand_hip_distance          0.088358
# max_stride_length                0.290533
# avg_l_hand_chest_distance        0.019536
# avg_r_hand_chest_distance        0.057522
# avg_l_elbow_hip_distance         0.110227
# avg_r_elbow_hip_distance         0.148545
# avg_chest_pelvis_distance        0.022516
# avg_neck_chest_distance          0.015557
# avg_total_body_volume            0.172614
# avg_lower_body_volume            0.077250
# avg_upper_body_volume            0.155252
# avg_triangle_area_hands_neck     0.126404
# avg_triangle_area_feet_hips      0.092934
# l_hand_speed                     0.417412
# r_hand_speed                     0.414344
# l_foot_speed                     0.394640
# r_foot_speed                     0.395537
# neck_speed                       0.429860
# l_hand_acceleration_magnitude    0.396284
# r_hand_acceleration_magnitude    0.382676
# l_foot_acceleration_magnitude    0.372178
# r_foot_acceleration_magnitude    0.374646
# neck_acceleration_magnitude      0.360310
# EMOTION_P                        1.000000
# EMOTION_A                        0.075613
# EMOTION_D                        0.306596
# Name: EMOTION_P, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===
# max_hand_distance                0.134012
# avg_l_hand_hip_distance          0.129996
# avg_r_hand_hip_distance          0.150742
# max_stride_length                0.132824
# avg_l_hand_chest_distance        0.107915
# avg_r_hand_chest_distance        0.138660
# avg_l_elbow_hip_distance         0.156419
# avg_r_elbow_hip_distance         0.190829
# avg_chest_pelvis_distance        0.007388
# avg_neck_chest_distance          0.013931
# avg_total_body_volume            0.137617
# avg_lower_body_volume            0.182180
# avg_upper_body_volume            0.114928
# avg_triangle_area_hands_neck     0.036023
# avg_triangle_area_feet_hips      0.185753
# l_hand_speed                     0.107328
# r_hand_speed                     0.106332
# l_foot_speed                     0.109213
# r_foot_speed                     0.109672
# neck_speed                       0.119144
# l_hand_acceleration_magnitude    0.011168
# r_hand_acceleration_magnitude    0.013148
# l_foot_acceleration_magnitude    0.103169
# r_foot_acceleration_magnitude    0.098820
# neck_acceleration_magnitude      0.062703
# EMOTION_P                        0.075613
# EMOTION_A                        1.000000
# EMOTION_D                        0.399571
# Name: EMOTION_A, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===
# max_hand_distance                0.185322
# avg_l_hand_hip_distance          0.059034
# avg_r_hand_hip_distance          0.039019
# max_stride_length                0.219294
# avg_l_hand_chest_distance        0.003093
# avg_r_hand_chest_distance        0.028914
# avg_l_elbow_hip_distance         0.018865
# avg_r_elbow_hip_distance         0.012221
# avg_chest_pelvis_distance        0.021897
# avg_neck_chest_distance          0.013491
# avg_total_body_volume            0.140745
# avg_lower_body_volume            0.059098
# avg_upper_body_volume            0.099910
# avg_triangle_area_hands_neck     0.119618
# avg_triangle_area_feet_hips      0.149644
# l_hand_speed                     0.184508
# r_hand_speed                     0.182597
# l_foot_speed                     0.173853
# r_foot_speed                     0.174727
# neck_speed                       0.190590
# l_hand_acceleration_magnitude    0.185137
# r_hand_acceleration_magnitude    0.196318
# l_foot_acceleration_magnitude    0.155246
# r_foot_acceleration_magnitude    0.157526
# neck_acceleration_magnitude      0.165715
# EMOTION_P                        0.306596
# EMOTION_A                        0.399571
# EMOTION_D                        1.000000
# Name: EMOTION_D, dtype: float64

# %% [markdown]
# ## Outliers

# %%
from scipy import stats

# %%
data = pd.read_csv('datasets/BANDAI_KIN_05sec.csv')
print(data.shape)
# Out:
# (49773, 28)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.433596
# avg_l_hand_hip_distance          0.158604
# avg_r_hand_hip_distance          0.262368
# max_stride_length                0.538619
# avg_l_hand_chest_distance        0.204290
# avg_r_hand_chest_distance        0.286321
# avg_l_elbow_hip_distance         0.174445
# avg_r_elbow_hip_distance         0.107800
# avg_chest_pelvis_distance        0.236151
# avg_neck_chest_distance          0.223894
# avg_total_body_volume            0.214717
# avg_lower_body_volume            0.062277
# avg_upper_body_volume            0.093622
# avg_triangle_area_hands_neck     0.065018
# avg_triangle_area_feet_hips      0.144140
# l_hand_speed                     0.391787
# r_hand_speed                     1.194499
# l_foot_speed                     1.160244
# r_foot_speed                     0.544719
# neck_speed                       0.747464
# l_hand_acceleration_magnitude    0.783573
# r_hand_acceleration_magnitude    2.388999
# l_foot_acceleration_magnitude    2.320488
# r_foot_acceleration_magnitude    1.089438
# neck_acceleration_magnitude      1.494928
# EMOTION_P                        0.050000
# EMOTION_A                       -0.100000
# EMOTION_D                        0.000000
# Name: 0, dtype: float64

# %%
data = data[(np.abs(stats.zscore(data)) < 3).all(axis=1)]
data.shape
# Out:
# (43461, 28)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.502380
# avg_l_hand_hip_distance          0.348371
# avg_r_hand_hip_distance          0.141433
# max_stride_length                0.355769
# avg_l_hand_chest_distance        0.308451
# avg_r_hand_chest_distance        0.226158
# avg_l_elbow_hip_distance         0.114087
# avg_r_elbow_hip_distance         0.185519
# avg_chest_pelvis_distance        0.236151
# avg_neck_chest_distance          0.223894
# avg_total_body_volume            0.232280
# avg_lower_body_volume            0.069039
# avg_upper_body_volume            0.067281
# avg_triangle_area_hands_neck     0.077002
# avg_triangle_area_feet_hips      0.086540
# l_hand_speed                     0.807009
# r_hand_speed                     1.046016
# l_foot_speed                     1.007270
# r_foot_speed                     0.375438
# neck_speed                       0.813410
# l_hand_acceleration_magnitude    1.279194
# r_hand_acceleration_magnitude    1.685722
# l_foot_acceleration_magnitude    0.708942
# r_foot_acceleration_magnitude    0.661071
# neck_acceleration_magnitude      0.783065
# EMOTION_P                        0.050000
# EMOTION_A                       -0.100000
# EMOTION_D                        0.000000
# Name: 1, dtype: float64

# %%
data.to_csv(r'datasets/O_BANDAI_KIN_05sec.csv', index = False)

# %% [markdown]
# ## Data Standardization

# %%
data = pd.read_csv('datasets/O_BANDAI_KIN_05sec.csv')

# %%
target = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)

numeric_vars = data.columns

rows = 14
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(data[numeric_vars[n]].values)))
    axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
    axs[i, j].boxplot(data[numeric_vars[n]].dropna().values)
    
    i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
    
plt.show()

# %%
numeric_data = data

transf = StandardScaler(copy=True).fit(numeric_data)
minMaxData = pd.DataFrame(transf.transform(numeric_data), columns = numeric_data.columns)
minMaxData.describe(include='all')
# Out:
#        max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# count       4.346100e+04             4.346100e+04             4.346100e+04
# mean       -1.007097e-16             1.033255e-16            -3.086686e-16
# std         1.000012e+00             1.000012e+00             1.000012e+00
# min        -2.678637e+00            -2.104005e+00            -2.195301e+00
# 25%        -6.401397e-01            -7.020282e-01            -6.984676e-01
# 50%        -7.384172e-02            -1.488128e-01            -2.109748e-01
# 75%         6.351888e-01             5.500778e-01             5.629578e-01
# max         3.264524e+00             3.313895e+00             3.421305e+00
#
#        max_stride_length  avg_l_hand_chest_distance  \
# count       4.346100e+04               4.346100e+04
# mean        3.871437e-16              -2.798944e-16
# std         1.000012e+00               1.000012e+00
# min        -2.244793e+00              -3.271155e+00
# 25%        -7.691254e-01              -6.113520e-01
# 50%        -1.088551e-01               8.979484e-02
# 75%         6.711649e-01               5.938017e-01
# max         3.359056e+00               3.373165e+00
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# count               4.346100e+04              4.346100e+04
# mean                2.105748e-16             -1.726452e-16
# std                 1.000012e+00              1.000012e+00
# min                -3.374038e+00             -2.475362e+00
# 25%                -6.319754e-01             -5.912623e-01
# 50%                 7.790081e-02             -1.286107e-02
# 75%                 5.811885e-01              5.837659e-01
# max                 3.519693e+00              3.256088e+00
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# count              4.346100e+04               4.346100e+04
# mean               1.517185e-16              -1.043087e-09
# std                1.000012e+00               1.000012e+00
# min               -2.576649e+00              -3.961043e+00
# 25%               -5.474041e-01              -6.082103e-01
# 50%               -1.523937e-02              -4.502112e-03
# 75%                5.565043e-01               6.042101e-01
# max                3.345306e+00               3.960451e+00
#
#        avg_neck_chest_distance  ...  l_hand_speed  r_hand_speed  l_foot_speed  \
# count             4.346100e+04  ...  4.346100e+04  4.346100e+04  4.346100e+04
# mean              4.250399e-10  ...  7.847507e-17  8.370674e-17 -2.197302e-16
# std               1.000012e+00  ...  1.000012e+00  1.000012e+00  1.000012e+00
# min              -3.903602e+00  ... -1.763512e+00 -2.051363e+00 -1.879757e+00
# 25%              -6.203528e-01  ... -7.604018e-01 -7.580411e-01 -7.271645e-01
# 50%               2.868448e-03  ... -7.138777e-01 -7.090185e-01 -7.063938e-01
# 75%               6.233143e-01  ...  6.906708e-01  6.812856e-01  6.503702e-01
# max               3.913365e+00  ...  3.461738e+00  3.458987e+00  3.463399e+00
#
#        r_foot_speed    neck_speed  l_hand_acceleration_magnitude  \
# count  4.346100e+04  4.346100e+04                   4.346100e+04
# mean  -7.324340e-17 -1.464868e-16                  -1.098651e-16
# std    1.000012e+00  1.000012e+00                   1.000012e+00
# min   -1.674414e+00 -1.972150e+00                  -7.391509e-01
# 25%   -7.283621e-01 -7.959334e-01                  -7.228785e-01
# 50%   -7.070439e-01 -7.700135e-01                  -5.920789e-01
# 75%    6.399473e-01  6.554160e-01                   5.108500e-01
# max    3.452777e+00  3.468188e+00                   3.855345e+00
#
#        r_hand_acceleration_magnitude  l_foot_acceleration_magnitude  \
# count                   4.346100e+04                   4.346100e+04
# mean                   -1.831085e-16                  -6.278006e-17
# std                     1.000012e+00                   1.000012e+00
# min                    -7.254037e-01                  -7.506206e-01
# 25%                    -7.083074e-01                  -7.418248e-01
# 50%                    -5.707178e-01                  -6.405319e-01
# 75%                     4.546511e-01                   5.014485e-01
# max                     3.905952e+00                   3.837051e+00
#
#        r_foot_acceleration_magnitude  neck_acceleration_magnitude
# count                   4.346100e+04                 4.346100e+04
# mean                   -6.278006e-17                -2.092669e-17
# std                     1.000012e+00                 1.000012e+00
# min                    -7.540958e-01                -7.279247e-01
# 25%                    -7.449704e-01                -7.159369e-01
# 50%                    -6.412269e-01                -5.886862e-01
# 75%                     5.151323e-01                 4.007196e-01
# max                     3.842695e+00                 4.185219e+00
#
# [8 rows x 25 columns]

# %%
numeric_vars = minMaxData.select_dtypes(include='number').columns
rows = 14
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(minMaxData[numeric_vars[n]].values)))
    #only boxplot non boolean vars
    if num_unique == 2:
        off+=1
    else:
        axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
        axs[i, j].boxplot(minMaxData[numeric_vars[n]].dropna().values)
        i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
plt.show()

minMaxData.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0          -0.162407                 0.126425                -1.331566
# 1          -0.051420                 0.694600                -1.085397
# 2          -0.692047                -0.972307                -0.364418
# 3          -0.274098                -1.405117                 0.794154
# 4          -0.270309                -1.195250                 0.819163
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0          -0.363196                  -0.494342                  -1.480733
# 1           1.120545                  -0.167215                  -1.672006
# 2           1.161898                  -1.291696                  -1.203875
# 3          -0.168092                  -2.085236                  -0.105307
# 4           1.429769                  -2.264918                  -0.014886
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                 -1.512957                 -0.758222
# 1                 -1.547322                  0.002579
# 2                 -1.580821                 -1.230956
# 3                 -0.727745                 -1.596562
# 4                 -0.259021                 -1.640791
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                  -1.628438                -1.054830  ...      1.248713
# 1                  -3.880335                 0.626800  ...      1.693640
# 2                   1.534487                -0.943333  ...      2.138140
# 3                   0.349986                -0.664813  ...      2.090674
# 4                  -0.506983                 1.678003  ...      1.667347
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0      1.836019      1.725601      0.201536    1.433501
# 1      1.501275      1.773872      0.125244    1.661448
# 2      0.460090      0.586935      2.454854    1.474161
# 3      1.903930      0.861384      2.486125    2.005182
# 4      1.711827      0.752739      2.331587    1.903107
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       2.553604                       3.650696
# 1                       1.222394                       0.151740
# 2                       0.384388                       0.736078
# 3                       3.426434                       2.460612
# 4                       0.635876                       1.558568
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       1.339624                       1.229858
# 1                       0.480925                       0.221275
# 2                       2.955166                       0.546594
# 3                       0.712058                       1.712614
# 4                       1.370133                       1.081653
#
#    neck_acceleration_magnitude
# 0                     2.612980
# 1                     0.165217
# 2                     0.058346
# 3                     3.531674
# 4                     0.675939
#
# [5 rows x 25 columns]

# %%
#Store MinMaxScaler

minMaxDataFull = minMaxData.join(target, how='right')
minMaxDataFull.to_csv(r'datasets/O_S_BANDAI_KIN_05sec.csv', index = False)

joblib.dump(transf, r'datasets/scalers/standardizers/O_S_BANDAI_KIN_05sec.pkl')
# Out:
# ['datasets/scalers/standardizers/O_S_BANDAI_KIN_05sec.pkl']

# %%
data = pd.read_csv('datasets/S_BANDAI_KIN5_5frame.csv')
scaler = joblib.load(r'datasets/scalers/standardizers/S_BANDAI_KIN5_5frame.pkl') 

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0          -0.458737                -1.343273                -0.059943
# 1          -0.872350                -1.246726                -0.548691
# 2          -1.006560                -0.857169                -1.024203
# 3          -0.619298                -0.340954                -1.292827
# 4          -0.302438                 0.097731                -1.297817
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.841679                  -1.721072                  -0.514527
# 1           0.331933                  -1.586667                  -0.769136
# 2          -0.129935                  -1.223236                  -1.008348
# 3          -0.499921                  -0.776566                  -1.209640
# 4          -0.560427                  -0.437376                  -1.357417
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                 -0.410040                 -1.743626
# 1                 -0.824661                 -1.625348
# 2                 -1.251456                 -1.382473
# 3                 -1.472165                 -1.064463
# 4                 -1.468726                 -0.742653
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.159003                -1.350800  ...     -1.309516
# 1                  -1.499978                 3.051210  ...     -0.293267
# 2                   3.903772                 0.235486  ...      0.228971
# 3                  -0.649258                -1.335106  ...      0.263201
# 4                  -1.240938                 0.594431  ...     -0.010420
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0   -1.551530                       3.539879                       7.949856
# 1   -0.762941                       1.544367                       0.774505
# 2   -0.733434                       0.722474                       1.225016
# 3   -0.876750                       1.344710                       1.722480
# 4   -1.162523                       1.350896                       0.942073
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       9.998070                       5.981761
# 1                       2.746953                       2.826966
# 2                       0.702426                       1.111060
# 3                       0.100154                      -0.033324
# 4                       0.311871                       0.410520
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     7.520298       0.05       -0.1        0.0
# 1                     2.079168       0.05       -0.1        0.0
# 2                     0.298493       0.05       -0.1        0.0
# 3                     0.717958       0.05       -0.1        0.0
# 4                     0.917174       0.05       -0.1        0.0
#
# [5 rows x 28 columns]

# %%
print(data.shape)
# Out:
# (132847, 28)
