# %% [markdown]
# # Data Preparation - LMA Features Data

# %% [markdown]
# ### Note: Datasets follow the format preprocess_datasetname
# So we have, for example: Fs_B_dataset1.csv -> Dataset was first Feature Selected and then Balanced
#
# Fs - Feature Selected
#
# B - Balanced
#
# N - Normalized
#
# S - Standardized

# %% [markdown]
# ## Imports

# %%
import ast
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTENC, SMOTE
from imblearn.under_sampling import NearMiss
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import joblib
from collections import Counter
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv('datasets/KIN_FULL.csv')

# %%
data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.651203                 0.200424                 0.249959
# 1           0.398364                 0.211188                 0.248686
# 2           0.420034                 0.460802                 0.447920
# 3           0.442311                 0.603969                 0.579870
# 4           0.426500                 0.451584                 0.420002
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.419565                   0.434269                   0.457952
# 1           0.084858                   0.433874                   0.452058
# 2           0.095952                   0.441120                   0.431634
# 3           0.113090                   0.483296                   0.462573
# 4           0.169001                   0.321611                   0.278041
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.315414                  0.345453
# 1                  0.319794                  0.346440
# 2                  0.360122                  0.365259
# 3                  0.404034                  0.394707
# 4                  0.311155                  0.305255
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278876  ...
# 1                   0.286151                 0.278843  ...
# 2                   0.286151                 0.278829  ...
# 3                   0.286151                 0.278865  ...
# 4                   0.286151                 0.278841  ...
#
#    r_foot_movement_jerk_y  r_foot_movement_jerk_z  neck_movement_jerk_x  \
# 0               -0.237901                1.761672             -2.399815
# 1                0.470754               -3.348153              4.796719
# 2               -0.236524                1.422290             -2.704696
# 3               -0.017171                0.253756              1.115774
# 4                0.035852               -0.345059             -1.865597
#
#    neck_movement_jerk_y  neck_movement_jerk_z  average upper_body_volume  \
# 0              0.187920              2.788207                   0.032320
# 1             -0.375397             -5.407813                   0.039086
# 2              0.185888              2.454424                   0.115943
# 3             -0.018277              0.309127                   0.142478
# 4              0.028502             -0.331333                   0.096183
#
#    average lower_body_volume  EMOTION_P  EMOTION_A  EMOTION_D
# 0                   0.014900       -0.5        0.6        0.9
# 1                   0.013927       -0.5        0.6        0.9
# 2                   0.010709       -0.5        0.6        0.9
# 3                   0.012613       -0.5        0.6        0.9
# 4                   0.016104       -0.5        0.6        0.9
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Feature Selection

# %%
data = pd.read_csv('datasets/KIN_FULL.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.651203                 0.200424                 0.249959
# 1           0.398364                 0.211188                 0.248686
# 2           0.420034                 0.460802                 0.447920
# 3           0.442311                 0.603969                 0.579870
# 4           0.426500                 0.451584                 0.420002
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.419565                   0.434269                   0.457952
# 1           0.084858                   0.433874                   0.452058
# 2           0.095952                   0.441120                   0.431634
# 3           0.113090                   0.483296                   0.462573
# 4           0.169001                   0.321611                   0.278041
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.315414                  0.345453
# 1                  0.319794                  0.346440
# 2                  0.360122                  0.365259
# 3                  0.404034                  0.394707
# 4                  0.311155                  0.305255
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278876  ...
# 1                   0.286151                 0.278843  ...
# 2                   0.286151                 0.278829  ...
# 3                   0.286151                 0.278865  ...
# 4                   0.286151                 0.278841  ...
#
#    l_foot_movement_jerk_y  l_foot_movement_jerk_z  r_foot_movement_jerk_x  \
# 0                0.174992                3.815811               -0.632432
# 1               -0.364398               -7.515033                1.278706
# 2                0.189845                3.509243               -0.899653
# 3               -0.022183                0.315296                1.025800
# 4                0.148428               -0.848701               -1.779857
#
#    r_foot_movement_jerk_y  r_foot_movement_jerk_z  neck_movement_jerk_x  \
# 0               -0.237901                1.761672             -2.399815
# 1                0.470754               -3.348153              4.796719
# 2               -0.236524                1.422290             -2.704696
# 3               -0.017171                0.253756              1.115774
# 4                0.035852               -0.345059             -1.865597
#
#    neck_movement_jerk_y  neck_movement_jerk_z  average upper_body_volume  \
# 0              0.187920              2.788207                   0.032320
# 1             -0.375397             -5.407813                   0.039086
# 2              0.185888              2.454424                   0.115943
# 3             -0.018277              0.309127                   0.142478
# 4              0.028502             -0.331333                   0.096183
#
#    average lower_body_volume
# 0                   0.014900
# 1                   0.013927
# 2                   0.010709
# 3                   0.012613
# 4                   0.016104
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Variance Analysis

# %%
x_fs = []
y_fs = []
for i in data.columns:
    x_fs.append(data[i].var())
    y_fs.append(i)


fig, ax = plt.subplots(figsize=(15,10))

ax.bar(y_fs, x_fs)

plt.show()

for i in data.columns:
    print(i, " - ", data[i].var())
# Out:
# max_hand_distance  -  0.05419578287875983
# avg_l_hand_hip_distance  -  0.017590618898229722
# avg_r_hand_hip_distance  -  0.02244920821574022
# max_stride_length  -  0.018201714563048206
# avg_l_hand_chest_distance  -  0.011545745379702757
# avg_r_hand_chest_distance  -  0.012047082132569767
# avg_l_elbow_hip_distance  -  0.004560899815279629
# avg_r_elbow_hip_distance  -  0.005052858150701931
# avg_chest_pelvis_distance  -  1.9256689294662283e-20
# avg_neck_chest_distance  -  3.51097714523587e-06
# avg_neck_rotation_w  -  0.004929546860771136
# avg_neck_rotation_x  -  0.01910210842258858
# avg_neck_rotation_y  -  0.013909967148208177
# avg_neck_rotation_z  -  0.003185789011489363
# avg_total_body_volume  -  0.02248712875011006
# avg_triangle_area_hands_neck  -  0.0036392182556160137
# avg_triangle_area_feet_hips  -  0.0028050018450475815
# l_hand_speed  -  0.21732571103048218
# r_hand_speed  -  0.2405768427237763
# l_foot_speed  -  0.14499039096056254
# r_foot_speed  -  0.1485772064765805
# neck_speed  -  0.149966908566844
# l_hand_acceleration_magnitude  -  1.5634258882845302
# r_hand_acceleration_magnitude  -  1.758139897428166
# l_foot_acceleration_magnitude  -  0.9247601954019607
# r_foot_acceleration_magnitude  -  0.9505864522691518
# neck_acceleration_magnitude  -  0.913685604249266
# l_hand_movement_jerk_x  -  16.04217963288006
# l_hand_movement_jerk_y  -  12.882535274659588
# l_hand_movement_jerk_z  -  11.711583171066872
# r_hand_movement_jerk_x  -  16.4281350468843
# r_hand_movement_jerk_y  -  16.712201619564414
# r_hand_movement_jerk_z  -  12.772102957920834
# l_foot_movement_jerk_x  -  10.066591250197781
# l_foot_movement_jerk_y  -  2.543875351513667
# l_foot_movement_jerk_z  -  5.443039238056857
# r_foot_movement_jerk_x  -  10.391480548327538
# r_foot_movement_jerk_y  -  2.4682119713229413
# r_foot_movement_jerk_z  -  5.731022096326255
# neck_movement_jerk_x  -  7.652857249346243
# neck_movement_jerk_y  -  3.6972562675420444
# neck_movement_jerk_z  -  6.631071796506083
# average upper_body_volume  -  0.002015417732925988
# average lower_body_volume  -  0.0011988066586322195

# %% [markdown]
# ### Remove highly correlated features

# %%
data = pd.read_csv('datasets/KIN_FULL.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.651203                 0.200424                 0.249959
# 1           0.398364                 0.211188                 0.248686
# 2           0.420034                 0.460802                 0.447920
# 3           0.442311                 0.603969                 0.579870
# 4           0.426500                 0.451584                 0.420002
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.419565                   0.434269                   0.457952
# 1           0.084858                   0.433874                   0.452058
# 2           0.095952                   0.441120                   0.431634
# 3           0.113090                   0.483296                   0.462573
# 4           0.169001                   0.321611                   0.278041
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.315414                  0.345453
# 1                  0.319794                  0.346440
# 2                  0.360122                  0.365259
# 3                  0.404034                  0.394707
# 4                  0.311155                  0.305255
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278876  ...
# 1                   0.286151                 0.278843  ...
# 2                   0.286151                 0.278829  ...
# 3                   0.286151                 0.278865  ...
# 4                   0.286151                 0.278841  ...
#
#    l_foot_movement_jerk_y  l_foot_movement_jerk_z  r_foot_movement_jerk_x  \
# 0                0.174992                3.815811               -0.632432
# 1               -0.364398               -7.515033                1.278706
# 2                0.189845                3.509243               -0.899653
# 3               -0.022183                0.315296                1.025800
# 4                0.148428               -0.848701               -1.779857
#
#    r_foot_movement_jerk_y  r_foot_movement_jerk_z  neck_movement_jerk_x  \
# 0               -0.237901                1.761672             -2.399815
# 1                0.470754               -3.348153              4.796719
# 2               -0.236524                1.422290             -2.704696
# 3               -0.017171                0.253756              1.115774
# 4                0.035852               -0.345059             -1.865597
#
#    neck_movement_jerk_y  neck_movement_jerk_z  average upper_body_volume  \
# 0              0.187920              2.788207                   0.032320
# 1             -0.375397             -5.407813                   0.039086
# 2              0.185888              2.454424                   0.115943
# 3             -0.018277              0.309127                   0.142478
# 4              0.028502             -0.331333                   0.096183
#
#    average lower_body_volume
# 0                   0.014900
# 1                   0.013927
# 2                   0.010709
# 3                   0.012613
# 4                   0.016104
#
# [5 rows x 44 columns]

# %%
fig = plt.figure(figsize=[32,32])
corr_mtx = data.corr()
sns.heatmap(corr_mtx, xticklabels=corr_mtx.columns, yticklabels=corr_mtx.columns, annot=True, cmap='Blues')
plt.title('Correlation analysis')
plt.show()

# %%
cor_matrix = data.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(to_drop)
# Out:
# []

# %%
df = pd.read_csv('datasets/KIN_FULL.csv')

cor = df.corr()

#Correlation with output variable
cor_target = abs(cor["EMOTION_P"])
print("===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_A"])
print("\n===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_D"])
print("\n===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===")
print(cor_target)
# Out:
# ===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===
# max_hand_distance                0.076806
# avg_l_hand_hip_distance          0.103176
# avg_r_hand_hip_distance          0.107955
# max_stride_length                0.086158
# avg_l_hand_chest_distance        0.000748
# avg_r_hand_chest_distance        0.014387
# avg_l_elbow_hip_distance         0.012232
# avg_r_elbow_hip_distance         0.031149
# avg_chest_pelvis_distance        0.004774
# avg_neck_chest_distance          0.073636
# avg_neck_rotation_w              0.062532
# avg_neck_rotation_x              0.034782
# avg_neck_rotation_y              0.068696
# avg_neck_rotation_z              0.039185
# avg_total_body_volume            0.092371
# avg_triangle_area_hands_neck     0.030234
# avg_triangle_area_feet_hips      0.029346
# l_hand_speed                     0.170075
# r_hand_speed                     0.167593
# l_foot_speed                     0.146356
# r_foot_speed                     0.144993
# neck_speed                       0.116762
# l_hand_acceleration_magnitude    0.216929
# r_hand_acceleration_magnitude    0.210419
# l_foot_acceleration_magnitude    0.186905
# r_foot_acceleration_magnitude    0.181340
# neck_acceleration_magnitude      0.151589
# l_hand_movement_jerk_x           0.001462
# l_hand_movement_jerk_y           0.000995
# l_hand_movement_jerk_z           0.000376
# r_hand_movement_jerk_x           0.001525
# r_hand_movement_jerk_y           0.000559
# r_hand_movement_jerk_z           0.001262
# l_foot_movement_jerk_x           0.001029
# l_foot_movement_jerk_y           0.000130
# l_foot_movement_jerk_z           0.000696
# r_foot_movement_jerk_x           0.001054
# r_foot_movement_jerk_y           0.000141
# r_foot_movement_jerk_z           0.000996
# neck_movement_jerk_x             0.000929
# neck_movement_jerk_y             0.000049
# neck_movement_jerk_z             0.000628
# average upper_body_volume        0.088299
# average lower_body_volume        0.045375
# EMOTION_P                        1.000000
# EMOTION_A                        0.376875
# EMOTION_D                        0.134608
# Name: EMOTION_P, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===
# max_hand_distance                0.128492
# avg_l_hand_hip_distance          0.030980
# avg_r_hand_hip_distance          0.044251
# max_stride_length                0.249075
# avg_l_hand_chest_distance        0.099726
# avg_r_hand_chest_distance        0.123504
# avg_l_elbow_hip_distance         0.109765
# avg_r_elbow_hip_distance         0.123464
# avg_chest_pelvis_distance        0.008777
# avg_neck_chest_distance          0.178499
# avg_neck_rotation_w              0.056153
# avg_neck_rotation_x              0.007009
# avg_neck_rotation_y              0.034433
# avg_neck_rotation_z              0.026638
# avg_total_body_volume            0.142330
# avg_triangle_area_hands_neck     0.153097
# avg_triangle_area_feet_hips      0.178950
# l_hand_speed                     0.168755
# r_hand_speed                     0.175396
# l_foot_speed                     0.185179
# r_foot_speed                     0.189427
# neck_speed                       0.179586
# l_hand_acceleration_magnitude    0.205021
# r_hand_acceleration_magnitude    0.211482
# l_foot_acceleration_magnitude    0.218931
# r_foot_acceleration_magnitude    0.221733
# neck_acceleration_magnitude      0.215912
# l_hand_movement_jerk_x           0.000602
# l_hand_movement_jerk_y           0.000097
# l_hand_movement_jerk_z           0.000558
# r_hand_movement_jerk_x           0.000873
# r_hand_movement_jerk_y           0.000092
# r_hand_movement_jerk_z           0.000326
# l_foot_movement_jerk_x           0.000390
# l_foot_movement_jerk_y           0.000018
# l_foot_movement_jerk_z           0.000190
# r_foot_movement_jerk_x           0.000821
# r_foot_movement_jerk_y           0.000341
# r_foot_movement_jerk_z           0.000007
# neck_movement_jerk_x             0.001330
# neck_movement_jerk_y             0.000184
# neck_movement_jerk_z             0.000273
# average upper_body_volume        0.140929
# average lower_body_volume        0.173817
# EMOTION_P                        0.376875
# EMOTION_A                        1.000000
# EMOTION_D                        0.187439
# Name: EMOTION_A, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===
# max_hand_distance                0.167270
# avg_l_hand_hip_distance          0.094361
# avg_r_hand_hip_distance          0.022465
# max_stride_length                0.049926
# avg_l_hand_chest_distance        0.086055
# avg_r_hand_chest_distance        0.120302
# avg_l_elbow_hip_distance         0.095079
# avg_r_elbow_hip_distance         0.125595
# avg_chest_pelvis_distance        0.011174
# avg_neck_chest_distance          0.038513
# avg_neck_rotation_w              0.045877
# avg_neck_rotation_x              0.030133
# avg_neck_rotation_y              0.044161
# avg_neck_rotation_z              0.097611
# avg_total_body_volume            0.021891
# avg_triangle_area_hands_neck     0.147402
# avg_triangle_area_feet_hips      0.067437
# l_hand_speed                     0.018451
# r_hand_speed                     0.064971
# l_foot_speed                     0.026274
# r_foot_speed                     0.032603
# neck_speed                       0.050393
# l_hand_acceleration_magnitude    0.053952
# r_hand_acceleration_magnitude    0.111019
# l_foot_acceleration_magnitude    0.014177
# r_foot_acceleration_magnitude    0.019510
# neck_acceleration_magnitude      0.041464
# l_hand_movement_jerk_x           0.001610
# l_hand_movement_jerk_y           0.000112
# l_hand_movement_jerk_z           0.001296
# r_hand_movement_jerk_x           0.001405
# r_hand_movement_jerk_y           0.000195
# r_hand_movement_jerk_z           0.001487
# l_foot_movement_jerk_x           0.001416
# l_foot_movement_jerk_y           0.000737
# l_foot_movement_jerk_z           0.000039
# r_foot_movement_jerk_x           0.001775
# r_foot_movement_jerk_y           0.000256
# r_foot_movement_jerk_z           0.000575
# neck_movement_jerk_x             0.001939
# neck_movement_jerk_y             0.001137
# neck_movement_jerk_z             0.000332
# average upper_body_volume        0.056811
# average lower_body_volume        0.003632
# EMOTION_P                        0.134608
# EMOTION_A                        0.187439
# EMOTION_D                        1.000000
# Name: EMOTION_D, dtype: float64

# %%
X = X.drop(columns=[
    "l_hand_movement_jerk_x", "l_hand_movement_jerk_y", "l_hand_movement_jerk_z",
    "r_hand_movement_jerk_x", "r_hand_movement_jerk_y", "r_hand_movement_jerk_z",
    "l_foot_movement_jerk_x", "l_foot_movement_jerk_y", "l_foot_movement_jerk_z",
    "r_foot_movement_jerk_x", "r_foot_movement_jerk_y", "r_foot_movement_jerk_z",
    "neck_movement_jerk_x", "neck_movement_jerk_y", "neck_movement_jerk_z",
])

# %%
#Store

fullData = X.join(y, how='right')
fullData.to_csv(r'datasets/Fs_KIN_FULL.csv', index = False)

# %%
data = pd.read_csv('datasets/Fs_KIN_FULL.csv')

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.651203                 0.200424                 0.249959
# 1           0.398364                 0.211188                 0.248686
# 2           0.420034                 0.460802                 0.447920
# 3           0.442311                 0.603969                 0.579870
# 4           0.426500                 0.451584                 0.420002
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.419565                   0.434269                   0.457952
# 1           0.084858                   0.433874                   0.452058
# 2           0.095952                   0.441120                   0.431634
# 3           0.113090                   0.483296                   0.462573
# 4           0.169001                   0.321611                   0.278041
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.315414                  0.345453
# 1                  0.319794                  0.346440
# 2                  0.360122                  0.365259
# 3                  0.404034                  0.394707
# 4                  0.311155                  0.305255
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278876  ...
# 1                   0.286151                 0.278843  ...
# 2                   0.286151                 0.278829  ...
# 3                   0.286151                 0.278865  ...
# 4                   0.286151                 0.278841  ...
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       1.978233                       1.310616
# 1                       2.286737                       1.715658
# 2                       1.190178                       1.413489
# 3                       2.147360                       2.604527
# 4                       1.166457                       1.262911
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       2.329827                       0.943406
# 1                       2.305231                       0.864409
# 2                       0.151763                       0.150974
# 3                       0.358770                       0.388938
# 4                       0.572567                       0.519719
#
#    neck_acceleration_magnitude  average upper_body_volume  \
# 0                     1.841774                   0.032320
# 1                     1.777824                   0.039086
# 2                     0.174659                   0.115943
# 3                     0.410472                   0.142478
# 4                     0.537061                   0.096183
#
#    average lower_body_volume  EMOTION_P  EMOTION_A  EMOTION_D
# 0                   0.014900       -0.5        0.6        0.9
# 1                   0.013927       -0.5        0.6        0.9
# 2                   0.010709       -0.5        0.6        0.9
# 3                   0.012613       -0.5        0.6        0.9
# 4                   0.016104       -0.5        0.6        0.9
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Data Balancing

# %%
data = pd.read_csv('datasets/KIN_FULL_LABELS.csv')
data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.651203                 0.200424                 0.249959
# 1           0.398364                 0.211188                 0.248686
# 2           0.420034                 0.460802                 0.447920
# 3           0.442311                 0.603969                 0.579870
# 4           0.426500                 0.451584                 0.420002
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.419565                   0.434269                   0.457952
# 1           0.084858                   0.433874                   0.452058
# 2           0.095952                   0.441120                   0.431634
# 3           0.113090                   0.483296                   0.462573
# 4           0.169001                   0.321611                   0.278041
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.315414                  0.345453
# 1                  0.319794                  0.346440
# 2                  0.360122                  0.365259
# 3                  0.404034                  0.394707
# 4                  0.311155                  0.305255
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278876  ...
# 1                   0.286151                 0.278843  ...
# 2                   0.286151                 0.278829  ...
# 3                   0.286151                 0.278865  ...
# 4                   0.286151                 0.278841  ...
#
#    l_foot_movement_jerk_z  r_foot_movement_jerk_x  r_foot_movement_jerk_y  \
# 0                3.815811               -0.632432               -0.237901
# 1               -7.515033                1.278706                0.470754
# 2                3.509243               -0.899653               -0.236524
# 3                0.315296                1.025800               -0.017171
# 4               -0.848701               -1.779857                0.035852
#
#    r_foot_movement_jerk_z  neck_movement_jerk_x  neck_movement_jerk_y  \
# 0                1.761672             -2.399815              0.187920
# 1               -3.348153              4.796719             -0.375397
# 2                1.422290             -2.704696              0.185888
# 3                0.253756              1.115774             -0.018277
# 4               -0.345059             -1.865597              0.028502
#
#    neck_movement_jerk_z  average upper_body_volume  average lower_body_volume  \
# 0              2.788207                   0.032320                   0.014900
# 1             -5.407813                   0.039086                   0.013927
# 2              2.454424                   0.115943                   0.010709
# 3              0.309127                   0.142478                   0.012613
# 4             -0.331333                   0.096183                   0.016104
#
#    EMOTION
# 0    angry
# 1    angry
# 2    angry
# 3    angry
# 4    angry
#
# [5 rows x 45 columns]

# %%
target_count = data['EMOTION'].value_counts()

plt.figure(figsize=(15,8))
plt.title('Class balance')
plt.bar([str(a) for a in target_count.index], target_count.values)
plt.show()
min_class = target_count.idxmin()
ind_min_class = target_count.index.get_loc(min_class)

print('Minority class:', target_count[ind_min_class])
print('Majority class:', target_count[1-ind_min_class])
print('Proportion:', round(target_count[ind_min_class] / target_count[1-ind_min_class], 2), ': 1.0')
# Out:
# Minority class: 3595
# Majority class: 3741
# Proportion: 0.96 : 1.0

# %% [markdown]
# ## Outliers

# %%
from scipy import stats

# %%
data = pd.read_csv('datasets/KIN_FULL.csv')
print(data.shape)
# Out:
# (19186, 47)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.651203
# avg_l_hand_hip_distance          0.200424
# avg_r_hand_hip_distance          0.249959
# max_stride_length                0.419565
# avg_l_hand_chest_distance        0.434269
# avg_r_hand_chest_distance        0.457952
# avg_l_elbow_hip_distance         0.315414
# avg_r_elbow_hip_distance         0.345453
# avg_chest_pelvis_distance        0.286151
# avg_neck_chest_distance          0.278876
# avg_neck_rotation_w              0.011726
# avg_neck_rotation_x             -0.133865
# avg_neck_rotation_y             -0.063344
# avg_neck_rotation_z              0.988637
# avg_total_body_volume            0.097957
# avg_triangle_area_hands_neck     0.126078
# avg_triangle_area_feet_hips      0.036530
# l_hand_speed                     0.989117
# r_hand_speed                     0.655308
# l_foot_speed                     1.164914
# r_foot_speed                     0.471703
# neck_speed                       0.920887
# l_hand_acceleration_magnitude    1.978233
# r_hand_acceleration_magnitude    1.310616
# l_foot_acceleration_magnitude    2.329827
# r_foot_acceleration_magnitude    0.943406
# neck_acceleration_magnitude      1.841774
# l_hand_movement_jerk_x          -2.527994
# l_hand_movement_jerk_y           0.136518
# l_hand_movement_jerk_z           3.040434
# r_hand_movement_jerk_x          -1.755378
# r_hand_movement_jerk_y          -1.538963
# r_hand_movement_jerk_z           1.192098
# l_foot_movement_jerk_x          -2.668585
# l_foot_movement_jerk_y           0.174992
# l_foot_movement_jerk_z           3.815811
# r_foot_movement_jerk_x          -0.632432
# r_foot_movement_jerk_y          -0.237901
# r_foot_movement_jerk_z           1.761672
# neck_movement_jerk_x            -2.399815
# neck_movement_jerk_y             0.187920
# neck_movement_jerk_z             2.788207
# average upper_body_volume        0.032320
# average lower_body_volume        0.014900
# EMOTION_P                       -0.500000
# EMOTION_A                        0.600000
# EMOTION_D                        0.900000
# Name: 0, dtype: float64

# %%
data = data[(np.abs(stats.zscore(data)) < 3).all(axis=1)]
data.shape
# Out:
# (14622, 47)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.651203
# avg_l_hand_hip_distance          0.200424
# avg_r_hand_hip_distance          0.249959
# max_stride_length                0.419565
# avg_l_hand_chest_distance        0.434269
# avg_r_hand_chest_distance        0.457952
# avg_l_elbow_hip_distance         0.315414
# avg_r_elbow_hip_distance         0.345453
# avg_chest_pelvis_distance        0.286151
# avg_neck_chest_distance          0.278876
# avg_neck_rotation_w              0.011726
# avg_neck_rotation_x             -0.133865
# avg_neck_rotation_y             -0.063344
# avg_neck_rotation_z              0.988637
# avg_total_body_volume            0.097957
# avg_triangle_area_hands_neck     0.126078
# avg_triangle_area_feet_hips      0.036530
# l_hand_speed                     0.989117
# r_hand_speed                     0.655308
# l_foot_speed                     1.164914
# r_foot_speed                     0.471703
# neck_speed                       0.920887
# l_hand_acceleration_magnitude    1.978233
# r_hand_acceleration_magnitude    1.310616
# l_foot_acceleration_magnitude    2.329827
# r_foot_acceleration_magnitude    0.943406
# neck_acceleration_magnitude      1.841774
# l_hand_movement_jerk_x          -2.527994
# l_hand_movement_jerk_y           0.136518
# l_hand_movement_jerk_z           3.040434
# r_hand_movement_jerk_x          -1.755378
# r_hand_movement_jerk_y          -1.538963
# r_hand_movement_jerk_z           1.192098
# l_foot_movement_jerk_x          -2.668585
# l_foot_movement_jerk_y           0.174992
# l_foot_movement_jerk_z           3.815811
# r_foot_movement_jerk_x          -0.632432
# r_foot_movement_jerk_y          -0.237901
# r_foot_movement_jerk_z           1.761672
# neck_movement_jerk_x            -2.399815
# neck_movement_jerk_y             0.187920
# neck_movement_jerk_z             2.788207
# average upper_body_volume        0.032320
# average lower_body_volume        0.014900
# EMOTION_P                       -0.500000
# EMOTION_A                        0.600000
# EMOTION_D                        0.900000
# Name: 0, dtype: float64

# %%
data.to_csv(r'datasets/O_KIN_FULL.csv', index = False)

# %% [markdown]
# ## Data Standardization

# %%
data = pd.read_csv('datasets/Fs_O_KIN_FULL.csv')

# %%
target = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)

numeric_vars = data.columns

rows = 16
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(data[numeric_vars[n]].values)))
    axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
    axs[i, j].boxplot(data[numeric_vars[n]].dropna().values)
    
    i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
    
plt.show()

# %%
numeric_data = data

transf = StandardScaler(copy=True).fit(numeric_data)
minMaxData = pd.DataFrame(transf.transform(numeric_data), columns = numeric_data.columns)
minMaxData.describe(include='all')
# Out:
#        max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# count       1.594900e+04             1.594900e+04             1.594900e+04
# mean        7.128148e-17            -3.332409e-16            -2.494852e-17
# std         1.000031e+00             1.000031e+00             1.000031e+00
# min        -2.549078e+00            -2.429937e+00            -2.322161e+00
# 25%        -6.009810e-01            -7.026780e-01            -7.451842e-01
# 50%        -8.650700e-02            -3.293812e-01            -3.381777e-01
# 75%         6.109167e-01             5.271307e-01             5.949399e-01
# max         3.452774e+00             3.458589e+00             3.450980e+00
#
#        max_stride_length  avg_l_hand_chest_distance  \
# count       1.594900e+04               1.594900e+04
# mean        1.880049e-16               3.252218e-16
# std         1.000031e+00               1.000031e+00
# min        -2.564054e+00              -3.203562e+00
# 25%        -6.933777e-01              -5.898895e-01
# 50%        -4.030285e-02               4.315339e-01
# 75%         6.550268e-01               6.752039e-01
# max         3.480436e+00               2.561411e+00
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# count               1.594900e+04              1.594900e+04
# mean                2.851259e-17             -7.110328e-16
# std                 1.000031e+00              1.000031e+00
# min                -3.248324e+00             -3.349666e+00
# 25%                -5.687066e-01             -3.883035e-01
# 50%                 3.689735e-01              2.351897e-01
# 75%                 6.257958e-01              5.741636e-01
# max                 2.769803e+00              3.400882e+00
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# count              1.594900e+04               1.594900e+04
# mean               6.985585e-16              -5.361195e-07
# std                1.000031e+00               1.000031e+00
# min               -3.427529e+00              -6.468927e+00
# 25%               -3.682691e-01              -2.687494e-01
# 50%                1.146300e-01               1.969572e-04
# 75%                5.008550e-01               2.574730e-01
# max                3.544528e+00               6.580935e+00
#
#        avg_neck_chest_distance  ...  l_foot_speed  r_foot_speed    neck_speed  \
# count             1.594900e+04  ...  1.594900e+04  1.594900e+04  1.594900e+04
# mean              1.772236e-14  ... -2.851259e-17  4.276889e-17 -2.049343e-17
# std               1.000031e+00  ...  1.000031e+00  1.000031e+00  1.000031e+00
# min              -9.056666e+00  ... -9.865455e-01 -9.885067e-01 -1.067111e+00
# 25%              -3.806212e-02  ... -7.220387e-01 -7.236357e-01 -7.768099e-01
# 50%               3.312541e-01  ... -3.301237e-01 -3.371371e-01 -3.201426e-01
# 75%               4.830963e-01  ...  3.701922e-01  3.899697e-01  5.009742e-01
# max               5.666180e-01  ...  4.620180e+00  4.631431e+00  4.450981e+00
#
#        l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# count                   1.594900e+04                   1.594900e+04
# mean                    2.494852e-17                   1.630564e-16
# std                     1.000031e+00                   1.000031e+00
# min                    -1.284643e+00                  -1.273422e+00
# 25%                    -7.965826e-01                  -7.980942e-01
# 50%                    -2.175710e-01                  -2.279309e-01
# 75%                     5.712501e-01                   5.654802e-01
# max                     4.051282e+00                   4.093811e+00
#
#        l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# count                   1.594900e+04                   1.594900e+04
# mean                    7.840963e-17                  -5.702519e-17
# std                     1.000031e+00                   1.000031e+00
# min                    -1.106742e+00                  -1.106579e+00
# 25%                    -7.477208e-01                  -7.506225e-01
# 50%                    -2.937363e-01                  -2.883414e-01
# 75%                     4.456056e-01                   4.555674e-01
# max                     4.817629e+00                   4.893644e+00
#
#        neck_acceleration_magnitude  average upper_body_volume  \
# count                 1.594900e+04               1.594900e+04
# mean                  3.742278e-17              -3.252218e-16
# std                   1.000031e+00               1.000031e+00
# min                  -1.154411e+00              -1.813605e+00
# 25%                  -7.863874e-01              -7.429912e-01
# 50%                  -2.771407e-01              -1.945506e-01
# 75%                   5.192152e-01               5.521709e-01
# max                   4.740207e+00               3.853113e+00
#
#        average lower_body_volume
# count               1.594900e+04
# mean               -1.033582e-16
# std                 1.000031e+00
# min                -1.695118e+00
# 25%                -7.499799e-01
# 50%                -2.010570e-01
# 75%                 5.547773e-01
# max                 3.723953e+00
#
# [8 rows x 29 columns]

# %%
numeric_vars = minMaxData.select_dtypes(include='number').columns
rows = 16
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(minMaxData[numeric_vars[n]].values)))
    #only boxplot non boolean vars
    if num_unique == 2:
        off+=1
    else:
        axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
        axs[i, j].boxplot(minMaxData[numeric_vars[n]].dropna().values)
        i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
plt.show()

minMaxData.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.516598                -1.151192                -0.810135
# 1          -0.708269                -1.060155                -0.819624
# 2          -0.603292                 1.051075                 0.664656
# 3          -0.495372                 2.261977                 1.647677
# 4          -0.571965                 0.973109                 0.456672
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.843300                   0.292253                   0.443174
# 1          -1.978618                   0.288282                   0.384267
# 2          -1.885088                   0.361110                   0.180158
# 3          -1.740598                   0.784990                   0.489356
# 4          -1.269206                  -0.839999                  -1.354791
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                 -0.182335                  0.142823
# 1                 -0.108630                  0.159001
# 2                  0.569925                  0.467495
# 3                  1.308789                  0.950228
# 4                 -0.253997                 -0.516128
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_foot_speed  \
# 0                  -0.726582                 0.539334  ...      3.527713
# 1                  -0.038778                 0.487580  ...     -0.850658
# 2                  -0.168087                 0.466177  ...     -0.815400
# 3                  -0.119520                 0.522579  ...     -0.453978
# 4                  -0.542692                 0.485252  ...     -0.255304
#
#    r_foot_speed  neck_speed  l_hand_acceleration_magnitude  \
# 0      0.821382    2.320389                       0.780696
# 1     -0.819864   -0.912037                       1.102877
# 2     -0.758342   -0.781360                      -0.042297
# 3     -0.467551   -0.589751                       0.957321
# 4     -0.509454   -0.550370                      -0.067069
#
#    r_hand_acceleration_magnitude  l_foot_acceleration_magnitude  \
# 0                       0.013971                       2.637739
# 1                       0.412047                       2.598199
# 2                       0.115075                      -0.863683
# 3                       1.285632                      -0.530902
# 4                      -0.032914                      -0.187205
#
#    r_foot_acceleration_magnitude  neck_acceleration_magnitude  \
# 0                       0.389839                     1.742647
# 1                       0.264455                     1.642030
# 2                      -0.867915                    -0.880341
# 3                      -0.490217                    -0.509321
# 4                      -0.282640                    -0.310149
#
#    average upper_body_volume  average lower_body_volume
# 0                  -1.263749                  -1.347394
# 1                  -1.076957                  -1.380873
# 2                   1.044744                  -1.491564
# 3                   1.777284                  -1.426095
# 4                   0.499247                  -1.306004
#
# [5 rows x 29 columns]

# %%
#Store MinMaxScaler

minMaxDataFull = minMaxData.join(target, how='right')
minMaxDataFull.to_csv(r'datasets/Fs_O_S_KIN_FULL.csv', index = False)

joblib.dump(transf, r'datasets/scalers/standardizers/Fs_O_S_KIN_FULL.pkl')
# Out:
# ['datasets/scalers/standardizers/Fs_O_S_KIN_FULL.pkl']
