# %% [markdown]
# # XGBRegression (LMA features to P,A coordinates)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.lines as mlines

import tensorflow as tf

import sklearn
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold

import xgboost as xgb

xgb.set_config(verbosity=2)

from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.utils import shuffle

# %% [markdown]
# ## Load Data

# %%
#dataset = pd.read_csv('datasets/pa/Fs_B_N_LMA_DATA.csv')
#dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA.csv')
#dataset = pd.read_csv('datasets/pa/Fs2_N_LMA_DATA_EXTRA.csv')
#dataset = pd.read_csv('datasets/pa/Fs_B2_N_LMA_DATA_EXTRA.csv')

#dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA_EXTRA.csv')
dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA_EXTRA_NEUTRAL.csv')

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.8, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])

train_dataset = shuffle(train_dataset)
test_dataset = shuffle(test_dataset)
# Out:
# No Training Samples: 45087
# No Test Samples: 11272

# %% [markdown]
# ### Split Features from Targets

# %%
train_X = train_dataset.copy()
test_X = test_dataset.copy()

train_y = pd.concat([train_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)
test_y = pd.concat([test_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)

test_y_p = test_y.iloc[:,0]
train_y_p = train_y.iloc[:,0]

test_y_a = test_y.iloc[:,1]
train_y_a = train_y.iloc[:,1]

# %%
train_X.head()
# Out:
#        avg_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 23645           0.386145                 0.289682                 0.272905
# 22773           0.756434                 0.385899                 0.762562
# 40871           0.431519                 0.636741                 0.588062
# 38398           0.190285                 0.191954                 0.245657
# 4346            0.583562                 0.240309                 0.629033
#
#        avg_feet_distance  avg_l_hand_chest_distance  \
# 23645           0.122893                   0.643832
# 22773           0.253628                   0.694133
# 40871           0.298824                   0.750960
# 38398           0.215687                   0.564221
# 4346            0.274378                   0.594281
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# 23645                   0.627023                  0.573009
# 22773                   0.778141                  0.641876
# 40871                   0.723189                  0.693800
# 38398                   0.528740                  0.466707
# 4346                    0.743033                  0.513947
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# 23645                  0.561757                   0.263210
# 22773                  0.816914                   0.255892
# 40871                  0.662809                   0.262511
# 38398                  0.421020                   0.341410
# 4346                   0.694758                   0.270146
#
#        avg_neck_chest_distance  ...  avg_pelvis_velocity_y  \
# 23645                 0.998517  ...               0.478936
# 22773                 0.984629  ...               0.507456
# 40871                 0.998165  ...               0.469143
# 38398                 0.950505  ...               0.466753
# 4346                  0.994500  ...               0.504846
#
#        avg_pelvis_velocity_z  avg_l_foot_velocity_x  avg_l_foot_velocity_y  \
# 23645               0.481982               0.590816               0.619317
# 22773               0.447254               0.597458               0.623525
# 40871               0.545884               0.592450               0.611776
# 38398               0.474123               0.592332               0.593241
# 4346                0.489602               0.587728               0.614034
#
#        avg_l_foot_velocity_z  avg_r_foot_velocity_x  avg_r_foot_velocity_y  \
# 23645               0.336081               0.448871               0.497298
# 22773               0.338189               0.455445               0.499938
# 40871               0.335615               0.450489               0.492565
# 38398               0.277612               0.436026               0.537028
# 4346                0.343253               0.445814               0.493982
#
#        avg_r_foot_velocity_z  avg_upper_body_volume  avg_distance_traveled
# 23645               0.538551               0.409763               0.001928
# 22773               0.540911               0.693156               0.088915
# 40871               0.538029               0.389446               0.055672
# 38398               0.493381               0.209899               0.022981
# 4346                0.546583               0.453651               0.034770
#
# [5 rows x 33 columns]

# %%
train_y.head()
# Out:
#        EMOTION_P  EMOTION_A
# 23645      -0.35       0.70
# 22773      -0.50       0.60
# 40871      -0.35       0.70
# 38398      -0.60      -0.30
# 4346       -0.40       0.25

# %%
train_X.describe().transpose()[['mean', 'std']]
# Out:
#                                mean       std
# avg_hand_distance          0.367866  0.202526
# avg_l_hand_hip_distance    0.354570  0.185754
# avg_r_hand_hip_distance    0.369125  0.193929
# avg_feet_distance          0.221029  0.105025
# avg_l_hand_chest_distance  0.566260  0.164762
# avg_r_hand_chest_distance  0.563325  0.164601
# avg_l_elbow_hip_distance   0.525713  0.154588
# avg_r_elbow_hip_distance   0.526010  0.155729
# avg_chest_pelvis_distance  0.268310  0.023227
# avg_neck_chest_distance    0.982620  0.035712
# avg_neck_rotation_w        0.476252  0.071978
# avg_neck_rotation_x        0.438399  0.173934
# avg_neck_rotation_y        0.443365  0.086577
# avg_neck_rotation_z        0.921091  0.167569
# avg_pelvis_rotation_w      0.518902  0.059338
# avg_pelvis_rotation_x      0.437719  0.177642
# avg_pelvis_rotation_y      0.421655  0.074516
# avg_pelvis_rotation_z      0.925631  0.163795
# std_l_hand_position        0.123915  0.127292
# std_r_hand_position        0.126052  0.128747
# avg_l_forearm_velocity     0.523746  0.065931
# avg_r_forearm_velocity     0.466473  0.061265
# avg_pelvis_velocity_x      0.595003  0.038377
# avg_pelvis_velocity_y      0.476610  0.027967
# avg_pelvis_velocity_z      0.481474  0.044548
# avg_l_foot_velocity_x      0.590995  0.018215
# avg_l_foot_velocity_y      0.619563  0.027526
# avg_l_foot_velocity_z      0.335727  0.022738
# avg_r_foot_velocity_x      0.448884  0.016939
# avg_r_foot_velocity_y      0.497207  0.017822
# avg_r_foot_velocity_z      0.538277  0.026444
# avg_upper_body_volume      0.424719  0.175602
# avg_distance_traveled      0.040045  0.045548

# %% [markdown]
# ## Define Model

# %%
xgbr = xgb.XGBRegressor(verbosity=1) 


# Current Best:
# n_estimators = 2000
# learning_rate = 0.05
# max_depth = 10
# min_child_weight = 11
# subsample = 1
# gamma = 0

# Try something like:
# {'objective': 'reg:linear', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'enable_categorical': False, 'gamma': 0.5, 'gpu_id': -1, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.05, 'max_delta_step': 0, 'max_depth': 20, 'min_child_weight': 22, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1000, 'n_jobs': 8, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 0.5, 'tree_method': 'exact', 'validate_parameters': 1, 'verbosity': None}

# Best:
#
#
#{'objective': 'reg:squarederror', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'enable_categorical': False, 'gamma': 0, 'gpu_id': 0, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.05, 'max_delta_step': 0, 'max_depth': 10, 'min_child_weight': 5, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1000, 'n_jobs': 12, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0.5, 'reg_lambda': 1.5, 'scale_pos_weight': 1, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'validate_parameters': 1, 'verbosity': None, 'lambda': 1.5, 'alpha': 0.5}
#

model_p = xgb.XGBRegressor(
                    n_estimators=1000, learning_rate=0.08, max_depth=15, min_child_weight=5, 
                    reg_alpha=0.5, reg_lambda=1.5,
                    subsample=0.8, colsample_bytree=1, objective="reg:squarederror"
                )

model_a = xgb.XGBRegressor(
                    n_estimators=1000, learning_rate=0.08, max_depth=15, min_child_weight=5, 
                    reg_alpha=0.5, reg_lambda=1.5,
                    subsample=0.8, colsample_bytree=1, objective="reg:squarederror"
                )

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Pleasure Regression

# %%
model_p.fit(train_X, train_y_p)
# Out:
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [19:41:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2574 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2402 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2500 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2340 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2316 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2588 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2424 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2596 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2352 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2450 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2856 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2360 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2880 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2310 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3056 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2390 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2580 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2896 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2362 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2448 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2482 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2286 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2502 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2392 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3036 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3252 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2222 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2612 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1534 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3100 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2864 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3678 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2536 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3536 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2026 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1792 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1976 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2302 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1242 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1252 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3168 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1150 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2146 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3834 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1380 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3540 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2774 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2172 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2108 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2102 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3864 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1406 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1956 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 926 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2336 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2502 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3654 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2216 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1206 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2814 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2560 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2414 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1442 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2340 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1536 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1984 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3240 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1768 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1302 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2400 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3052 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3312 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2744 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1956 extra nodes, 0 pruned nodes, max_depth=15
# [19:41:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1782 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3374 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2328 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1850 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4390 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2552 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3258 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2596 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1872 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2492 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3260 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3528 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2872 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2554 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2428 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3060 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2846 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3066 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2666 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3496 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4000 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1478 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2068 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2400 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3020 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3030 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3290 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1676 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3706 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1114 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2940 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3600 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2268 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2484 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1792 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2724 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2656 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3390 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4132 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3824 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2084 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4036 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3908 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2698 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3792 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2738 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2632 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2276 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3462 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3176 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3386 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2446 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1816 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2320 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2998 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3306 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2808 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2786 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3556 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2150 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2508 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1654 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2354 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3094 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3872 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3452 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2654 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3712 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1850 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3846 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1818 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3732 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2810 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2682 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2558 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2726 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1984 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1674 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2742 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4048 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2092 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2936 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2614 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3182 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2720 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2338 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3198 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2950 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3106 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2406 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2798 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3958 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3044 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2284 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3308 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2694 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2410 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2770 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2088 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3346 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2906 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2700 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2504 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2858 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2878 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2404 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1518 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2520 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2276 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2188 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3416 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3058 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2696 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3078 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2246 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2490 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2268 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2968 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2070 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3212 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2280 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3328 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2418 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2534 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1174 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2556 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2896 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2020 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2670 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2238 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2052 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2890 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2670 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1936 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2354 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1776 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2978 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2378 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2430 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2050 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1960 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1654 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1736 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2548 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1962 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2206 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2166 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3096 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1746 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2254 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2366 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2522 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1558 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1730 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2006 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2060 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2098 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2648 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2386 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2614 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1646 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1686 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2486 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2248 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1504 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1640 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2076 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1554 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1822 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2186 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2278 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2186 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2182 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2078 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2078 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1838 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1908 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1874 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2422 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2008 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1438 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1364 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2296 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2024 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2250 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1286 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2102 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1500 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2248 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1884 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2222 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1468 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2022 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1880 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1862 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1756 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1888 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1990 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1676 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1956 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1960 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1740 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1680 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1374 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1744 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1998 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1322 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1584 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1580 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1766 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1718 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1784 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1290 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1820 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1992 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1648 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1752 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1434 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1526 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1642 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1810 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1510 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1720 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1900 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1490 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1918 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1312 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1558 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1476 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1666 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1412 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1774 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1552 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1292 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1610 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1736 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1468 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1574 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1626 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1262 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1548 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1172 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1384 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1398 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1498 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1490 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1404 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1130 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1606 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1412 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1588 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1644 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1228 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1702 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1442 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1494 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1260 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1174 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1432 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1338 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 968 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1114 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1384 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1424 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1226 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1180 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1462 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1256 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1324 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1204 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1294 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1268 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1330 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1270 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1402 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1126 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1308 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 976 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1362 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1334 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1220 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1266 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1164 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1238 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1056 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1202 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1228 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1100 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1296 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1162 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1126 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1154 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1154 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1270 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 968 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1186 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1040 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1148 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1168 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1098 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1076 extra nodes, 0 pruned nodes, max_depth=15
# [19:42:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1150 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1188 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1086 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1118 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 972 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 920 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1074 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 998 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1158 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1062 extra nodes, 0 pruned nodes, max_depth=15
# [19:43:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 932 extra nodes, 0 pruned nodes, max_depth=15
# ...
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 454 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 340 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 308 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 374 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 410 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 294 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 358 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 414 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 340 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 344 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 312 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 416 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 268 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 388 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 350 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 314 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 296 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 352 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 356 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 330 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 404 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 344 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 414 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 368 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 244 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 432 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 424 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 310 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 366 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 326 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 324 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 310 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 306 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 344 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 396 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 402 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 336 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 436 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 366 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 350 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 410 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 388 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 260 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 452 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 308 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 292 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 360 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 294 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 286 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 298 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 330 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 318 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 288 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 284 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 284 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 374 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 356 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 400 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 368 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 252 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 334 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 286 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 396 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 354 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 382 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 342 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 294 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 380 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 286 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 300 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 352 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 352 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 256 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 322 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 382 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 284 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 264 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 288 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 272 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 306 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 322 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 272 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 312 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 246 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 240 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 314 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 388 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 330 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 268 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 352 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 390 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 258 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 268 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 314 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 372 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 294 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 286 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 258 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 268 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 218 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 286 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 260 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 336 extra nodes, 0 pruned nodes, max_depth=15
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.08, max_delta_step=0,
#              max_depth=15, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0.5, reg_lambda=1.5, scale_pos_weight=1, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ### Arousal Regression

# %%
model_a.fit(train_X, train_y_a)
# Out:
# [19:44:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3140 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3128 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3126 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3408 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3290 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3214 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3044 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2852 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3512 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3304 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3312 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3172 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3050 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3442 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2984 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3544 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3540 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3438 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3564 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3860 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4602 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3404 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3326 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3252 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3442 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3752 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3916 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3662 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3414 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3580 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4440 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3456 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3870 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2984 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3476 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2908 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3514 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3112 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3528 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3360 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2540 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3138 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2562 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3332 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2120 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3232 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2434 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3056 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2042 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2872 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3060 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2718 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3662 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1436 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4366 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3256 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3774 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1674 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2540 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2986 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3544 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4124 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1804 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3572 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2694 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2192 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2982 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3336 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3052 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1390 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3302 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3476 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3208 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3930 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1514 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3374 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2632 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2548 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2294 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2184 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4010 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2648 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3108 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3124 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2432 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1766 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2906 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3092 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1536 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2408 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1974 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1498 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2754 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3956 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3418 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1742 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3408 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2394 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1772 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3546 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2608 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1756 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2434 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1816 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4256 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1900 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3606 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2810 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2026 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1796 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2514 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2086 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3320 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2826 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2372 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2870 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3374 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3224 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3316 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1460 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3820 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1840 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2496 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2948 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2754 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3184 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3836 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3656 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2492 extra nodes, 0 pruned nodes, max_depth=15
# [19:44:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3684 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3244 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1636 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1970 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2736 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3598 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2000 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2992 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3340 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3122 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2154 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2184 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2760 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2928 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1954 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3196 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3096 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2380 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1946 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2062 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2764 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2262 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3230 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2806 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3006 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2794 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2948 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1766 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2952 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3058 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2064 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2526 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2570 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2532 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3406 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1536 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2022 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2366 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3212 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2902 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1950 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2432 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2458 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3074 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2940 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2300 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2424 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2386 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3016 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2712 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1352 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1930 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1728 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2130 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2472 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2820 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2180 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1992 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1942 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1562 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1430 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2854 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2394 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2282 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2198 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2810 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1896 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2134 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2094 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2594 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2344 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2590 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2400 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2132 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1896 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2476 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1958 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1630 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1772 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2040 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1928 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2008 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1258 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1256 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2096 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1860 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2168 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1724 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2540 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2516 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1540 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2060 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2362 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1872 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1918 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1598 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1358 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1952 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1504 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2220 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1200 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1970 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1972 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1322 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1944 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1796 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2176 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2004 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1546 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1794 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1578 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1912 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2056 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1910 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1680 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1818 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1924 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1894 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1520 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1224 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2180 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1894 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1544 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1608 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1840 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1566 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1316 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1612 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1382 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1448 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1868 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1834 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1150 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1632 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1694 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1302 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1462 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1804 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1172 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1620 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1554 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1624 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1848 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1478 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1602 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1616 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1576 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1486 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1288 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1530 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1598 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1418 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1308 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 744 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1580 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1028 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1244 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1442 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1308 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1204 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1566 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1226 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1170 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1316 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1326 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1140 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1404 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 690 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1114 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1152 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1496 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1390 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1180 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1382 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1214 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1612 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1022 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 762 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1624 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 968 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1258 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1020 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1374 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1368 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1200 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1432 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1100 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1172 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1292 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1044 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1270 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1150 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1340 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 774 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1454 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1228 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 748 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1136 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1156 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1126 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1154 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1012 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 964 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 942 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1144 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1084 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1244 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1016 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1104 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1156 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1244 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1284 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1032 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1128 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1168 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 954 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 808 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1088 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 974 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 846 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 894 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1026 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 954 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1006 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 960 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1074 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 982 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1048 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 650 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 978 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1100 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 790 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1244 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1136 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 944 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1048 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 754 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 886 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 712 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 770 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1006 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 914 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 762 extra nodes, 0 pruned nodes, max_depth=15
# [19:45:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 950 extra nodes, 0 pruned nodes, max_depth=15
# ...
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 362 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 280 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 358 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 372 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 350 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 326 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 408 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 442 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 414 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 334 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 378 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 250 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 330 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 370 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 354 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 362 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 390 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 372 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 246 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 268 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 374 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 344 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 454 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 298 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 386 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 316 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 310 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 362 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 452 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 246 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 344 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 300 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 324 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 356 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 334 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 236 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 260 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 296 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 324 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 324 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 234 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 272 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 330 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 288 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 372 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 284 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 300 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 252 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 196 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 326 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 430 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 264 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 318 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 306 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 306 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 316 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 400 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 322 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 394 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 202 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 220 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 256 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 154 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 296 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 326 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 272 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 242 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 390 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 296 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 256 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 254 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 188 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 300 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 260 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 322 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 276 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 336 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 288 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 272 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 336 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 252 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 178 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=15
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.08, max_delta_step=0,
#              max_depth=15, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0.5, reg_lambda=1.5, scale_pos_weight=1, subsample=0.8,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Training Score

# %%
score = model_p.score(train_X, train_y_p)  

print("Pleasure")
print("Training score: ", score)

print()

score = model_a.score(train_X, train_y_a)  

print("Arousal")
print("Training score: ", score)
# Out:
# Pleasure
# Training score:  0.999727023219456
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Arousal
# Training score:  0.9986722516110799

# %% [markdown]
# ### 10-Fold Cross Validation Average Score

# %%
kfold = KFold(n_splits=10, shuffle=True)

scores_p = cross_val_score(model_p, train_X, train_y_p,cv=kfold)

scores_a = cross_val_score(model_a, train_X, train_y_a,cv=kfold)

print("\n\nPleasure")
print("Training score: ", scores_p)
print("Mean cross-validation score: %.2f" % scores_p.mean())


print("\nArousal")
print("Training score: ", scores_a)
print("Mean cross-validation score: %.2f" % scores_a.mean())
# Out:
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [19:47:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2148 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2138 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2254 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2258 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2224 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2160 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2222 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2214 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2188 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2254 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2136 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2596 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2294 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2898 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2162 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2408 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2638 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2924 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2354 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2644 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1880 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3040 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2270 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2846 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2324 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2702 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1914 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2752 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1794 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2314 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3580 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2328 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1942 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2904 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2400 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3520 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2702 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2848 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2286 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1490 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1632 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2800 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1272 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2550 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2688 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1338 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3062 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 986 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3004 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1194 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2800 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1354 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 924 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3734 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2482 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3102 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2404 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2916 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2500 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3388 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1452 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1916 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3566 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2854 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2390 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1044 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1606 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2308 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2284 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2170 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2232 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2256 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1758 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2610 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2228 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2668 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3388 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1774 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2402 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2592 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2668 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3210 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1056 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1982 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2912 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3938 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2774 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1424 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3532 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1894 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2350 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2226 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1874 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3476 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3382 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2272 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1724 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3088 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1896 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2750 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2672 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2908 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3876 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3418 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3884 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3520 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1954 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2410 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2536 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4062 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2156 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3358 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2766 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2476 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3884 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2026 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2566 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2866 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2380 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3674 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2570 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3414 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3924 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2208 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2484 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2210 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2340 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3090 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3802 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1796 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3602 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2458 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2582 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2162 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2058 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3368 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3076 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4452 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2668 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2840 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3034 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3218 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2276 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3236 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2692 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2368 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3492 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2284 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2520 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2686 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2978 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3114 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2238 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3394 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2458 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2752 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2512 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2576 extra nodes, 0 pruned nodes, max_depth=15
# [19:47:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2508 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2466 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3308 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2532 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1998 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1824 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2930 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2756 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2926 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1852 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2602 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2490 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1944 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2488 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2086 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2370 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2780 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1844 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2896 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3372 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1574 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2456 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1570 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2466 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2476 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2524 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2466 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1766 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2496 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2308 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2138 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2068 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2286 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2116 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2020 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1802 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2254 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1818 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1840 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2008 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2388 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1548 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2442 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2338 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2188 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1754 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1992 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1518 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2694 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1470 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2026 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2528 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1818 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2720 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2034 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2506 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1980 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1972 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2020 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2304 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2146 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2496 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2396 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2404 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1946 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1650 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1758 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2284 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1694 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2018 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1866 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1812 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1958 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1698 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2024 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1956 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2154 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1568 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1766 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1340 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2070 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1646 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1978 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1520 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1616 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1814 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1500 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1444 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1588 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1872 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2034 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1632 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1998 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1620 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1554 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1996 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1748 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1924 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1966 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1252 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1366 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1758 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1572 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1482 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1778 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1168 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1290 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1902 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1638 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1500 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1402 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1798 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1742 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1384 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1458 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1194 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1544 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1716 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1444 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1358 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1314 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1312 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1660 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1676 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1306 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1200 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1314 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1352 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1232 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1570 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1188 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1566 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1460 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1120 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1586 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1580 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1428 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1340 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1366 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1288 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1360 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1342 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1220 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1424 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1494 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1104 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1094 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1272 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1240 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1346 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1248 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1326 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1336 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1106 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1368 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1152 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1254 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1120 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1342 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1132 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1118 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1336 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 938 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1156 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1158 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1128 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1278 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1086 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1220 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1030 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1186 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1144 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1152 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1126 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1146 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1116 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 936 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1032 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1102 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1104 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1114 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1230 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1252 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1252 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1106 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1104 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1054 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1006 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1164 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 982 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1052 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1020 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1190 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 990 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1018 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1038 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1130 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1116 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 904 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1038 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1086 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 966 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1086 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1004 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1018 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1084 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 976 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 966 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 860 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 978 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1008 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1012 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 986 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1032 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1064 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=15
# [19:48:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 930 extra nodes, 0 pruned nodes, max_depth=15
# ...
# [19:53:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2698 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2198 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2840 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2656 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2350 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2292 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1972 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2402 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3028 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2510 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2868 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2816 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2602 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1614 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2450 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2278 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2440 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2454 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2610 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2340 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2732 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2168 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2202 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2074 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2220 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2588 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2260 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2582 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2310 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1920 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2554 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2276 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1908 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2250 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2484 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2084 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1370 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2496 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1620 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1560 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2178 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1864 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2150 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2034 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:25] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1958 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1936 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2388 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2208 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:26] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1814 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2100 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2004 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1934 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2130 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1838 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:27] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1614 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1820 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1914 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1782 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1292 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:28] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1290 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1952 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2098 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1432 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1504 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1874 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:29] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1518 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1750 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1584 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1582 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1432 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:30] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1838 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1806 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1994 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1772 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:31] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2040 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1706 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1688 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1772 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1920 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:32] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1348 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1896 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1458 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1720 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1378 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:33] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1780 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1322 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1542 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1690 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1610 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:34] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1662 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1192 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1428 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1484 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1902 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:35] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1564 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1784 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1444 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1434 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1454 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:36] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1606 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1308 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1430 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1050 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1720 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1386 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1640 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1326 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1514 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1512 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1420 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1652 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1338 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1370 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1592 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1282 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1362 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1588 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1160 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1498 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1330 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1466 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1226 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1460 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1348 extra nodes, 0 pruned nodes, max_depth=15
# [19:53:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1534 extra nodes, 0 pruned nodes, max_depth=15

# %% [markdown]
# ### Test Set MAE & MSE

# %%
pred_y_p = model_p.predict(test_X)
mse = mean_squared_error(test_y_p, pred_y_p)
mae = mean_absolute_error(test_y_p, pred_y_p)
print("Pleasure")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)


pred_y_a = model_a.predict(test_X)
mse = mean_squared_error(test_y_a, pred_y_a)
mae = mean_absolute_error(test_y_a, pred_y_a)
print("\nArousal")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)

# %% [markdown]
# ### Graphs

# %%
x_ax = range(100)
plt.plot(x_ax, test_y_p[0:100], label="original")

plt.title("Pleasure predictions")

plt.legend()
plt.show()

# %%
x_ax = range(100)
plt.plot(x_ax, pred_y_p[0:100], label="predicted")

plt.title("Pleasure predictions")

plt.legend()
plt.show()

# %%
x_ax = range(len(test_y_a))
plt.plot(x_ax, test_y_a, label="original")
plt.plot(x_ax, pred_y_a, label="predicted")

plt.title("Arousal predictions")

plt.legend()
plt.show()

# %% [markdown]
# ### Prediction Examples

# %%
row=test_X.iloc[0]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % [y_p[0], y_a[0]])

# %%
row=test_X.iloc[420]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[420]))
print('Predicted: %s' % [y_p[0], y_a[0]])

# %%
row=test_X.iloc[4000]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[4000]))
print('Predicted: %s' % [y_p[0], y_a[0]])

# %% [markdown]
# ## Save Models

# %%
# save to JSON
model_p.save_model("models/l2p_model.json")
model_a.save_model("models/l2a_model.json")

# save to text format
model_p.save_model("models/l2p_model.txt")
model_a.save_model("models/l2a_model.txt")

# %% [markdown]
# ## Load Models

# %%
model_p = xgb.XGBRegressor(verbosity=0)
model_p.load_model("models/l2p_model_final.json")

model_a = xgb.XGBRegressor(verbosity=0)
model_a.load_model("models/l2a_model_final.json")

# %% [markdown]
# ### Graphs

# %%
pred_y_p = model_p.predict(test_X)
mse = mean_squared_error(test_y_p, pred_y_p)
mae = mean_absolute_error(test_y_p, pred_y_p)
print("Pleasure")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)


pred_y_a = model_a.predict(test_X)
mse = mean_squared_error(test_y_a, pred_y_a)
mae = mean_absolute_error(test_y_a, pred_y_a)
print("\nArousal")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)
# Out:
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Pleasure
# MSE: 0.11
# MAE: 0.23
#
# Arousal
# MSE: 0.08
# MAE: 0.20

# %%
x = pred_y_p[0:300]
y = pred_y_a[0:300]

x_reference = [-0.5, 0.6, -0.6, -0.4, -0.35, 0.0, 0.7, -0.5, 0.1, 0.6, 0.5, -0.85, -0.3, 0.9]
y_reference = [0.6, 0.5, -0.3, 0.25, 0.7, 0.0, 0.2, -0.7, -0.7, -0.55, 0.7, -0.1, -0.66, -0.25]
colors_reference = ["crimson", "springgreen", "cornflowerblue", "darkorange", "gold", "olive", 
                    "lightseagreen", "plum", "chocolate", "olivedrab", "purple", "lightslategray",
                    "lightpink", "aquamarine"]

colors = []

color_map = {
    (-0.5, 0.6): "crimson",
    (0.6, 0.5): "springgreen",
    (-0.6, -0.3): "cornflowerblue",
    (-0.4, 0.25): "darkorange" ,
    (-0.35, 0.7): "gold",
    (0.0, 0.0): "olive", 
    (0.7, 0.2): "lightseagreen",
    (-0.5, -0.7): "plum",
    (0.1, -0.7): "chocolate",
    (0.6, -0.55): "olivedrab",
    (0.5, 0.7): "purple",
    (-0.85, -0.1): "lightslategray",
    (-0.3, -0.66): "lightpink",
    (0.9, -0.25): "aquamarine",
}

conv_dict = {
    (-0.5, 0.6): "angry",
    (0.6, 0.5): "happy",
    (-0.6, -0.3): "sad",
    (-0.4, 0.25): "disgusted" ,
    (-0.35, 0.7): "afraid",
    (0.0, 0.0): "neutral", 
    (0.7, 0.2): "pleased",
    (-0.5, -0.7): "bored",
    (0.1, -0.7): "tired",
    (0.6, -0.55): "relaxed",
    (0.5, 0.7): "excited",
    (-0.85, -0.1): "miserable",
    (-0.3, -0.66): "nervous",
    (0.9, -0.25): "satisfied",
    
}

for i in range(len(x)):
    point_coords = (test_y_p.iloc[i], test_y_a.iloc[i])
    
    colors.append(color_map[point_coords])

fig, ax = plt.subplots(figsize=(10,10))

for i in range(len(x_reference)):
    ax.scatter(x_reference[i], y_reference[i], c=colors_reference[i], label=conv_dict[(x_reference[i], y_reference[i])] , marker="x", linewidths=3)

ax.legend()

ax.scatter(x, y, c=colors, alpha=0.6)


line = mlines.Line2D([-1, 1], [0, 0], color='black')
line_2 = mlines.Line2D([0, 0], [-1, 1], color='black')
ax.add_line(line)
ax.add_line(line_2)


plt.ylim([-1,1])
plt.xlim([-1,1])


plt.xlabel('Pleasure')
plt.ylabel('Arousal')
plt.grid(True)

plt.show()

# %% [markdown]
# # Hyperparameter Grid Search with XGBoost

# %%
from datetime import datetime
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

import sklearn
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_absolute_error


import xgboost as xgb

xgb.set_config(verbosity=0)

from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Load Data

# %%
#dataset = pd.read_csv('datasets/pa/Fs_B_N_LMA_DATA.csv')
#dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA.csv')
#dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA_EXTRA.csv')
#dataset = pd.read_csv('datasets/pa/Fs2_N_LMA_DATA_EXTRA.csv')

dataset = pd.read_csv('datasets/pa/Fs_N_LMA_DATA_EXTRA_NEUTRAL.csv')

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.8, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])

train_dataset = shuffle(train_dataset)
test_dataset = shuffle(test_dataset)
# Out:
# No Training Samples: 45087
# No Test Samples: 11272

# %% [markdown]
# ### Split Features from Targets

# %%
train_X = train_dataset.copy()
test_X = test_dataset.copy()

train_y = pd.concat([train_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)
test_y = pd.concat([test_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)

test_y_p = test_y.iloc[:,0]
train_y_p = train_y.iloc[:,0]

test_y_a = test_y.iloc[:,1]
train_y_a = train_y.iloc[:,1]

# %%
train_X.head()
# Out:
#        avg_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 20060           0.326341                 0.278543                 0.215931
# 51171           0.351379                 0.613145                 0.233814
# 45              0.611422                 0.450835                 0.485425
# 41236           0.248388                 0.203329                 0.187738
# 46759           0.566658                 0.354489                 0.904407
#
#        avg_feet_distance  avg_l_hand_chest_distance  \
# 20060           0.126718                   0.628685
# 51171           0.373425                   0.814615
# 45              0.203940                   0.715695
# 41236           0.093227                   0.588670
# 46759           0.436247                   0.517851
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# 20060                   0.585598                  0.550684
# 51171                   0.472974                  0.794014
# 45                      0.443658                  0.654895
# 41236                   0.570449                  0.503468
# 46759                   0.949617                  0.385207
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# 20060                  0.508032                   0.262890
# 51171                  0.337162                   0.264611
# 45                     0.559491                   0.262996
# 41236                  0.481326                   0.261633
# 46759                  0.955074                   0.249014
#
#        avg_neck_chest_distance  ...  avg_pelvis_velocity_y  \
# 20060                 0.999881  ...               0.477107
# 51171                 0.953509  ...               0.480842
# 45                    0.999456  ...               0.476564
# 41236                 0.998808  ...               0.477219
# 46759                 0.984524  ...               0.479265
#
#        avg_pelvis_velocity_z  avg_l_foot_velocity_x  avg_l_foot_velocity_y  \
# 20060               0.481386               0.590563               0.618753
# 51171               0.523682               0.594905               0.608959
# 45                  0.482201               0.590955               0.629147
# 41236               0.483041               0.590525               0.618454
# 46759               0.579248               0.597859               0.613482
#
#        avg_l_foot_velocity_z  avg_r_foot_velocity_x  avg_r_foot_velocity_y  \
# 20060               0.335966               0.448620               0.496944
# 51171               0.318693               0.447435               0.508526
# 45                  0.335214               0.449009               0.503466
# 41236               0.336130               0.448583               0.496756
# 46759               0.314301               0.457932               0.511429
#
#        avg_r_foot_velocity_z  avg_upper_body_volume  avg_distance_traveled
# 20060               0.538421               0.348004               0.002672
# 51171               0.540617               0.364041               0.039767
# 45                  0.537580               0.648522               0.006951
# 41236               0.538606               0.291665               0.001550
# 46759               0.499175               0.441044               0.076062
#
# [5 rows x 33 columns]

# %%
train_y.head()
# Out:
#        EMOTION_P  EMOTION_A
# 20060       -0.6      -0.30
# 51171        0.6      -0.55
# 45           0.6       0.50
# 41236       -0.6      -0.30
# 46759        0.7       0.20

# %%
train_X.describe().transpose()[['mean', 'std']]
# Out:
#                                mean       std
# avg_hand_distance          0.367866  0.202526
# avg_l_hand_hip_distance    0.354570  0.185754
# avg_r_hand_hip_distance    0.369125  0.193929
# avg_feet_distance          0.221029  0.105025
# avg_l_hand_chest_distance  0.566260  0.164762
# avg_r_hand_chest_distance  0.563325  0.164601
# avg_l_elbow_hip_distance   0.525713  0.154588
# avg_r_elbow_hip_distance   0.526010  0.155729
# avg_chest_pelvis_distance  0.268310  0.023227
# avg_neck_chest_distance    0.982620  0.035712
# avg_neck_rotation_w        0.476252  0.071978
# avg_neck_rotation_x        0.438399  0.173934
# avg_neck_rotation_y        0.443365  0.086577
# avg_neck_rotation_z        0.921091  0.167569
# avg_pelvis_rotation_w      0.518902  0.059338
# avg_pelvis_rotation_x      0.437719  0.177642
# avg_pelvis_rotation_y      0.421655  0.074516
# avg_pelvis_rotation_z      0.925631  0.163795
# std_l_hand_position        0.123915  0.127292
# std_r_hand_position        0.126052  0.128747
# avg_l_forearm_velocity     0.523746  0.065931
# avg_r_forearm_velocity     0.466473  0.061265
# avg_pelvis_velocity_x      0.595003  0.038377
# avg_pelvis_velocity_y      0.476610  0.027967
# avg_pelvis_velocity_z      0.481474  0.044548
# avg_l_foot_velocity_x      0.590995  0.018215
# avg_l_foot_velocity_y      0.619563  0.027526
# avg_l_foot_velocity_z      0.335727  0.022738
# avg_r_foot_velocity_x      0.448884  0.016939
# avg_r_foot_velocity_y      0.497207  0.017822
# avg_r_foot_velocity_z      0.538277  0.026444
# avg_upper_body_volume      0.424719  0.175602
# avg_distance_traveled      0.040045  0.045548

# %% [markdown]
# ## Get Best

# %%
# A parameter grid for XGBoost
params = {
        'n_estimators': [500, 1000, 1500, 2000],
        'min_child_weight': [1, 5, 11, 22, 33],
        'gamma': [0, 0.1, 0.25, 0.5],
        'learning_rate': [0.05, 0.1, 0.15, 0.3, 0.5],
        'subsample': [1, 0.8, 0.5],
        'max_depth': [6, 10, 15, 20, 30],
        'lambda': [0.5, 1, 1.5, 2],
        'alpha': [0, 0.1, 0.5, 1]
        }

# %%
model_p = xgb.XGBRegressor(
                    n_estimators=2000, learning_rate=0.05, max_depth=10, min_child_weight=11, 
                    subsample=1, colsample_bytree=1, objective="reg:squarederror"
                )

model_a = xgb.XGBRegressor(
                    n_estimators=2000, learning_rate=0.05, max_depth=10, min_child_weight=11, 
                    subsample=1, colsample_bytree=1, objective="reg:squarederror"
                )

# %%
# Pleasure
# run randomized search
kfold = KFold(n_splits=10, shuffle=True)

n_iter_search = 100
random_search_p = RandomizedSearchCV(model_p, param_distributions=params,
                                   n_iter=n_iter_search, cv=kfold, scoring='neg_mean_absolute_error')

start = time.time()
random_search_p.fit(train_X, train_y_p)


print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
# Out:
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /home/ds/.local/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [215], in <module>
#       5 random_search_p = RandomizedSearchCV(model_p, param_distributions=params,
#       6                                    n_iter=n_iter_search, cv=kfold, scoring='neg_mean_absolute_error')
#       8 start = time.time()
# ----> 9 random_search_p.fit(train_X, train_y_p)
#      12 print("RandomizedSearchCV took %.2f seconds for %d candidates"
#      13       " parameter settings." % ((time.time() - start), n_iter_search))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1766, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1764 def _run_search(self, evaluate_candidates):
#    1765     """Search n_iter candidates from param_distributions"""
# -> 1766     evaluate_candidates(
#    1767         ParameterSampler(
#    1768             self.param_distributions, self.n_iter, random_state=self.random_state
#    1769         )
#    1770     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/.local/lib/python3.8/site-packages/xgboost/core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/xgboost/sklearn.py:789, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     786     obj = None
#     788 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 789 self._Booster = train(
#     790     params,
#     791     train_dmatrix,
#     792     self.get_num_boosting_rounds(),
#     793     evals=evals,
#     794     early_stopping_rounds=early_stopping_rounds,
#     795     evals_result=evals_result,
#     796     obj=obj,
#     797     feval=feval,
#     798     verbose_eval=verbose,
#     799     xgb_model=model,
#     800     callbacks=callbacks,
#     801 )
#     803 self._set_evaluation_result(evals_result)
#     804 return self
#
# File ~/.local/lib/python3.8/site-packages/xgboost/training.py:188, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     115 def train(params, dtrain, num_boost_round=10, evals=(), obj=None, feval=None,
#     116           maximize=None, early_stopping_rounds=None, evals_result=None,
#     117           verbose_eval=True, xgb_model=None, callbacks=None):
#     118     # pylint: disable=too-many-statements,too-many-branches, attribute-defined-outside-init
#     119     """Train a booster with given parameters.
#     120
#     121     Parameters
#    (...)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#     191                           obj=obj, feval=feval,
#     192                           xgb_model=xgb_model, callbacks=callbacks,
#     193                           verbose_eval=verbose_eval,
#     194                           evals_result=evals_result,
#     195                           maximize=maximize,
#     196                           early_stopping_rounds=early_stopping_rounds)
#     197     return bst
#
# File ~/.local/lib/python3.8/site-packages/xgboost/training.py:81, in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79 if callbacks.before_iteration(bst, i, dtrain, evals):
#      80     break
# ---> 81 bst.update(dtrain, i, obj)
#      82 if callbacks.after_iteration(bst, i, dtrain, evals):
#      83     break
#
# File ~/.local/lib/python3.8/site-packages/xgboost/core.py:1680, in Booster.update(self, dtrain, iteration, fobj)
#    1677 self._validate_features(dtrain)
#    1679 if fobj is None:
# -> 1680     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                             ctypes.c_int(iteration),
#    1682                                             dtrain.handle))
#    1683 else:
#    1684     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Arousal
# run randomized search
kfold = KFold(n_splits=10, shuffle=True)

n_iter_search = 100
random_search_a = RandomizedSearchCV(model_a, param_distributions=params,
                                   n_iter=n_iter_search, cv=kfold, scoring='neg_mean_absolute_error')

start = time.time()
random_search_a.fit(train_X, train_y_a)


print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))

# %% [markdown]
# ## Results

# %%
best_regressor_p = random_search_p.best_estimator_

print(best_regressor_p.get_params())
# Out:
# {'objective': 'reg:linear', 'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1.0, 'enable_categorical': False, 'gamma': 0.5, 'gpu_id': -1, 'importance_type': None, 'interaction_constraints': '', 'learning_rate': 0.05, 'max_delta_step': 0, 'max_depth': 20, 'min_child_weight': 22, 'missing': nan, 'monotone_constraints': '()', 'n_estimators': 1000, 'n_jobs': 8, 'num_parallel_tree': 1, 'predictor': 'auto', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'subsample': 0.5, 'tree_method': 'exact', 'validate_parameters': 1, 'verbosity': None}

# %%
best_regressor_a = random_search_a.best_estimator_

print(best_regressor_a.get_params())

# %%
pred_y_p = best_regressor_p.predict(test_X)
mse = mean_squared_error(test_y_p, pred_y_p)
mae = mean_absolute_error(test_y_p, pred_y_p)
print("Pleasure")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)

pred_y_a = best_regressor_p.predict(test_X)
mse = mean_squared_error(test_y_a, pred_y_a)
mae = mean_absolute_error(test_y_a, pred_y_a)
print("\n\nArousal")
print("MSE: %.2f" % mse)
print("MAE: %.2f" % mae)

# %%
x_ax = range(len(test_y_p))
plt.plot(x_ax, test_y_p, label="original")
plt.plot(x_ax, pred_y_p, label="predicted")

plt.title("Pleasure predictions")

plt.legend()
plt.show()

# %% [markdown]
# ### Predictions

# %%
row=test_X.iloc[0]

x = np.asarray([row])

y_p = best_regressor_p.predict(x)
y_a = best_regressor_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % [y_p[0], y_a[0]])
# Out:
# Real: -0.5
# Predicted: -0.23044229

# %% [markdown]
# # Neural Network for Regression (LMA features to P,A coordinates)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import RepeatedKFold
# Out:
# 2022-03-10 19:51:17.745214: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:17.745282: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Load Data

# %%
#dataset = pd.read_csv('datasets/pa/LMA_DATA.csv')
#dataset = pd.read_csv('datasets/pa/Fs_B_LMA_DATA.csv')

dataset = pd.read_csv('datasets/pa/Fs_LMA_DATA_EXTRA.csv')

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.8, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])
# Out:
# No Training Samples: 45087
# No Test Samples: 11272

# %% [markdown]
# ### Split Features from Targets

# %%
train_X = train_dataset.copy()
test_X = test_dataset.copy()

train_y = pd.concat([train_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)
test_y = pd.concat([test_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)

# %%
train_X.head()
# Out:
#        avg_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 5770            0.380282                 0.661481                 0.693188
# 20189           0.760466                 0.506470                 0.499213
# 55768           0.580429                 0.168741                 0.465727
# 5563            0.473783                 0.286455                 0.248704
# 53047           0.815654                 0.545759                 0.515166
#
#        avg_feet_distance  avg_l_hand_chest_distance  \
# 5770            0.369381                   0.480609
# 20189           0.280216                   0.567541
# 55768           0.278130                   0.418851
# 5563            0.449423                   0.480491
# 53047           0.417240                   0.429151
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# 5770                    0.458428                  0.432211
# 20189                   0.307238                  0.443042
# 55768                   0.543607                  0.287841
# 5563                    0.461131                  0.361082
# 53047                   0.430379                  0.412061
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# 5770                   0.406739                   0.286151
# 20189                  0.275669                   0.286151
# 55768                  0.427787                   0.286151
# 5563                   0.343791                   0.286151
# 53047                  0.387947                   0.286151
#
#        avg_neck_chest_distance  ...  avg_pelvis_velocity_y  \
# 5770                  0.278481  ...              -0.032571
# 20189                 0.278833  ...               0.148304
# 55768                 0.267957  ...               0.055718
# 5563                  0.278724  ...               0.286956
# 53047                 0.277062  ...              -0.268965
#
#        avg_pelvis_velocity_z  avg_l_foot_velocity_x  avg_l_foot_velocity_y  \
# 5770                0.463787               0.008890               0.521765
# 20189              -0.986957               0.107026              -0.060120
# 55768              -0.386061              -0.208628               1.608111
# 5563                0.203860              -0.085325               0.126640
# 53047               0.362865              -0.787257               1.232325
#
#        avg_l_foot_velocity_z  avg_r_foot_velocity_x  avg_r_foot_velocity_y  \
# 5770               -0.203105               0.008890               0.521765
# 20189               0.487608               0.107026              -0.060120
# 55768               1.892997              -0.512417              -0.950072
# 5563                0.158180              -0.085325               0.126640
# 53047               1.885969               0.323288               0.566038
#
#        avg_r_foot_velocity_z  avg_upper_body_volume  avg_distance_traveled
# 5770               -0.203105               0.051152               0.004335
# 20189               0.487608               0.043785               0.010320
# 55768              -0.566143               0.027890               0.002431
# 5563                0.158180               0.030401               0.002548
# 53047              -2.243664               0.055453               0.003610
#
# [5 rows x 33 columns]

# %%
train_y.head()
# Out:
#        EMOTION_P  EMOTION_A
# 5770       -0.35        0.7
# 20189      -0.35        0.7
# 55768      -0.85       -0.1
# 5563       -0.50        0.6
# 53047       0.50        0.7

# %%
train_X.describe().transpose()[['mean', 'std']]
# Out:
#                                mean           std
# avg_hand_distance          0.529250  2.858826e-01
# avg_l_hand_hip_distance    0.368487  1.767053e-01
# avg_r_hand_hip_distance    0.384095  1.830527e-01
# avg_feet_distance          0.338780  1.578916e-01
# avg_l_hand_chest_distance  0.433375  1.218224e-01
# avg_r_hand_chest_distance  0.435605  1.203586e-01
# avg_l_elbow_hip_distance   0.342878  8.884460e-02
# avg_r_elbow_hip_distance   0.348284  8.796934e-02
# avg_chest_pelvis_distance  0.286151  7.207276e-10
# avg_neck_chest_distance    0.277053  3.783007e-03
# avg_neck_rotation_w       -0.006553  1.122287e-01
# avg_neck_rotation_x       -0.044965  3.232766e-01
# avg_neck_rotation_y       -0.073788  1.523782e-01
# avg_neck_rotation_z        0.881896  2.507139e-01
# avg_pelvis_rotation_w     -0.008579  8.910255e-02
# avg_pelvis_rotation_x     -0.045808  3.302284e-01
# avg_pelvis_rotation_y     -0.067394  1.271939e-01
# avg_pelvis_rotation_z      0.888927  2.445222e-01
# std_l_hand_position        0.946554  9.527397e-01
# std_r_hand_position        0.976579  9.857990e-01
# avg_l_forearm_velocity     0.028861  1.687643e+00
# avg_r_forearm_velocity     0.032204  1.709835e+00
# avg_pelvis_velocity_x      0.005840  3.695934e-01
# avg_pelvis_velocity_y     -0.002192  2.586952e-01
# avg_pelvis_velocity_z      0.002865  3.563536e-01
# avg_l_foot_velocity_x      0.012743  9.709588e-01
# avg_l_foot_velocity_y      0.000351  1.028966e+00
# avg_l_foot_velocity_z     -0.007952  1.165969e+00
# avg_r_foot_velocity_x      0.003867  9.121743e-01
# avg_r_foot_velocity_y     -0.014228  1.061643e+00
# avg_r_foot_velocity_z     -0.002313  1.210872e+00
# avg_upper_body_volume      0.035811  1.284636e-02
# avg_distance_traveled      0.003116  3.543725e-03

# %% [markdown]
# ### Normalize Data

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_X))
# Out:
# 2022-03-10 19:51:57.070678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-10 19:51:57.070951: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071045: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071113: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071209: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071329: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071393: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071454: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071518: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-10 19:51:57.071527: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-10 19:51:57.080168: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(normalizer.mean.numpy())
# Out:
# [[ 5.2924943e-01  3.6848739e-01  3.8409463e-01  3.3877978e-01
#    4.3337458e-01  4.3560424e-01  3.4287751e-01  3.4828344e-01
#    2.8615117e-01  2.7705243e-01 -6.5531838e-03 -4.4965312e-02
#   -7.3787861e-02  8.8189656e-01 -8.5787745e-03 -4.5807511e-02
#   -6.7394182e-02  8.8892668e-01  9.4655275e-01  9.7657913e-01
#    2.8861398e-02  3.2204371e-02  5.8395267e-03 -2.1922518e-03
#    2.8645722e-03  1.2742929e-02  3.5076356e-04 -7.9521555e-03
#    3.8666967e-03 -1.4228471e-02 -2.3128937e-03  3.5810597e-02
#    3.1155969e-03]]

# %%
first = np.array(train_X[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[ 0.38  0.66  0.69  0.37  0.48  0.46  0.43  0.41  0.29  0.28  0.23 -0.27
#   -0.03  0.94  0.17 -0.28 -0.03  0.94  0.67  0.86  0.34  0.17 -0.06 -0.03
#    0.46  0.01  0.52 -0.2   0.01  0.52 -0.2   0.05  0.  ]]
#
# Normalized: [[-0.52  1.66  1.69  0.19  0.39  0.19  1.01  0.66 -0.6   0.38  2.1  -0.68
#    0.27  0.21  2.06 -0.71  0.31  0.22 -0.29 -0.12  0.18  0.08 -0.17 -0.12
#    1.29 -0.    0.51 -0.17  0.01  0.5  -0.17  1.19  0.34]]

# %% [markdown]
# ## Create Model

# %% [markdown]
# ### Define Model Layers

# %%
# "Usually it's a good practice to apply following formula in order to find out the total number of hidden layers needed." - https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# Nh = Ns/(α∗ (Ni + No))
# where:
#      Ni = number of input neurons.
#      No = number of output neurons.
#      Ns = number of samples in training data set.
#      α = an arbitrary scaling factor usually 2-10.
 
# Nh = 34431 / (5 * (29 + 2)) +-= 230

def build_and_compile_model(norm):
    model = keras.Sequential([
                norm,
        
                layers.Dense(32, activation='relu'),
                layers.Dense(64, activation='relu'),
                layers.Dense(32, activation='relu'),
        
                layers.Dense(2)
            ])

    
    model.compile(loss='mean_absolute_error',optimizer='adam') # Using MAE
    #model.compile(loss='mean_squared_error', optimizer='adam') # Using MSE
    
    return model

# %% [markdown]
# ### Build Model

# %%
model = build_and_compile_model(normalizer)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 33)               67
#  n)
#
#  dense (Dense)               (None, 32)                1088
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 5,413
# Trainable params: 5,346
# Non-trainable params: 67
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
# %%time
history = model.fit(
    train_X,
    train_y,
    validation_split=0.2,
    epochs=128, batch_size = 16, 
    verbose=2)
# Out:
# Epoch 1/128
# 2255/2255 - 3s - loss: 0.3520 - val_loss: 0.3318 - 3s/epoch - 1ms/step
# Epoch 2/128
# 2255/2255 - 2s - loss: 0.3244 - val_loss: 0.3222 - 2s/epoch - 806us/step
# Epoch 3/128
# 2255/2255 - 2s - loss: 0.3136 - val_loss: 0.3141 - 2s/epoch - 809us/step
# Epoch 4/128
# 2255/2255 - 2s - loss: 0.3064 - val_loss: 0.3084 - 2s/epoch - 814us/step
# Epoch 5/128
# 2255/2255 - 2s - loss: 0.3010 - val_loss: 0.3019 - 2s/epoch - 811us/step
# Epoch 6/128
# 2255/2255 - 2s - loss: 0.2965 - val_loss: 0.3025 - 2s/epoch - 812us/step
# Epoch 7/128
# 2255/2255 - 2s - loss: 0.2928 - val_loss: 0.2982 - 2s/epoch - 813us/step
# Epoch 8/128
# 2255/2255 - 2s - loss: 0.2891 - val_loss: 0.2996 - 2s/epoch - 812us/step
# Epoch 9/128
# 2255/2255 - 2s - loss: 0.2864 - val_loss: 0.2968 - 2s/epoch - 815us/step
# Epoch 10/128
# 2255/2255 - 2s - loss: 0.2845 - val_loss: 0.2924 - 2s/epoch - 811us/step
# Epoch 11/128
# 2255/2255 - 2s - loss: 0.2821 - val_loss: 0.2923 - 2s/epoch - 811us/step
# Epoch 12/128
# 2255/2255 - 2s - loss: 0.2800 - val_loss: 0.2915 - 2s/epoch - 813us/step
# Epoch 13/128
# 2255/2255 - 2s - loss: 0.2779 - val_loss: 0.2900 - 2s/epoch - 812us/step
# Epoch 14/128
# 2255/2255 - 2s - loss: 0.2765 - val_loss: 0.2905 - 2s/epoch - 815us/step
# Epoch 15/128
# 2255/2255 - 2s - loss: 0.2752 - val_loss: 0.2913 - 2s/epoch - 806us/step
# Epoch 16/128
# 2255/2255 - 2s - loss: 0.2737 - val_loss: 0.2896 - 2s/epoch - 812us/step
# Epoch 17/128
# 2255/2255 - 2s - loss: 0.2723 - val_loss: 0.2920 - 2s/epoch - 813us/step
# Epoch 18/128
# 2255/2255 - 2s - loss: 0.2713 - val_loss: 0.2866 - 2s/epoch - 812us/step
# Epoch 19/128
# 2255/2255 - 2s - loss: 0.2703 - val_loss: 0.2852 - 2s/epoch - 814us/step
# Epoch 20/128
# 2255/2255 - 2s - loss: 0.2694 - val_loss: 0.2844 - 2s/epoch - 820us/step
# Epoch 21/128
# 2255/2255 - 2s - loss: 0.2686 - val_loss: 0.2880 - 2s/epoch - 811us/step
# Epoch 22/128
# 2255/2255 - 2s - loss: 0.2677 - val_loss: 0.2849 - 2s/epoch - 818us/step
# Epoch 23/128
# 2255/2255 - 2s - loss: 0.2664 - val_loss: 0.2863 - 2s/epoch - 810us/step
# Epoch 24/128
# 2255/2255 - 2s - loss: 0.2661 - val_loss: 0.2836 - 2s/epoch - 809us/step
# Epoch 25/128
# 2255/2255 - 2s - loss: 0.2656 - val_loss: 0.2858 - 2s/epoch - 802us/step
# Epoch 26/128
# 2255/2255 - 2s - loss: 0.2639 - val_loss: 0.2864 - 2s/epoch - 814us/step
# Epoch 27/128
# 2255/2255 - 2s - loss: 0.2638 - val_loss: 0.2847 - 2s/epoch - 804us/step
# Epoch 28/128
# 2255/2255 - 2s - loss: 0.2630 - val_loss: 0.2852 - 2s/epoch - 893us/step
# Epoch 29/128
# 2255/2255 - 2s - loss: 0.2619 - val_loss: 0.2842 - 2s/epoch - 855us/step
# Epoch 30/128
# 2255/2255 - 2s - loss: 0.2612 - val_loss: 0.2845 - 2s/epoch - 808us/step
# Epoch 31/128
# 2255/2255 - 2s - loss: 0.2609 - val_loss: 0.2829 - 2s/epoch - 809us/step
# Epoch 32/128
# 2255/2255 - 2s - loss: 0.2607 - val_loss: 0.2834 - 2s/epoch - 809us/step
# Epoch 33/128
# 2255/2255 - 2s - loss: 0.2596 - val_loss: 0.2829 - 2s/epoch - 798us/step
# Epoch 34/128
# 2255/2255 - 2s - loss: 0.2584 - val_loss: 0.2842 - 2s/epoch - 806us/step
# Epoch 35/128
# 2255/2255 - 2s - loss: 0.2578 - val_loss: 0.2809 - 2s/epoch - 801us/step
# Epoch 36/128
# 2255/2255 - 2s - loss: 0.2573 - val_loss: 0.2815 - 2s/epoch - 804us/step
# Epoch 37/128
# 2255/2255 - 2s - loss: 0.2568 - val_loss: 0.2825 - 2s/epoch - 815us/step
# Epoch 38/128
# 2255/2255 - 2s - loss: 0.2561 - val_loss: 0.2812 - 2s/epoch - 831us/step
# Epoch 39/128
# 2255/2255 - 2s - loss: 0.2559 - val_loss: 0.2808 - 2s/epoch - 810us/step
# Epoch 40/128
# 2255/2255 - 2s - loss: 0.2553 - val_loss: 0.2816 - 2s/epoch - 812us/step
# Epoch 41/128
# 2255/2255 - 2s - loss: 0.2553 - val_loss: 0.2809 - 2s/epoch - 819us/step
# Epoch 42/128
# 2255/2255 - 2s - loss: 0.2546 - val_loss: 0.2789 - 2s/epoch - 809us/step
# Epoch 43/128
# 2255/2255 - 2s - loss: 0.2543 - val_loss: 0.2816 - 2s/epoch - 809us/step
# Epoch 44/128
# 2255/2255 - 2s - loss: 0.2536 - val_loss: 0.2811 - 2s/epoch - 815us/step
# Epoch 45/128
# 2255/2255 - 2s - loss: 0.2531 - val_loss: 0.2815 - 2s/epoch - 815us/step
# Epoch 46/128
# 2255/2255 - 2s - loss: 0.2526 - val_loss: 0.2813 - 2s/epoch - 837us/step
# Epoch 47/128
# 2255/2255 - 2s - loss: 0.2523 - val_loss: 0.2800 - 2s/epoch - 817us/step
# Epoch 48/128
# 2255/2255 - 2s - loss: 0.2521 - val_loss: 0.2803 - 2s/epoch - 823us/step
# Epoch 49/128
# 2255/2255 - 2s - loss: 0.2521 - val_loss: 0.2806 - 2s/epoch - 811us/step
# Epoch 50/128
# 2255/2255 - 2s - loss: 0.2510 - val_loss: 0.2824 - 2s/epoch - 808us/step
# Epoch 51/128
# 2255/2255 - 2s - loss: 0.2513 - val_loss: 0.2797 - 2s/epoch - 809us/step
# Epoch 52/128
# 2255/2255 - 2s - loss: 0.2506 - val_loss: 0.2774 - 2s/epoch - 806us/step
# Epoch 53/128
# 2255/2255 - 2s - loss: 0.2500 - val_loss: 0.2789 - 2s/epoch - 814us/step
# Epoch 54/128
# 2255/2255 - 2s - loss: 0.2500 - val_loss: 0.2802 - 2s/epoch - 813us/step
# Epoch 55/128
# 2255/2255 - 2s - loss: 0.2499 - val_loss: 0.2805 - 2s/epoch - 817us/step
# Epoch 56/128
# 2255/2255 - 2s - loss: 0.2496 - val_loss: 0.2777 - 2s/epoch - 812us/step
# Epoch 57/128
# 2255/2255 - 2s - loss: 0.2491 - val_loss: 0.2800 - 2s/epoch - 809us/step
# Epoch 58/128
# 2255/2255 - 2s - loss: 0.2486 - val_loss: 0.2793 - 2s/epoch - 814us/step
# Epoch 59/128
# 2255/2255 - 2s - loss: 0.2486 - val_loss: 0.2795 - 2s/epoch - 812us/step
# Epoch 60/128
# 2255/2255 - 2s - loss: 0.2484 - val_loss: 0.2782 - 2s/epoch - 819us/step
# Epoch 61/128
# 2255/2255 - 2s - loss: 0.2479 - val_loss: 0.2786 - 2s/epoch - 806us/step
# Epoch 62/128
# 2255/2255 - 2s - loss: 0.2474 - val_loss: 0.2789 - 2s/epoch - 822us/step
# Epoch 63/128
# 2255/2255 - 2s - loss: 0.2474 - val_loss: 0.2797 - 2s/epoch - 808us/step
# Epoch 64/128
# 2255/2255 - 2s - loss: 0.2472 - val_loss: 0.2781 - 2s/epoch - 811us/step
# Epoch 65/128
# 2255/2255 - 2s - loss: 0.2472 - val_loss: 0.2788 - 2s/epoch - 803us/step
# Epoch 66/128
# 2255/2255 - 2s - loss: 0.2470 - val_loss: 0.2777 - 2s/epoch - 810us/step
# Epoch 67/128
# 2255/2255 - 2s - loss: 0.2459 - val_loss: 0.2781 - 2s/epoch - 823us/step
# Epoch 68/128
# 2255/2255 - 2s - loss: 0.2459 - val_loss: 0.2784 - 2s/epoch - 816us/step
# Epoch 69/128
# 2255/2255 - 2s - loss: 0.2459 - val_loss: 0.2773 - 2s/epoch - 809us/step
# Epoch 70/128
# 2255/2255 - 2s - loss: 0.2458 - val_loss: 0.2772 - 2s/epoch - 807us/step
# Epoch 71/128
# 2255/2255 - 2s - loss: 0.2456 - val_loss: 0.2768 - 2s/epoch - 813us/step
# Epoch 72/128
# 2255/2255 - 2s - loss: 0.2456 - val_loss: 0.2780 - 2s/epoch - 814us/step
# Epoch 73/128
# 2255/2255 - 2s - loss: 0.2448 - val_loss: 0.2784 - 2s/epoch - 810us/step
# Epoch 74/128
# 2255/2255 - 2s - loss: 0.2447 - val_loss: 0.2773 - 2s/epoch - 814us/step
# Epoch 75/128
# 2255/2255 - 2s - loss: 0.2446 - val_loss: 0.2777 - 2s/epoch - 815us/step
# Epoch 76/128
# 2255/2255 - 2s - loss: 0.2443 - val_loss: 0.2774 - 2s/epoch - 813us/step
# Epoch 77/128
# 2255/2255 - 2s - loss: 0.2442 - val_loss: 0.2774 - 2s/epoch - 820us/step
# Epoch 78/128
# 2255/2255 - 2s - loss: 0.2441 - val_loss: 0.2762 - 2s/epoch - 831us/step
# Epoch 79/128
# 2255/2255 - 2s - loss: 0.2442 - val_loss: 0.2785 - 2s/epoch - 818us/step
# Epoch 80/128
# 2255/2255 - 2s - loss: 0.2437 - val_loss: 0.2776 - 2s/epoch - 813us/step
# Epoch 81/128
# 2255/2255 - 2s - loss: 0.2439 - val_loss: 0.2765 - 2s/epoch - 815us/step
# Epoch 82/128
# 2255/2255 - 2s - loss: 0.2435 - val_loss: 0.2770 - 2s/epoch - 822us/step
# Epoch 83/128
# 2255/2255 - 2s - loss: 0.2434 - val_loss: 0.2770 - 2s/epoch - 831us/step
# Epoch 84/128
# 2255/2255 - 2s - loss: 0.2432 - val_loss: 0.2760 - 2s/epoch - 813us/step
# Epoch 85/128
# 2255/2255 - 2s - loss: 0.2430 - val_loss: 0.2783 - 2s/epoch - 815us/step
# Epoch 86/128
# 2255/2255 - 2s - loss: 0.2430 - val_loss: 0.2773 - 2s/epoch - 813us/step
# Epoch 87/128
# 2255/2255 - 2s - loss: 0.2425 - val_loss: 0.2778 - 2s/epoch - 806us/step
# Epoch 88/128
# 2255/2255 - 2s - loss: 0.2422 - val_loss: 0.2768 - 2s/epoch - 812us/step
# Epoch 89/128
# 2255/2255 - 2s - loss: 0.2426 - val_loss: 0.2759 - 2s/epoch - 811us/step
# Epoch 90/128
# 2255/2255 - 2s - loss: 0.2424 - val_loss: 0.2774 - 2s/epoch - 816us/step
# Epoch 91/128
# 2255/2255 - 2s - loss: 0.2422 - val_loss: 0.2780 - 2s/epoch - 808us/step
# Epoch 92/128
# 2255/2255 - 2s - loss: 0.2418 - val_loss: 0.2791 - 2s/epoch - 811us/step
# Epoch 93/128
# 2255/2255 - 2s - loss: 0.2421 - val_loss: 0.2773 - 2s/epoch - 837us/step
# Epoch 94/128
# 2255/2255 - 2s - loss: 0.2411 - val_loss: 0.2768 - 2s/epoch - 915us/step
# Epoch 95/128
# 2255/2255 - 2s - loss: 0.2415 - val_loss: 0.2780 - 2s/epoch - 814us/step
# Epoch 96/128
# 2255/2255 - 2s - loss: 0.2416 - val_loss: 0.2776 - 2s/epoch - 821us/step
# Epoch 97/128
# 2255/2255 - 2s - loss: 0.2418 - val_loss: 0.2769 - 2s/epoch - 807us/step
# Epoch 98/128
# 2255/2255 - 2s - loss: 0.2411 - val_loss: 0.2790 - 2s/epoch - 821us/step
# Epoch 99/128
# 2255/2255 - 2s - loss: 0.2409 - val_loss: 0.2763 - 2s/epoch - 806us/step
# Epoch 100/128
# 2255/2255 - 2s - loss: 0.2406 - val_loss: 0.2798 - 2s/epoch - 816us/step
# Epoch 101/128
# 2255/2255 - 2s - loss: 0.2405 - val_loss: 0.2755 - 2s/epoch - 814us/step
# Epoch 102/128
# 2255/2255 - 2s - loss: 0.2406 - val_loss: 0.2765 - 2s/epoch - 828us/step
# Epoch 103/128
# 2255/2255 - 2s - loss: 0.2405 - val_loss: 0.2745 - 2s/epoch - 850us/step
# Epoch 104/128
# 2255/2255 - 2s - loss: 0.2404 - val_loss: 0.2781 - 2s/epoch - 813us/step
# Epoch 105/128
# 2255/2255 - 2s - loss: 0.2405 - val_loss: 0.2759 - 2s/epoch - 822us/step
# Epoch 106/128
# 2255/2255 - 2s - loss: 0.2405 - val_loss: 0.2763 - 2s/epoch - 808us/step
# Epoch 107/128
# 2255/2255 - 2s - loss: 0.2397 - val_loss: 0.2766 - 2s/epoch - 811us/step
# Epoch 108/128
# 2255/2255 - 2s - loss: 0.2396 - val_loss: 0.2758 - 2s/epoch - 829us/step
# Epoch 109/128
# 2255/2255 - 2s - loss: 0.2396 - val_loss: 0.2754 - 2s/epoch - 818us/step
# Epoch 110/128
# 2255/2255 - 2s - loss: 0.2392 - val_loss: 0.2768 - 2s/epoch - 816us/step
# Epoch 111/128
# 2255/2255 - 2s - loss: 0.2393 - val_loss: 0.2776 - 2s/epoch - 812us/step
# Epoch 112/128
# 2255/2255 - 2s - loss: 0.2392 - val_loss: 0.2761 - 2s/epoch - 839us/step
# Epoch 113/128
# 2255/2255 - 2s - loss: 0.2384 - val_loss: 0.2768 - 2s/epoch - 814us/step
# Epoch 114/128
# 2255/2255 - 2s - loss: 0.2388 - val_loss: 0.2760 - 2s/epoch - 824us/step
# Epoch 115/128
# 2255/2255 - 2s - loss: 0.2390 - val_loss: 0.2782 - 2s/epoch - 819us/step
# Epoch 116/128
# 2255/2255 - 2s - loss: 0.2386 - val_loss: 0.2744 - 2s/epoch - 811us/step
# Epoch 117/128
# 2255/2255 - 2s - loss: 0.2379 - val_loss: 0.2772 - 2s/epoch - 816us/step
# Epoch 118/128
# 2255/2255 - 2s - loss: 0.2381 - val_loss: 0.2758 - 2s/epoch - 820us/step
# Epoch 119/128
# 2255/2255 - 2s - loss: 0.2375 - val_loss: 0.2778 - 2s/epoch - 815us/step
# Epoch 120/128
# 2255/2255 - 2s - loss: 0.2379 - val_loss: 0.2752 - 2s/epoch - 816us/step
# Epoch 121/128
# 2255/2255 - 2s - loss: 0.2380 - val_loss: 0.2779 - 2s/epoch - 814us/step
# Epoch 122/128
# 2255/2255 - 2s - loss: 0.2375 - val_loss: 0.2746 - 2s/epoch - 809us/step
# Epoch 123/128
# 2255/2255 - 2s - loss: 0.2376 - val_loss: 0.2761 - 2s/epoch - 816us/step
# Epoch 124/128
# 2255/2255 - 2s - loss: 0.2380 - val_loss: 0.2767 - 2s/epoch - 821us/step
# Epoch 125/128
# 2255/2255 - 2s - loss: 0.2378 - val_loss: 0.2763 - 2s/epoch - 813us/step
# Epoch 126/128
# 2255/2255 - 2s - loss: 0.2374 - val_loss: 0.2775 - 2s/epoch - 811us/step
# Epoch 127/128
# 2255/2255 - 2s - loss: 0.2378 - val_loss: 0.2776 - 2s/epoch - 822us/step
# Epoch 128/128
# 2255/2255 - 2s - loss: 0.2374 - val_loss: 0.2762 - 2s/epoch - 826us/step
# CPU times: user 6min 47s, sys: 1min 2s, total: 7min 49s
# Wall time: 3min 56s

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, .5])
    plt.xlabel('Epoch')
    plt.ylabel('Error [P,A]')
    plt.legend()
    plt.grid(True)


plot_loss(history)

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Test

# %%
test_results = model.evaluate(test_X, test_y, verbose=2)
print("Mean Absolute Error:",test_results)
# Out:
# 353/353 - 0s - loss: 0.2719 - 220ms/epoch - 624us/step
# Mean Absolute Error: 0.27186521887779236

# %% [markdown]
# ### Predictions

# %%
test_y.head()
# Out:
#     EMOTION_P  EMOTION_A
# 2        -0.5        0.6
# 9        -0.5        0.6
# 10       -0.5        0.6
# 12       -0.5        0.6
# 16       -0.5        0.6

# %%
test_predictions = model.predict(test_X)

# %%
test_y_p = test_y.iloc[:,0]
pred_y_p = test_predictions[:,0]

fig = plt.figure(figsize=[8,8])

plt.scatter(test_y_p, pred_y_p)

plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Pleasure Predictions')

lims = [-1,1]
plt.xlim(lims)
plt.ylim(lims)

plt.plot(lims, lims)

# %%
test_y_a = test_y.iloc[:,1]
pred_y_a = test_predictions[:,1]

fig = plt.figure(figsize=[8,8])

plt.scatter(test_y_a, pred_y_a)

plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Arousal Predictions')

lims = [-1,1]
plt.xlim(lims)
plt.ylim(lims)

plt.plot(lims, lims)

# %% [markdown]
# ### Prediction

# %%
row=test_X.iloc[3]

newX = np.asarray([row])
print(newX)

yhat = model.predict(newX)
print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % yhat[0])
# Out:
# [[ 4.29294321e-01  3.06416764e-01  1.90160499e-01  4.80217455e-01
#    4.81940802e-01  3.92710381e-01  3.68086612e-01  2.79621814e-01
#    2.86151000e-01  2.78543929e-01  1.46260049e-03  7.27718893e-02
#   -1.24973131e-01  9.88677098e-01 -7.23215648e-03  7.74506342e-02
#   -7.46573787e-02  9.93415262e-01  3.44755140e-01  2.35700501e-01
#    2.43901109e-01 -1.90304534e+00  1.11720574e-01  1.17148491e-02
#   -2.64487607e-01 -3.25672018e-01 -1.32798951e+00 -1.13553977e-01
#   -3.25672018e-01 -1.32798951e+00 -1.13553977e-01  2.75070287e-02
#    2.29849149e-03]]
# Real: [-0.5  0.6]
# Predicted: [-0.52534443  0.1486804 ]

# %%
row=test_X.iloc[150]

newX = np.asarray([row])
print(newX)

yhat = model.predict(newX)
print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % yhat[0])
# Out:
# [[ 1.17215946e-01  3.61241095e-01  3.99839017e-01  4.36527563e-01
#    2.25056134e-01  2.50486207e-01  2.13999571e-01  2.25460328e-01
#    2.86151000e-01  2.78802821e-01 -4.47469565e-02 -1.97556939e-02
#   -1.22498981e-01  9.91259681e-01 -3.79469484e-02 -1.91014097e-02
#   -9.71441635e-02  9.94360778e-01  1.50873400e+00  1.53570480e+00
#    5.10256963e-03  2.48060947e-02 -6.57138458e-02  3.51885611e-03
#    3.30361134e-02  1.60708801e-02 -3.23744358e-02  6.02535890e-02
#    1.60708801e-02 -3.23744358e-02  6.02535890e-02  3.09335762e-02
#    5.35708106e-04]]
# Real: [-0.5  0.6]
# Predicted: [-0.37035128  0.5560564 ]

# %%
row=test_X.iloc[69]

newX = np.asarray([row])
print(newX)

yhat = model.predict(newX)
print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % yhat[0])
# Out:
# [[ 7.45094044e-01  3.08864935e-01  5.89613759e-01  2.16829686e-01
#    4.88945356e-01  5.00097549e-01  3.68079471e-01  4.04840912e-01
#    2.86151000e-01  2.78836833e-01 -4.74951927e-02  1.28751507e-02
#   -1.02237442e-02  9.98701594e-01 -3.35488704e-02  1.02280769e-02
#   -2.56976120e-02  9.99019439e-01  8.40703464e-01  8.31786194e-01
#    7.28529193e-03 -1.12519885e+00 -4.73639152e-02  3.69714237e-03
#   -3.61404533e-02 -3.79055102e-02  1.92132258e-01 -1.37202153e-01
#   -3.79055102e-02  1.92132258e-01 -1.37202153e-01  3.92774494e-02
#    3.67095874e-04]]
# Real: [-0.5  0.6]
# Predicted: [-0.0444088 -0.0207414]

# %% [markdown]
# # Gradient Boosting (LMA features to P,A coordinates)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import sklearn
import tensorflow as tf

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# ## Load Data

# %%
dataset = pd.read_csv('datasets/pa/Fs_B_N_LMA_DATA.csv')

# %% [markdown]
# ### Split into Test and Train data

# %%
train_dataset = dataset.sample(frac=0.8, random_state=42)
test_dataset = dataset.drop(train_dataset.index)

print("No Training Samples:",train_dataset.shape[0])
print("No Test Samples:",test_dataset.shape[0])
# Out:
# No Training Samples: 8000
# No Test Samples: 2000

# %% [markdown]
# ### Split Features from Targets

# %%
train_X = train_dataset.copy()
test_X = test_dataset.copy()

train_y = pd.concat([train_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)
test_y = pd.concat([test_X.pop(x) for x in ['EMOTION_P', 'EMOTION_A']], axis=1)

test_y_p = test_y.iloc[:,0]
train_y_p = train_y.iloc[:,0]

test_y_a = test_y.iloc[:,1]
train_y_a = train_y.iloc[:,1]

# %%
train_X.head()
# Out:
#       avg_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 6252           0.182161                 0.239957                 0.073864
# 4684           0.445825                 0.270398                 0.307184
# 1731           0.630929                 0.655890                 0.246729
# 4742           0.713392                 0.546526                 0.452078
# 4521           0.403415                 0.269620                 0.282995
#
#       avg_feet_distance  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 6252           0.239951                   0.627903                   0.481206
# 4684           0.540458                   0.629404                   0.480568
# 1731           0.060113                   0.653721                   0.612517
# 4742           0.520810                   0.801025                   0.734590
# 4521           0.051448                   0.644198                   0.634451
#
#       avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 6252                  0.502666                  0.344620
# 4684                  0.497964                  0.556971
# 1731                  0.599840                  0.526427
# 4742                  0.773689                  0.665912
# 4521                  0.521853                  0.554992
#
#       avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 6252                   0.415943                 0.979307  ...
# 4684                   0.355507                 0.977475  ...
# 1731                   0.305967                 0.996776  ...
# 4742                   0.339651                 0.989962  ...
# 4521                   0.314383                 0.999728  ...
#
#       avg_pelvis_velocity_y  avg_pelvis_velocity_z  avg_l_foot_velocity_x  \
# 6252               0.581273               0.457494               0.579834
# 4684               0.701403               0.453512               0.567967
# 1731               0.574805               0.494450               0.583849
# 4742               0.532673               0.334498               0.570885
# 4521               0.584685               0.488869               0.583202
#
#       avg_l_foot_velocity_y  avg_l_foot_velocity_z  avg_r_foot_velocity_x  \
# 6252               0.408163               0.508905               0.625058
# 4684               0.471092               0.594918               0.640870
# 1731               0.422701               0.483744               0.630963
# 4742               0.344419               0.486102               0.629931
# 4521               0.422638               0.485936               0.630273
#
#       avg_r_foot_velocity_y  avg_r_foot_velocity_z  avg_upper_body_volume  \
# 6252               0.410921               0.481715               0.206246
# 4684               0.502866               0.438463               0.529884
# 1731               0.421293               0.454491               0.467607
# 4742               0.353288               0.494141               0.682069
# 4521               0.421230               0.457467               0.350990
#
#       avg_distance_traveled
# 6252               0.093821
# 4684               0.154873
# 1731               0.005886
# 4742               0.130044
# 4521               0.006148
#
# [5 rows x 33 columns]

# %%
train_y.head()
# Out:
#       EMOTION_P  EMOTION_A
# 6252        0.1       -0.7
# 4684        0.7        0.2
# 1731       -0.5        0.6
# 4742        0.7        0.2
# 4521        0.6        0.5

# %%
train_X.describe().transpose()[['mean', 'std']]
# Out:
#                                mean       std
# avg_hand_distance          0.403083  0.223347
# avg_l_hand_hip_distance    0.337277  0.200253
# avg_r_hand_hip_distance    0.350649  0.198675
# avg_feet_distance          0.246535  0.107873
# avg_l_hand_chest_distance  0.603496  0.160886
# avg_r_hand_chest_distance  0.589745  0.170321
# avg_l_elbow_hip_distance   0.514783  0.171863
# avg_r_elbow_hip_distance   0.543706  0.171387
# avg_chest_pelvis_distance  0.323467  0.062589
# avg_neck_chest_distance    0.973500  0.048300
# avg_neck_rotation_w        0.419621  0.071443
# avg_neck_rotation_x        0.439855  0.151033
# avg_neck_rotation_y        0.422771  0.083809
# avg_neck_rotation_z        0.942024  0.131383
# avg_pelvis_rotation_w      0.474726  0.059747
# avg_pelvis_rotation_x      0.432543  0.152147
# avg_pelvis_rotation_y      0.467433  0.078508
# avg_pelvis_rotation_z      0.945587  0.119850
# std_l_hand_position        0.372793  0.176933
# std_r_hand_position        0.370799  0.183757
# avg_l_forearm_velocity     0.508280  0.069435
# avg_r_forearm_velocity     0.431091  0.041335
# avg_pelvis_velocity_x      0.548084  0.099633
# avg_pelvis_velocity_y      0.574691  0.075237
# avg_pelvis_velocity_z      0.494783  0.074325
# avg_l_foot_velocity_x      0.583680  0.020146
# avg_l_foot_velocity_y      0.422088  0.032834
# avg_l_foot_velocity_z      0.486823  0.046077
# avg_r_foot_velocity_x      0.629970  0.019218
# avg_r_foot_velocity_y      0.421198  0.031831
# avg_r_foot_velocity_z      0.457458  0.063123
# avg_upper_body_volume      0.436529  0.210297
# avg_distance_traveled      0.060930  0.070738

# %% [markdown]
# ## Define Model

# %%
model_p = GradientBoostingRegressor()
model_a = GradientBoostingRegressor()

# %% [markdown]
# ## Train Model

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ### Pleasure Regression

# %%
n_scores = cross_val_score(model_p, train_X, train_y_p, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
print('MAE: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
# Out:
# MAE: -0.236 (0.007)

# %%
model_p.fit(train_X, train_y_p)
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# ### Arousal Regression

# %%
n_scores = cross_val_score(model_a, train_X, train_y_a, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
print('MAE: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
# Out:
# MAE: -0.240 (0.006)

# %%
model_a.fit(train_X, train_y_a)
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# ## Test Model

# %% [markdown]
# ### Prediction

# %%
row=test_X.iloc[0]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % [y_p, y_a])
# Out:
# Real: [-0.35  0.7 ]
# Predicted: [array([-0.16072887]), array([0.50489924])]
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(

# %%
row=test_X.iloc[150]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % [y_p, y_a])
# Out:
# Real: [-0.35  0.7 ]
# Predicted: [array([-0.25354781]), array([0.40621777])]
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(

# %%
row=test_X.iloc[69]

x = np.asarray([row])

y_p = model_p.predict(x)
y_a = model_a.predict(x)

print('Real: %s' % np.asarray(test_y.iloc[0]))
print('Predicted: %s' % [y_p, y_a])
# Out:
# Real: [-0.35  0.7 ]
# Predicted: [array([-0.27337685]), array([0.32014121])]
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# /home/ds/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
