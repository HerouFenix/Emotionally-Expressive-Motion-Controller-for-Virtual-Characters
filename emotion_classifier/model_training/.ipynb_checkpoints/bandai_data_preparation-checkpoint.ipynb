# %% [markdown]
# # Data Preparation - LMA Features Data

# %% [markdown]
# ### Note: Datasets follow the format preprocess_datasetname
# So we have, for example: Fs_B_dataset1.csv -> Dataset was first Feature Selected and then Balanced
#
# Fs - Feature Selected
#
# B - Balanced
#
# N - Normalized
#
# S - Standardized

# %% [markdown]
# ## Imports

# %%
import ast
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTENC, SMOTE
from imblearn.under_sampling import NearMiss
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import joblib
from collections import Counter
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
data = pd.read_csv('datasets/BANDAI_5frame.csv')

# %%
data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.130036                 0.335475
# 1           0.348051                 0.145184                 0.256784
# 2           0.320294                 0.206306                 0.180224
# 3           0.400389                 0.287300                 0.136974
# 4           0.465923                 0.356129                 0.136171
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.184473                   0.310089
# 1           0.455501                   0.197954                   0.284215
# 2           0.380190                   0.234406                   0.259905
# 3           0.319861                   0.279208                   0.239450
# 4           0.309995                   0.313229                   0.224432
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.210679                  0.093915
# 1                  0.172405                  0.104876
# 2                  0.133006                  0.127385
# 3                  0.112632                  0.156856
# 4                  0.112950                  0.186680
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.236151                 0.223894  ...     -0.137483
# 1                   0.236151                 0.223894  ...     -0.072441
# 2                   0.236151                 0.223894  ...     -0.039016
# 3                   0.236151                 0.223894  ...     -0.036825
# 4                   0.236151                 0.223894  ...     -0.054338
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0   -0.139467                       0.092920                       0.196129
# 1   -0.095084                       0.048935                       0.032804
# 2   -0.093423                       0.030819                       0.043059
# 3   -0.101489                       0.044534                       0.054382
# 4   -0.117573                       0.044670                       0.036618
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.221155                       0.137483
# 1                       0.070625                       0.072096
# 2                       0.028182                       0.036532
# 3                       0.015679                       0.012813
# 4                       0.020074                       0.022012
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     0.139467        0.0        0.0        0.0
# 1                     0.045111        0.0        0.0        0.0
# 2                     0.014232        0.0        0.0        0.0
# 3                     0.021506        0.0        0.0        0.0
# 4                     0.024961        0.0        0.0        0.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Feature Selection

# %%
data = pd.read_csv('datasets/BANDAI_5frame.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.130036                 0.335475
# 1           0.348051                 0.145184                 0.256784
# 2           0.320294                 0.206306                 0.180224
# 3           0.400389                 0.287300                 0.136974
# 4           0.465923                 0.356129                 0.136171
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.184473                   0.310089
# 1           0.455501                   0.197954                   0.284215
# 2           0.380190                   0.234406                   0.259905
# 3           0.319861                   0.279208                   0.239450
# 4           0.309995                   0.313229                   0.224432
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.210679                  0.093915
# 1                  0.172405                  0.104876
# 2                  0.133006                  0.127385
# 3                  0.112632                  0.156856
# 4                  0.112950                  0.186680
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                   0.236151                 0.223894  ...     -0.092920
# 1                   0.236151                 0.223894  ...     -0.048761
# 2                   0.236151                 0.223894  ...     -0.046947
# 3                   0.236151                 0.223894  ...     -0.080247
# 4                   0.236151                 0.223894  ...     -0.119633
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0     -0.196129     -0.221155     -0.137483   -0.139467
# 1     -0.165199     -0.153981     -0.072441   -0.095084
# 2     -0.162465     -0.134006     -0.039016   -0.093423
# 3     -0.151546     -0.128707     -0.036825   -0.101489
# 4     -0.150856     -0.142704     -0.054338   -0.117573
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       0.092920                       0.196129
# 1                       0.048935                       0.032804
# 2                       0.030819                       0.043059
# 3                       0.044534                       0.054382
# 4                       0.044670                       0.036618
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.221155                       0.137483
# 1                       0.070625                       0.072096
# 2                       0.028182                       0.036532
# 3                       0.015679                       0.012813
# 4                       0.020074                       0.022012
#
#    neck_acceleration_magnitude
# 0                     0.139467
# 1                     0.045111
# 2                     0.014232
# 3                     0.021506
# 4                     0.024961
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Variance Analysis

# %%
x_fs = []
y_fs = []
for i in data.columns:
    x_fs.append(data[i].var())
    y_fs.append(i)


fig, ax = plt.subplots(figsize=(15,10))

ax.bar(y_fs, x_fs)

plt.show()

for i in data.columns:
    print(i, " - ", data[i].var())
# Out:
# max_hand_distance  -  0.04138702281688425
# avg_l_hand_hip_distance  -  0.017698249986514217
# avg_r_hand_hip_distance  -  0.016730648847963936
# max_stride_length  -  0.030220419283778825
# avg_l_hand_chest_distance  -  0.009713294572389284
# avg_r_hand_chest_distance  -  0.008602589582727046
# avg_l_elbow_hip_distance  -  0.009810601820626487
# avg_r_elbow_hip_distance  -  0.008122907001707338
# avg_chest_pelvis_distance  -  1.1954088843571798e-15
# avg_neck_chest_distance  -  1.6429687792320283e-15
# avg_total_body_volume  -  0.023660526014428983
# avg_lower_body_volume  -  0.0014029833731013259
# avg_upper_body_volume  -  0.0009643268914666492
# avg_triangle_area_hands_neck  -  0.0018266304801359682
# avg_triangle_area_feet_hips  -  0.0041509300921868785
# l_hand_speed  -  0.0038823566416599574
# r_hand_speed  -  0.003929074422715657
# l_foot_speed  -  0.004472255059550906
# r_foot_speed  -  0.0044071400764339914
# neck_speed  -  0.002892686996260732
# l_hand_acceleration_magnitude  -  0.00043379697323386217
# r_hand_acceleration_magnitude  -  0.00044745030147019034
# l_foot_acceleration_magnitude  -  0.00039714792691029985
# r_foot_acceleration_magnitude  -  0.00038655535765314545
# neck_acceleration_magnitude  -  0.00022859908679562894

# %% [markdown]
# ### Remove highly correlated features

# %%
data = pd.read_csv('datasets/BANDAI_5frame.csv')

# %%
y = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)
X = data

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.433596                 0.130036                 0.335475
# 1           0.348051                 0.145184                 0.256784
# 2           0.320294                 0.206306                 0.180224
# 3           0.400389                 0.287300                 0.136974
# 4           0.465923                 0.356129                 0.136171
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.538619                   0.184473                   0.310089
# 1           0.455501                   0.197954                   0.284215
# 2           0.380190                   0.234406                   0.259905
# 3           0.319861                   0.279208                   0.239450
# 4           0.309995                   0.313229                   0.224432
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.210679                  0.093915
# 1                  0.172405                  0.104876
# 2                  0.133006                  0.127385
# 3                  0.112632                  0.156856
# 4                  0.112950                  0.186680
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                   0.236151                 0.223894  ...     -0.092920
# 1                   0.236151                 0.223894  ...     -0.048761
# 2                   0.236151                 0.223894  ...     -0.046947
# 3                   0.236151                 0.223894  ...     -0.080247
# 4                   0.236151                 0.223894  ...     -0.119633
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0     -0.196129     -0.221155     -0.137483   -0.139467
# 1     -0.165199     -0.153981     -0.072441   -0.095084
# 2     -0.162465     -0.134006     -0.039016   -0.093423
# 3     -0.151546     -0.128707     -0.036825   -0.101489
# 4     -0.150856     -0.142704     -0.054338   -0.117573
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       0.092920                       0.196129
# 1                       0.048935                       0.032804
# 2                       0.030819                       0.043059
# 3                       0.044534                       0.054382
# 4                       0.044670                       0.036618
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.221155                       0.137483
# 1                       0.070625                       0.072096
# 2                       0.028182                       0.036532
# 3                       0.015679                       0.012813
# 4                       0.020074                       0.022012
#
#    neck_acceleration_magnitude
# 0                     0.139467
# 1                     0.045111
# 2                     0.014232
# 3                     0.021506
# 4                     0.024961
#
# [5 rows x 25 columns]

# %%
fig = plt.figure(figsize=[32,32])
corr_mtx = data.corr()
sns.heatmap(corr_mtx, xticklabels=corr_mtx.columns, yticklabels=corr_mtx.columns, annot=True, cmap='Blues')
plt.title('Correlation analysis')
plt.show()

# %%
cor_matrix = data.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(to_drop)
# Out:
# []

# %%
df = pd.read_csv('datasets/BANDAI_5frame.csv')

cor = df.corr()

#Correlation with output variable
cor_target = abs(cor["EMOTION_P"])
print("===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_A"])
print("\n===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_D"])
print("\n===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===")
print(cor_target)
# Out:
# ===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===
# max_hand_distance                0.276000
# avg_l_hand_hip_distance          0.114467
# avg_r_hand_hip_distance          0.094378
# max_stride_length                0.136977
# avg_l_hand_chest_distance        0.222583
# avg_r_hand_chest_distance        0.227384
# avg_l_elbow_hip_distance         0.002018
# avg_r_elbow_hip_distance         0.008609
# avg_chest_pelvis_distance        0.017133
# avg_neck_chest_distance          0.000326
# avg_total_body_volume            0.201772
# avg_lower_body_volume            0.239829
# avg_upper_body_volume            0.084824
# avg_triangle_area_hands_neck     0.224215
# avg_triangle_area_feet_hips      0.149504
# l_hand_speed                     0.072267
# r_hand_speed                     0.066878
# l_foot_speed                     0.065954
# r_foot_speed                     0.064131
# neck_speed                       0.080902
# l_hand_acceleration_magnitude    0.033363
# r_hand_acceleration_magnitude    0.018474
# l_foot_acceleration_magnitude    0.030227
# r_foot_acceleration_magnitude    0.031398
# neck_acceleration_magnitude      0.024755
# EMOTION_P                        1.000000
# EMOTION_A                        0.293274
# EMOTION_D                        0.567683
# Name: EMOTION_P, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===
# max_hand_distance                0.292108
# avg_l_hand_hip_distance          0.208916
# avg_r_hand_hip_distance          0.208006
# max_stride_length                0.294764
# avg_l_hand_chest_distance        0.083364
# avg_r_hand_chest_distance        0.115480
# avg_l_elbow_hip_distance         0.143258
# avg_r_elbow_hip_distance         0.171151
# avg_chest_pelvis_distance        0.003494
# avg_neck_chest_distance          0.006962
# avg_total_body_volume            0.320651
# avg_lower_body_volume            0.346814
# avg_upper_body_volume            0.231569
# avg_triangle_area_hands_neck     0.029774
# avg_triangle_area_feet_hips      0.187476
# l_hand_speed                     0.269009
# r_hand_speed                     0.269789
# l_foot_speed                     0.217934
# r_foot_speed                     0.220185
# neck_speed                       0.261410
# l_hand_acceleration_magnitude    0.260547
# r_hand_acceleration_magnitude    0.282567
# l_foot_acceleration_magnitude    0.163498
# r_foot_acceleration_magnitude    0.172293
# neck_acceleration_magnitude      0.152931
# EMOTION_P                        0.293274
# EMOTION_A                        1.000000
# EMOTION_D                        0.475306
# Name: EMOTION_A, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND DOMINANCE COORDINATE===
# max_hand_distance                0.267581
# avg_l_hand_hip_distance          0.077657
# avg_r_hand_hip_distance          0.092908
# max_stride_length                0.243087
# avg_l_hand_chest_distance        0.151125
# avg_r_hand_chest_distance        0.200152
# avg_l_elbow_hip_distance         0.104746
# avg_r_elbow_hip_distance         0.106868
# avg_chest_pelvis_distance        0.024503
# avg_neck_chest_distance          0.013678
# avg_total_body_volume            0.288924
# avg_lower_body_volume            0.169012
# avg_upper_body_volume            0.205698
# avg_triangle_area_hands_neck     0.225177
# avg_triangle_area_feet_hips      0.203392
# l_hand_speed                     0.113034
# r_hand_speed                     0.113529
# l_foot_speed                     0.109655
# r_foot_speed                     0.110801
# neck_speed                       0.135381
# l_hand_acceleration_magnitude    0.034360
# r_hand_acceleration_magnitude    0.043092
# l_foot_acceleration_magnitude    0.053329
# r_foot_acceleration_magnitude    0.053189
# neck_acceleration_magnitude      0.059421
# EMOTION_P                        0.567683
# EMOTION_A                        0.475306
# EMOTION_D                        1.000000
# Name: EMOTION_D, dtype: float64

# %%
X = X.drop(columns=[

])

# %%
#Store

fullData = X.join(y, how='right')
fullData.to_csv(r'datasets/Fs_BANDAI_05sec.csv', index = False)

# %%
data = pd.read_csv('datasets/Fs_BANDAI_05sec.csv')

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           1.347685                 0.738734                 0.750029
# 1           1.348750                 0.739083                 0.750776
# 2           1.345034                 0.740744                 0.751565
# 3           1.344209                 0.739995                 0.749265
# 4           1.344109                 0.731976                 0.743006
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.265600                   0.677576                   0.697204
# 1           0.264740                   0.677642                   0.697476
# 2           0.264228                   0.677716                   0.697627
# 3           0.264495                   0.677222                   0.696668
# 4           0.264412                   0.675670                   0.694244
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.544674                  0.563073
# 1                  0.544730                  0.563324
# 2                  0.544780                  0.563463
# 3                  0.544343                  0.562580
# 4                  0.542910                  0.560357
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                   0.286151                 0.278618  ...      0.003056
# 1                   0.286151                 0.278559  ...      0.010137
# 2                   0.286151                 0.278467  ...      0.011678
# 3                   0.286151                 0.278507  ...      0.034689
# 4                   0.286151                 0.278629  ...      0.011147
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0    0.003035                       0.019870                       0.016691
# 1    0.000441                       0.072091                       0.023939
# 2    0.004609                       0.017927                       0.015746
# 3    0.006447                       0.104179                       0.024900
# 4    0.001455                       0.074775                       0.038912
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       0.043644                       0.053025
# 1                       0.026367                       0.014939
# 2                       0.011888                       0.009061
# 3                       0.065732                       0.088783
# 4                       0.033537                       0.085538
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     0.014415      -0.35        0.7       -0.8
# 1                     0.005996      -0.35        0.7       -0.8
# 2                     0.009223      -0.35        0.7       -0.8
# 3                     0.019284      -0.35        0.7       -0.8
# 4                     0.013481      -0.35        0.7       -0.8
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Outliers

# %%
from scipy import stats

# %%
data = pd.read_csv('datasets/BANDAI_5frame.csv')
print(data.shape)
# Out:
# (79201, 28)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.433596
# avg_l_hand_hip_distance          0.130036
# avg_r_hand_hip_distance          0.335475
# max_stride_length                0.538619
# avg_l_hand_chest_distance        0.184473
# avg_r_hand_chest_distance        0.310089
# avg_l_elbow_hip_distance         0.210679
# avg_r_elbow_hip_distance         0.093915
# avg_chest_pelvis_distance        0.236151
# avg_neck_chest_distance          0.223894
# avg_total_body_volume            0.247232
# avg_lower_body_volume            0.079520
# avg_upper_body_volume            0.108071
# avg_triangle_area_hands_neck     0.070847
# avg_triangle_area_feet_hips      0.176692
# l_hand_speed                    -0.092920
# r_hand_speed                    -0.196129
# l_foot_speed                    -0.221155
# r_foot_speed                    -0.137483
# neck_speed                      -0.139467
# l_hand_acceleration_magnitude    0.092920
# r_hand_acceleration_magnitude    0.196129
# l_foot_acceleration_magnitude    0.221155
# r_foot_acceleration_magnitude    0.137483
# neck_acceleration_magnitude      0.139467
# EMOTION_P                        0.000000
# EMOTION_A                        0.000000
# EMOTION_D                        0.000000
# Name: 0, dtype: float64

# %%
data = data[(np.abs(stats.zscore(data)) < 3).all(axis=1)]
data.shape
# Out:
# (71283, 28)

# %%
data.iloc[0]
# Out:
# max_hand_distance                0.348051
# avg_l_hand_hip_distance          0.145184
# avg_r_hand_hip_distance          0.256784
# max_stride_length                0.455501
# avg_l_hand_chest_distance        0.197954
# avg_r_hand_chest_distance        0.284215
# avg_l_elbow_hip_distance         0.172405
# avg_r_elbow_hip_distance         0.104876
# avg_chest_pelvis_distance        0.236151
# avg_neck_chest_distance          0.223894
# avg_total_body_volume            0.213422
# avg_lower_body_volume            0.060301
# avg_upper_body_volume            0.095905
# avg_triangle_area_hands_neck     0.062156
# avg_triangle_area_feet_hips      0.140964
# l_hand_speed                    -0.048761
# r_hand_speed                    -0.165199
# l_foot_speed                    -0.153981
# r_foot_speed                    -0.072441
# neck_speed                      -0.095084
# l_hand_acceleration_magnitude    0.048935
# r_hand_acceleration_magnitude    0.032804
# l_foot_acceleration_magnitude    0.070625
# r_foot_acceleration_magnitude    0.072096
# neck_acceleration_magnitude      0.045111
# EMOTION_P                        0.000000
# EMOTION_A                        0.000000
# EMOTION_D                        0.000000
# Name: 1, dtype: float64

# %%
data.to_csv(r'datasets/O_BANDAI_5frame.csv', index = False)

# %% [markdown]
# ## Data Standardization

# %%
data = pd.read_csv('datasets/O_BANDAI_5frame.csv')

# %%
target = pd.concat([data.pop(x) for x in ['EMOTION_P', 'EMOTION_A', 'EMOTION_D']], axis=1)

numeric_vars = data.columns

rows = 14
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(data[numeric_vars[n]].values)))
    axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
    axs[i, j].boxplot(data[numeric_vars[n]].dropna().values)
    
    i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
    
plt.show()

# %%
numeric_data = data

transf = StandardScaler(copy=True).fit(numeric_data)
minMaxData = pd.DataFrame(transf.transform(numeric_data), columns = numeric_data.columns)
minMaxData.describe(include='all')
# Out:
#        max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# count       7.128300e+04             7.128300e+04             7.128300e+04
# mean       -1.347662e-16             2.842849e-16             1.299816e-16
# std         1.000007e+00             1.000007e+00             1.000007e+00
# min        -2.623416e+00            -2.427678e+00            -2.437198e+00
# 25%        -6.682372e-01            -5.796683e-01            -6.361186e-01
# 50%         4.892125e-02             9.955252e-02             5.398142e-04
# 75%         7.117178e-01             6.667794e-01             6.962013e-01
# max         3.175737e+00             3.177894e+00             3.222394e+00
#
#        max_stride_length  avg_l_hand_chest_distance  \
# count       7.128300e+04               7.128300e+04
# mean        1.475251e-16               1.602840e-16
# std         1.000007e+00               1.000007e+00
# min        -2.118452e+00              -3.162451e+00
# 25%        -8.119127e-01              -6.577448e-01
# 50%        -9.713996e-02               5.377188e-02
# 75%         7.586870e-01               7.587618e-01
# max         3.233507e+00               3.215755e+00
#
#        avg_r_hand_chest_distance  avg_l_elbow_hip_distance  \
# count               7.128300e+04              7.128300e+04
# mean                2.456094e-16              4.784598e-17
# std                 1.000007e+00              1.000007e+00
# min                -3.105722e+00             -2.047260e+00
# 25%                -6.782463e-01             -9.916483e-01
# 50%                 5.094368e-02              3.013264e-01
# 75%                 7.621498e-01              7.248909e-01
# max                 3.087463e+00              2.612834e+00
#
#        avg_r_elbow_hip_distance  avg_chest_pelvis_distance  \
# count              7.128300e+04               7.128300e+04
# mean              -2.073326e-17              -1.360432e-09
# std                1.000007e+00               1.000007e+00
# min               -2.274590e+00              -3.529587e+00
# 25%               -9.410647e-01              -6.411214e-01
# 50%                2.406902e-01              -3.838093e-03
# 75%                7.334125e-01               6.349614e-01
# max                2.790915e+00               3.529264e+00
#
#        avg_neck_chest_distance  ...  l_hand_speed  r_hand_speed  l_foot_speed  \
# count             7.128300e+04  ...  7.128300e+04  7.128300e+04  7.128300e+04
# mean             -2.380931e-10  ...  3.628320e-16 -1.834096e-16 -1.754353e-16
# std               1.000007e+00  ...  1.000007e+00  1.000007e+00  1.000007e+00
# min              -3.397991e+00  ... -3.208637e+00 -3.248233e+00 -3.234008e+00
# 25%              -6.542473e-01  ... -6.505527e-01 -6.384982e-01 -5.489696e-01
# 50%              -5.357641e-03  ...  1.305168e-01  1.403661e-01  1.080704e-01
# 75%               6.446813e-01  ...  7.435378e-01  7.319739e-01  8.069580e-01
# max               3.402979e+00  ...  1.584503e+00  1.578625e+00  1.437625e+00
#
#        r_foot_speed    neck_speed  l_hand_acceleration_magnitude  \
# count  7.128300e+04  7.128300e+04                   7.128300e+04
# mean   1.451328e-16 -1.403482e-16                  -7.495871e-17
# std    1.000007e+00  1.000007e+00                   1.000007e+00
# min   -3.207605e+00 -3.268854e+00                  -1.173228e+00
# 25%   -5.614400e-01 -6.053883e-01                  -7.494685e-01
# 50%    1.272824e-01  2.111593e-01                  -2.525653e-01
# 75%    8.004915e-01  6.321433e-01                   4.794188e-01
# max    1.436457e+00  1.751133e+00                   4.395957e+00
#
#        r_hand_acceleration_magnitude  l_foot_acceleration_magnitude  \
# count                   7.128300e+04                   7.128300e+04
# mean                   -9.728683e-17                   1.794224e-16
# std                     1.000007e+00                   1.000007e+00
# min                    -1.144191e+00                  -1.259022e+00
# 25%                    -7.532913e-01                  -7.059608e-01
# 50%                    -2.602473e-01                  -2.618167e-01
# 75%                     4.588846e-01                   4.894525e-01
# max                     4.472347e+00                   4.480046e+00
#
#        r_foot_acceleration_magnitude  neck_acceleration_magnitude
# count                   7.128300e+04                 7.128300e+04
# mean                   -1.491200e-16                 9.728683e-17
# std                     1.000007e+00                 1.000007e+00
# min                    -1.278369e+00                -1.255560e+00
# 25%                    -7.184079e-01                -7.177742e-01
# 50%                    -2.506449e-01                -2.810039e-01
# 75%                     5.043572e-01                 4.954332e-01
# max                     4.568095e+00                 5.528974e+00
#
# [8 rows x 25 columns]

# %%
numeric_vars = minMaxData.select_dtypes(include='number').columns
rows = 14
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0

off=0
for n in range(len(numeric_vars)):
    num_unique = len(list(set(minMaxData[numeric_vars[n]].values)))
    #only boxplot non boolean vars
    if num_unique == 2:
        off+=1
    else:
        axs[i, j].set_title('Boxplot for %s'%numeric_vars[n])
        axs[i, j].boxplot(minMaxData[numeric_vars[n]].dropna().values)
        i, j = (i + 1, 0) if (n+1-off) % cols == 0 else (i, j + 1)
plt.show()

minMaxData.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0          -0.982673                -1.361776                -0.419574
# 1          -0.712179                -0.239658                -1.397944
# 2          -0.373479                 0.303809                -1.404505
# 3          -0.185058                 0.663510                -1.282143
# 4          -0.093530                 0.860543                -1.155933
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.051043                  -1.507705                  -0.598805
# 1          -0.774386                  -0.627450                  -1.113656
# 2          -0.834425                  -0.258885                  -1.286375
# 3          -0.555872                  -0.045593                  -1.399540
# 4          -0.164727                   0.043690                  -1.454359
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                 -0.583161                 -1.420212
# 1                 -1.202001                 -0.819670
# 2                 -1.198714                 -0.475107
# 3                 -1.160121                 -0.170775
# 4                 -1.161320                  0.084042
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  l_hand_speed  \
# 0                  -1.743283                 3.293970  ...      0.754198
# 1                  -0.765794                -1.466291  ...      0.218064
# 2                  -1.445642                 0.627744  ...     -0.452601
# 3                  -0.830898                -1.061375  ...     -0.847862
# 4                  -2.100372                 0.234865  ...     -0.922001
#
#    r_hand_speed  l_foot_speed  r_foot_speed  neck_speed  \
# 0     -1.247417     -1.020393      0.281300   -0.155434
# 1     -1.013856     -0.616945      0.849229   -0.283870
# 2     -1.002045     -0.840374      0.569972   -0.606373
# 3     -1.004577     -1.109644      0.354187   -0.827430
# 4     -0.833004     -0.727503      0.731144   -0.900542
#
#    l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0                       2.168930                       1.098686
# 1                       1.868361                       2.573991
# 2                       1.877673                       1.359467
# 3                       0.885428                       0.264883
# 4                      -0.366069                      -0.427021
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       3.888332                       4.152678
# 1                      -0.116317                      -0.313167
# 2                       0.204014                       0.379819
# 3                       0.649897                      -0.195085
# 4                       1.061553                       0.707329
#
#    neck_acceleration_magnitude
# 0                     4.156950
# 1                     1.324764
# 2                     1.739261
# 3                     0.896850
# 4                    -0.809423
#
# [5 rows x 25 columns]

# %%
#Store MinMaxScaler

minMaxDataFull = minMaxData.join(target, how='right')
minMaxDataFull.to_csv(r'datasets/S_O_BANDAI_5frame.csv', index = False)

joblib.dump(transf, r'datasets/scalers/standardizers/S_O_BANDAI_5frame.pkl')
# Out:
# ['datasets/scalers/standardizers/S_O_BANDAI_5frame.pkl']

# %%
data = pd.read_csv('datasets/S_O_BANDAI_5frame.csv')
scaler = joblib.load(r'datasets/scalers/standardizers/S_O_BANDAI_5frame.pkl') 

data.head()
# Out:
#    max_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0          -0.982673                -1.361776                -0.419574
# 1          -0.712179                -0.239658                -1.397944
# 2          -0.373479                 0.303809                -1.404505
# 3          -0.185058                 0.663510                -1.282143
# 4          -0.093530                 0.860543                -1.155933
#
#    max_stride_length  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.051043                  -1.507705                  -0.598805
# 1          -0.774386                  -0.627450                  -1.113656
# 2          -0.834425                  -0.258885                  -1.286375
# 3          -0.555872                  -0.045593                  -1.399540
# 4          -0.164727                   0.043690                  -1.454359
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                 -0.583161                 -1.420212
# 1                 -1.202001                 -0.819670
# 2                 -1.198714                 -0.475107
# 3                 -1.160121                 -0.170775
# 4                 -1.161320                  0.084042
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  r_foot_speed  \
# 0                  -1.743283                 3.293970  ...      0.281300
# 1                  -0.765794                -1.466291  ...      0.849229
# 2                  -1.445642                 0.627744  ...      0.569972
# 3                  -0.830898                -1.061375  ...      0.354187
# 4                  -2.100372                 0.234865  ...      0.731144
#
#    neck_speed  l_hand_acceleration_magnitude  r_hand_acceleration_magnitude  \
# 0   -0.155434                       2.168930                       1.098686
# 1   -0.283870                       1.868361                       2.573991
# 2   -0.606373                       1.877673                       1.359467
# 3   -0.827430                       0.885428                       0.264883
# 4   -0.900542                      -0.366069                      -0.427021
#
#    l_foot_acceleration_magnitude  r_foot_acceleration_magnitude  \
# 0                       3.888332                       4.152678
# 1                      -0.116317                      -0.313167
# 2                       0.204014                       0.379819
# 3                       0.649897                      -0.195085
# 4                       1.061553                       0.707329
#
#    neck_acceleration_magnitude  EMOTION_P  EMOTION_A  EMOTION_D
# 0                     4.156950        0.0        0.0        0.0
# 1                     1.324764        0.0        0.0        0.0
# 2                     1.739261        0.0        0.0        0.0
# 3                     0.896850        0.0        0.0        0.0
# 4                    -0.809423        0.0        0.0        0.0
#
# [5 rows x 28 columns]

# %%
print(data.shape)
# Out:
# (71283, 28)
