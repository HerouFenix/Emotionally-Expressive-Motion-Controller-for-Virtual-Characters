# %% [markdown]
# # Data Profiling - LMA Features Data

# %% [markdown]
# ## Imports

# %%
import ast
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data from CSV

# %%
data = pd.read_csv('datasets/pa/LMA_DATA.csv')
#data = pd.read_csv('datasets/pa/REDUCED_LMA_DATA.csv')

# %%
data.head()
# Out:
#    avg_hand_distance  avg_l_hand_hip_distance  avg_r_hand_hip_distance  \
# 0           0.440457                 0.268696                 0.232545
# 1           0.436696                 0.266929                 0.231202
# 2           0.429922                 0.264091                 0.228568
# 3           0.420335                 0.262567                 0.222643
# 4           0.404506                 0.261934                 0.217203
#
#    avg_feet_distance  avg_l_hand_chest_distance  avg_r_hand_chest_distance  \
# 0           0.262020                   0.469732                   0.453368
# 1           0.270096                   0.468911                   0.452745
# 2           0.278028                   0.467631                   0.451541
# 3           0.286988                   0.467149                   0.448736
# 4           0.295619                   0.450226                   0.435649
#
#    avg_l_elbow_hip_distance  avg_r_elbow_hip_distance  \
# 0                  0.351519                  0.334725
# 1                  0.350940                  0.334144
# 2                  0.350120                  0.333041
# 3                  0.349962                  0.330507
# 4                  0.340933                  0.322575
#
#    avg_chest_pelvis_distance  avg_neck_chest_distance  ...  \
# 0                   0.286151                 0.278746  ...
# 1                   0.286151                 0.278748  ...
# 2                   0.286151                 0.278751  ...
# 3                   0.286151                 0.278767  ...
# 4                   0.286151                 0.278727  ...
#
#    avg_l_foot_velocity_y  avg_l_foot_velocity_z  avg_r_foot_velocity_x  \
# 0              -0.004276              -0.003432              -0.001553
# 1              -0.001323              -0.012256              -0.001765
# 2               0.010741              -0.015035              -0.000829
# 3               0.002394              -0.002680              -0.034921
# 4              -0.134403               0.026550               0.013267
#
#    avg_r_foot_velocity_y  avg_r_foot_velocity_z  avg_upper_body_volume  \
# 0              -0.004276              -0.003432               0.028602
# 1              -0.001323              -0.012256               0.028540
# 2               0.010741              -0.015035               0.028424
# 3               0.002394              -0.002680               0.028234
# 4              -0.134403               0.026550               0.028782
#
#    avg_total_body_volume  avg_distance_traveled  EMOTION_P  EMOTION_A
# 0               0.223692               0.000175       -0.5        0.6
# 1               0.223304               0.000057       -0.5        0.6
# 2               0.222493               0.000173       -0.5        0.6
# 3               0.220828               0.000941       -0.5        0.6
# 4               0.224766               0.002854       -0.5        0.6
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Data Shape

# %%
no_entries = data.shape[0]
no_variables = data.shape[1]

no_variables = no_variables - 2 # Remove the target variable to get the ratio

entries2variables_ration = no_entries/no_variables

print('No. entries:', no_entries, '\nNo. Features:', no_variables)
print('Entries to Feature Ratio:', entries2variables_ration)
# Out:
# No. entries: 43039
# No. Features: 34
# Entries to Feature Ratio: 1265.8529411764705

# %% [markdown]
# ### Variable Types

# %%
print("Feature Types:\n" + str(data.dtypes))
# Out:
# Feature Types:
# avg_hand_distance            float64
# avg_l_hand_hip_distance      float64
# avg_r_hand_hip_distance      float64
# avg_feet_distance            float64
# avg_l_hand_chest_distance    float64
# avg_r_hand_chest_distance    float64
# avg_l_elbow_hip_distance     float64
# avg_r_elbow_hip_distance     float64
# avg_chest_pelvis_distance    float64
# avg_neck_chest_distance      float64
# avg_neck_rotation_w          float64
# avg_neck_rotation_x          float64
# avg_neck_rotation_y          float64
# avg_neck_rotation_z          float64
# avg_pelvis_rotation_w        float64
# avg_pelvis_rotation_x        float64
# avg_pelvis_rotation_y        float64
# avg_pelvis_rotation_z        float64
# std_l_hand_position          float64
# std_r_hand_position          float64
# avg_l_forearm_velocity       float64
# avg_r_forearm_velocity       float64
# avg_pelvis_velocity_x        float64
# avg_pelvis_velocity_y        float64
# avg_pelvis_velocity_z        float64
# avg_l_foot_velocity_x        float64
# avg_l_foot_velocity_y        float64
# avg_l_foot_velocity_z        float64
# avg_r_foot_velocity_x        float64
# avg_r_foot_velocity_y        float64
# avg_r_foot_velocity_z        float64
# avg_upper_body_volume        float64
# avg_total_body_volume        float64
# avg_distance_traveled        float64
# EMOTION_P                    float64
# EMOTION_A                    float64
# dtype: object

# %% [markdown]
# ### Granularity

# %%
variables = data.drop(columns=['EMOTION_P', 'EMOTION_A'])
variables = variables.columns

rows = 12
cols = 3

fig, axs = plt.subplots(rows, cols, figsize=(cols * 8, rows * 9))
i, j = 0, 0
for n in range(len(variables)):
    axs[i, j].set_title('Histogram for %s'%variables[n])
    axs[i, j].set_xlabel(variables[n])
    axs[i, j].set_ylabel('nr records')
    axs[i, j].hist(data[variables[n]].values)

    i, j = (i + 1, 0) if (n+1) % cols == 0 else (i, j + 1)
    
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
fig = plt.figure(figsize=[32,32])
corr_mtx = data.corr()
sns.heatmap(corr_mtx, xticklabels=corr_mtx.columns, yticklabels=corr_mtx.columns, annot=True, cmap='Blues')
plt.title('Correlation analysis')
plt.show()

# %%
df = pd.DataFrame(data)

cor = df.corr()

#Correlation with output variable
cor_target = abs(cor["EMOTION_P"])
print("===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===")
print(cor_target)

cor_target = abs(cor["EMOTION_A"])
print("\n===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===")
print(cor_target)
# Out:
# ===CORRELATION BETWEEN VAR AND PLEASURE COORDINATE===
# avg_hand_distance            0.131267
# avg_l_hand_hip_distance      0.144179
# avg_r_hand_hip_distance      0.149279
# avg_feet_distance            0.045754
# avg_l_hand_chest_distance    0.101829
# avg_r_hand_chest_distance    0.100222
# avg_l_elbow_hip_distance     0.110844
# avg_r_elbow_hip_distance     0.117776
# avg_chest_pelvis_distance    0.055979
# avg_neck_chest_distance      0.043295
# avg_neck_rotation_w          0.062695
# avg_neck_rotation_x          0.037636
# avg_neck_rotation_y          0.093825
# avg_neck_rotation_z          0.064475
# avg_pelvis_rotation_w        0.037697
# avg_pelvis_rotation_x        0.039689
# avg_pelvis_rotation_y        0.040775
# avg_pelvis_rotation_z        0.081058
# std_l_hand_position          0.015363
# std_r_hand_position          0.019009
# avg_l_forearm_velocity       0.001250
# avg_r_forearm_velocity       0.001386
# avg_pelvis_velocity_x        0.011626
# avg_pelvis_velocity_y        0.001758
# avg_pelvis_velocity_z        0.006656
# avg_l_foot_velocity_x        0.005652
# avg_l_foot_velocity_y        0.005270
# avg_l_foot_velocity_z        0.000553
# avg_r_foot_velocity_x        0.004690
# avg_r_foot_velocity_y        0.007975
# avg_r_foot_velocity_z        0.000273
# avg_upper_body_volume        0.115771
# avg_total_body_volume        0.096029
# avg_distance_traveled        0.204351
# EMOTION_P                    1.000000
# EMOTION_A                    0.370733
# Name: EMOTION_P, dtype: float64
#
# ===CORRELATION BETWEEN VAR AND AROUSAL COORDINATE===
# avg_hand_distance            0.058883
# avg_l_hand_hip_distance      0.080700
# avg_r_hand_hip_distance      0.087110
# avg_feet_distance            0.203205
# avg_l_hand_chest_distance    0.003360
# avg_r_hand_chest_distance    0.017384
# avg_l_elbow_hip_distance     0.047752
# avg_r_elbow_hip_distance     0.063525
# avg_chest_pelvis_distance    0.010811
# avg_neck_chest_distance      0.066348
# avg_neck_rotation_w          0.043625
# avg_neck_rotation_x          0.000107
# avg_neck_rotation_y          0.011997
# avg_neck_rotation_z          0.010324
# avg_pelvis_rotation_w        0.004162
# avg_pelvis_rotation_x        0.010890
# avg_pelvis_rotation_y        0.053134
# avg_pelvis_rotation_z        0.034529
# std_l_hand_position          0.047174
# std_r_hand_position          0.040761
# avg_l_forearm_velocity       0.006002
# avg_r_forearm_velocity       0.005194
# avg_pelvis_velocity_x        0.014953
# avg_pelvis_velocity_y        0.000123
# avg_pelvis_velocity_z        0.001418
# avg_l_foot_velocity_x        0.004693
# avg_l_foot_velocity_y        0.006290
# avg_l_foot_velocity_z        0.003055
# avg_r_foot_velocity_x        0.000664
# avg_r_foot_velocity_y        0.000740
# avg_r_foot_velocity_z        0.000510
# avg_upper_body_volume        0.142512
# avg_total_body_volume        0.124516
# avg_distance_traveled        0.251873
# EMOTION_P                    0.370733
# EMOTION_A                    1.000000
# Name: EMOTION_A, dtype: float64
